# %%
import re
import numpy as np

def parse_and_process_iq(log_lines):
    # 存储结构：{counter: [ {...}, ... ]}
    data_per_counter = {}
    ranging_counter = None
    current_data = []
    for line in log_lines:
        # 检测counter标记
        m = re.search(r'I: Ranging data get completed for ranging counter (\d+)', line)
        if m:
            if ranging_counter is not None and current_data:
                # 按channel排序后保存
                current_data.sort(key=lambda x: x['channel'])
                data_per_counter[ranging_counter] = current_data
            ranging_counter = int(m.group(1))
            current_data = []
        # 解析IQ行
        m = re.match(r'id:(\d+), f:(\d+), ch:(\d+), ap:(\d+), li:(-?\d+), lq:(-?\d+), pi:(-?\d+), pq:(-?\d+)', line)
        if m:
            failed = int(m.group(2))
            if failed:
                continue
            channel = int(m.group(3))
            li, lq, pi, pq = map(int, [m.group(5), m.group(6), m.group(7), m.group(8)])
            # local/peer幅值和相位
            local_amp  = np.hypot(li, lq)
            local_phs  = np.arctan2(lq, li)
            peer_amp   = np.hypot(pi, pq)
            peer_phs   = np.arctan2(pq, pi)
            # signal = local x conj(peer)
            sig_i = li * pi - lq * pq
            sig_q = li * pq + lq * pi
            sig_amp = np.hypot(sig_i, sig_q)
            sig_phs = np.arctan2(sig_q, sig_i)
            entry = {
                'channel': channel,
                'local':  {'i': li, 'q': lq, 'amplitude': local_amp, 'phase': local_phs},
                'peer':   {'i': pi, 'q': pq, 'amplitude': peer_amp, 'phase': peer_phs},
                'signal': {'i': sig_i, 'q': sig_q, 'amplitude': sig_amp, 'phase': sig_phs},
            }
            current_data.append(entry)
    # 最后一组
    if ranging_counter is not None and current_data:
        current_data.sort(key=lambda x: x['channel'])
        data_per_counter[ranging_counter] = current_data
    return data_per_counter

# 用法举例
if __name__ == '__main__':
    # 1mcable.iq, angle.iq.test, close.AT.iq.txt, cable.angle.test
    with open('1mcable.iq.txt', 'r', encoding='utf-8') as f:
        log_lines = f.readlines()
    data_per_counter = parse_and_process_iq(log_lines)

    # 访问数据示例
    for counter, ch_list in data_per_counter.items():
        print(f'Counter {counter}:')
        for entry in ch_list:
            ch = entry['channel']
            la, lp = entry['local']['amplitude'], entry['local']['phase']
            pa, pp = entry['peer']['amplitude'], entry['peer']['phase']
            sa, sp = entry['signal']['amplitude'], entry['signal']['phase']
            print(f' ch{ch}: local_amp={la:.1f} local_phase={lp:.3f}  '
                  f'peer_amp={pa:.1f} peer_phase={pp:.3f}  '
                  f'signal_amp={sa:.1f} signal_phase={sp:.3f}')
# Out:
# Counter 0:
#  ch2: local_amp=1130.4 local_phase=-2.466  peer_amp=1174.5 peer_phase=-2.271  signal_amp=1327639.9 signal_phase=1.546
#  ch5: local_amp=1131.0 local_phase=-0.207  peer_amp=1174.5 peer_phase=1.398  signal_amp=1328419.0 signal_phase=1.191
#  ch8: local_amp=1131.3 local_phase=-2.156  peer_amp=1174.7 peer_phase=3.073  signal_amp=1328986.7 signal_phase=0.917
#  ch11: local_amp=1130.7 local_phase=1.536  peer_amp=1175.8 peer_phase=-0.969  signal_amp=1329450.6 signal_phase=0.568
#  ch14: local_amp=1131.5 local_phase=-1.115  peer_amp=1175.7 peer_phase=1.481  signal_amp=1330285.6 signal_phase=0.366
#  ch17: local_amp=1131.0 local_phase=-2.423  peer_amp=1175.4 peer_phase=2.374  signal_amp=1329414.5 signal_phase=-0.048
#  ch20: local_amp=1132.0 local_phase=-1.570  peer_amp=1176.1 peer_phase=1.224  signal_amp=1331357.6 signal_phase=-0.346
#  ch26: local_amp=1132.0 local_phase=-2.588  peer_amp=1174.4 peer_phase=1.666  signal_amp=1329352.0 signal_phase=-0.922
#  ch29: local_amp=1131.5 local_phase=-0.433  peer_amp=1176.0 peer_phase=-0.901  signal_amp=1330679.9 signal_phase=-1.334
#  ch32: local_amp=1131.4 local_phase=-0.379  peer_amp=1175.2 peer_phase=-1.202  signal_amp=1329621.6 signal_phase=-1.581
#  ch35: local_amp=1131.1 local_phase=-2.984  peer_amp=1176.8 peer_phase=1.003  signal_amp=1331020.5 signal_phase=-1.981
#  ch38: local_amp=1132.4 local_phase=-1.955  peer_amp=1175.7 peer_phase=-0.320  signal_amp=1331376.0 signal_phase=-2.275
#  ch41: local_amp=1133.0 local_phase=1.571  peer_amp=1176.4 peer_phase=2.079  signal_amp=1332885.8 signal_phase=-2.634
#  ch44: local_amp=1132.0 local_phase=-1.872  peer_amp=1175.6 peer_phase=-1.144  signal_amp=1330812.5 signal_phase=-3.016
#  ch47: local_amp=1131.7 local_phase=-2.142  peer_amp=1175.9 peer_phase=-1.267  signal_amp=1330842.3 signal_phase=2.874
#  ch50: local_amp=1131.6 local_phase=-1.277  peer_amp=1174.5 peer_phase=-2.350  signal_amp=1329074.6 signal_phase=2.657
# Counter 2:
#  ch2: local_amp=1132.3 local_phase=-2.519  peer_amp=1173.8 peer_phase=-2.213  signal_amp=1329041.4 signal_phase=1.551
#  ch5: local_amp=1130.1 local_phase=2.275  peer_amp=1176.0 peer_phase=-1.036  signal_amp=1328992.6 signal_phase=1.239
#  ch8: local_amp=1129.8 local_phase=0.222  peer_amp=1173.8 peer_phase=0.681  signal_amp=1326165.1 signal_phase=0.903
#  ch11: local_amp=1131.1 local_phase=-0.613  peer_amp=1174.5 peer_phase=1.215  signal_amp=1328512.4 signal_phase=0.602
#  ch14: local_amp=1129.6 local_phase=0.860  peer_amp=1173.7 peer_phase=-0.516  signal_amp=1325817.2 signal_phase=0.344
#  ch17: local_amp=1131.0 local_phase=0.811  peer_amp=1174.9 peer_phase=-0.811  signal_amp=1328851.0 signal_phase=-0.000
#  ch20: local_amp=1128.8 local_phase=2.248  peer_amp=1176.3 peer_phase=-2.585  signal_amp=1327819.4 signal_phase=-0.338
#  ch26: local_amp=1132.2 local_phase=2.756  peer_amp=1175.3 peer_phase=2.605  signal_amp=1330660.7 signal_phase=-0.923
#  ch29: local_amp=1132.0 local_phase=-1.498  peer_amp=1174.6 peer_phase=0.236  signal_amp=1329666.6 signal_phase=-1.262
#  ch32: local_amp=1132.1 local_phase=-2.731  peer_amp=1175.2 peer_phase=1.153  signal_amp=1330451.2 signal_phase=-1.578
#  ch35: local_amp=1130.0 local_phase=0.639  peer_amp=1176.3 peer_phase=-2.663  signal_amp=1329240.8 signal_phase=-2.024
#  ch38: local_amp=1132.1 local_phase=-1.556  peer_amp=1176.4 peer_phase=-0.710  signal_amp=1331852.3 signal_phase=-2.266
#  ch41: local_amp=1130.5 local_phase=2.556  peer_amp=1174.0 peer_phase=1.119  signal_amp=1327199.5 signal_phase=-2.609
#  ch44: local_amp=1131.6 local_phase=1.231  peer_amp=1174.8 peer_phase=2.036  signal_amp=1329490.9 signal_phase=-3.016
#  ch47: local_amp=1132.9 local_phase=1.672  peer_amp=1175.7 peer_phase=1.294  signal_amp=1331861.3 signal_phase=2.967
#  ch50: local_amp=1131.5 local_phase=-2.269  peer_amp=1175.8 peer_phase=-1.396  signal_amp=1330414.9 signal_phase=2.618
# Counter 4:
#  ch2: local_amp=1130.6 local_phase=-2.734  peer_amp=1175.1 peer_phase=-2.087  signal_amp=1328523.3 signal_phase=1.462
#  ch5: local_amp=1132.6 local_phase=-0.700  peer_amp=1176.3 peer_phase=1.816  signal_amp=1332313.2 signal_phase=1.116
#  ch8: local_amp=1130.7 local_phase=-1.462  peer_amp=1174.6 peer_phase=2.246  signal_amp=1328112.6 signal_phase=0.784
#  ch11: local_amp=1131.2 local_phase=-1.554  peer_amp=1174.4 peer_phase=2.045  signal_amp=1328484.7 signal_phase=0.491
#  ch14: local_amp=1132.5 local_phase=1.214  peer_amp=1174.0 peer_phase=-0.858  signal_amp=1329589.4 signal_phase=0.356
#  ch17: local_amp=1131.8 local_phase=1.886  peer_amp=1176.5 peer_phase=-1.968  signal_amp=1331612.7 signal_phase=-0.082
#  ch20: local_amp=1130.9 local_phase=1.039  peer_amp=1176.7 peer_phase=-1.418  signal_amp=1330733.8 signal_phase=-0.379
#  ch26: local_amp=1132.5 local_phase=-1.123  peer_amp=1175.4 peer_phase=0.151  signal_amp=1331136.4 signal_phase=-0.972
#  ch29: local_amp=1132.3 local_phase=0.899  peer_amp=1175.7 peer_phase=-2.274  signal_amp=1331172.8 signal_phase=-1.375
#  ch32: local_amp=1132.4 local_phase=-0.494  peer_amp=1174.8 peer_phase=-1.202  signal_amp=1330363.7 signal_phase=-1.697
#  ch35: local_amp=1133.2 local_phase=1.966  peer_amp=1175.2 peer_phase=2.217  signal_amp=1331779.1 signal_phase=-2.100
#  ch38: local_amp=1132.0 local_phase=1.841  peer_amp=1174.5 peer_phase=2.091  signal_amp=1329549.6 signal_phase=-2.351
#  ch41: local_amp=1132.8 local_phase=-2.355  peer_amp=1176.0 peer_phase=-0.430  signal_amp=1332100.9 signal_phase=-2.785
#  ch44: local_amp=1132.0 local_phase=-1.528  peer_amp=1175.6 peer_phase=-1.540  signal_amp=1330745.4 signal_phase=-3.069
#  ch47: local_amp=1134.2 local_phase=3.124  peer_amp=1174.9 peer_phase=-0.349  signal_amp=1332558.3 signal_phase=2.775
#  ch50: local_amp=1133.0 local_phase=2.911  peer_amp=1174.2 peer_phase=-0.327  signal_amp=1330334.1 signal_phase=2.584
# Counter 6:
#  ch2: local_amp=1133.1 local_phase=-2.171  peer_amp=1175.1 peer_phase=-2.584  signal_amp=1331474.7 signal_phase=1.528
#  ch5: local_amp=1131.2 local_phase=-0.296  peer_amp=1175.5 peer_phase=1.506  signal_amp=1329685.3 signal_phase=1.210
#  ch8: local_amp=1132.2 local_phase=3.007  peer_amp=1175.5 peer_phase=-2.093  signal_amp=1330938.0 signal_phase=0.914
#  ch11: local_amp=1132.3 local_phase=-2.851  peer_amp=1175.9 peer_phase=-2.884  signal_amp=1331535.9 signal_phase=0.548
#  ch14: local_amp=1132.3 local_phase=-3.045  peer_amp=1176.0 peer_phase=-2.915  signal_amp=1331553.7 signal_phase=0.323
#  ch17: local_amp=1132.6 local_phase=1.762  peer_amp=1175.3 peer_phase=-1.795  signal_amp=1331189.2 signal_phase=-0.033
#  ch20: local_amp=1131.0 local_phase=0.073  peer_amp=1175.8 peer_phase=-0.450  signal_amp=1329848.6 signal_phase=-0.377
#  ch26: local_amp=1132.8 local_phase=-1.767  peer_amp=1176.3 peer_phase=0.841  signal_amp=1332524.0 signal_phase=-0.926
#  ch29: local_amp=1130.8 local_phase=1.515  peer_amp=1175.5 peer_phase=-2.793  signal_amp=1329216.5 signal_phase=-1.278
#  ch32: local_amp=1131.6 local_phase=-0.033  peer_amp=1174.4 peer_phase=-1.597  signal_amp=1328967.4 signal_phase=-1.630
#  ch35: local_amp=1132.8 local_phase=1.177  peer_amp=1176.9 peer_phase=3.102  signal_amp=1333246.2 signal_phase=-2.004
#  ch38: local_amp=1133.3 local_phase=2.988  peer_amp=1175.8 peer_phase=0.996  signal_amp=1332505.9 signal_phase=-2.299
#  ch41: local_amp=1131.9 local_phase=2.776  peer_amp=1176.1 peer_phase=0.770  signal_amp=1331212.3 signal_phase=-2.737
#  ch44: local_amp=1130.7 local_phase=1.702  peer_amp=1175.3 peer_phase=1.508  signal_amp=1328980.2 signal_phase=-3.073
#  ch47: local_amp=1132.0 local_phase=2.865  peer_amp=1175.1 peer_phase=-0.014  signal_amp=1330211.9 signal_phase=2.851
#  ch50: local_amp=1130.3 local_phase=1.522  peer_amp=1174.9 peer_phase=1.100  signal_amp=1327990.9 signal_phase=2.622
# Counter 8:
#  ch2: local_amp=1132.9 local_phase=0.340  peer_amp=1172.7 peer_phase=1.119  signal_amp=1328548.2 signal_phase=1.459
#  ch5: local_amp=1132.0 local_phase=1.831  peer_amp=1174.9 peer_phase=-0.673  signal_amp=1330032.6 signal_phase=1.158
#  ch8: local_amp=1132.3 local_phase=-2.967  peer_amp=1176.6 peer_phase=-2.454  signal_amp=1332181.2 signal_phase=0.863
#  ch11: local_amp=1132.3 local_phase=-0.839  peer_amp=1175.5 peer_phase=1.393  signal_amp=1331026.1 signal_phase=0.554
#  ch14: local_amp=1132.9 local_phase=-1.361  peer_amp=1174.8 peer_phase=1.797  signal_amp=1330896.6 signal_phase=0.436
#  ch17: local_amp=1132.4 local_phase=-0.689  peer_amp=1176.0 peer_phase=0.576  signal_amp=1331723.1 signal_phase=-0.113
#  ch20: local_amp=1133.2 local_phase=2.906  peer_amp=1175.9 peer_phase=3.019  signal_amp=1332452.2 signal_phase=-0.358
#  ch26: local_amp=1134.5 local_phase=3.113  peer_amp=1176.2 peer_phase=2.207  signal_amp=1334375.8 signal_phase=-0.963
#  ch29: local_amp=1132.7 local_phase=-1.708  peer_amp=1174.9 peer_phase=0.407  signal_amp=1330793.8 signal_phase=-1.301
#  ch32: local_amp=1131.0 local_phase=-0.146  peer_amp=1175.9 peer_phase=-1.441  signal_amp=1329850.0 signal_phase=-1.587
#  ch35: local_amp=1132.4 local_phase=2.524  peer_amp=1176.4 peer_phase=1.852  signal_amp=1332079.4 signal_phase=-1.907
#  ch38: local_amp=1131.6 local_phase=0.450  peer_amp=1176.1 peer_phase=-2.795  signal_amp=1330838.1 signal_phase=-2.345
#  ch41: local_amp=1135.0 local_phase=-2.847  peer_amp=1175.8 peer_phase=0.115  signal_amp=1334542.4 signal_phase=-2.732
#  ch44: local_amp=1133.6 local_phase=0.801  peer_amp=1175.0 peer_phase=2.494  signal_amp=1332027.3 signal_phase=-2.988
#  ch47: local_amp=1131.6 local_phase=1.366  peer_amp=1175.2 peer_phase=1.591  signal_amp=1329930.9 signal_phase=2.957
#  ch50: local_amp=1131.5 local_phase=2.140  peer_amp=1175.3 peer_phase=0.547  signal_amp=1329864.0 signal_phase=2.687
# Counter 10:
#  ch2: local_amp=1130.9 local_phase=-2.107  peer_amp=1175.7 peer_phase=-2.716  signal_amp=1329562.2 signal_phase=1.460
#  ch5: local_amp=1131.5 local_phase=-1.829  peer_amp=1178.0 peer_phase=3.025  signal_amp=1332933.5 signal_phase=1.196
#  ch8: local_amp=1130.8 local_phase=-0.886  peer_amp=1175.8 peer_phase=1.712  signal_amp=1329512.9 signal_phase=0.826
#  ch11: local_amp=1132.6 local_phase=-2.106  peer_amp=1177.0 peer_phase=2.606  signal_amp=1333066.1 signal_phase=0.499
#  ch14: local_amp=1130.2 local_phase=1.634  peer_amp=1176.1 peer_phase=-1.296  signal_amp=1329253.6 signal_phase=0.338
#  ch17: local_amp=1131.3 local_phase=-1.647  peer_amp=1176.4 peer_phase=1.494  signal_amp=1330884.2 signal_phase=-0.153
#  ch20: local_amp=1132.1 local_phase=0.045  peer_amp=1176.3 peer_phase=-0.477  signal_amp=1331719.9 signal_phase=-0.432
#  ch26: local_amp=1132.7 local_phase=1.974  peer_amp=1176.9 peer_phase=-2.935  signal_amp=1333061.8 signal_phase=-0.962
#  ch29: local_amp=1132.5 local_phase=-0.660  peer_amp=1176.3 peer_phase=-0.711  signal_amp=1332225.4 signal_phase=-1.371
#  ch32: local_amp=1130.9 local_phase=0.408  peer_amp=1176.9 peer_phase=-2.079  signal_amp=1331022.9 signal_phase=-1.671
#  ch35: local_amp=1132.5 local_phase=1.121  peer_amp=1177.8 peer_phase=3.062  signal_amp=1333762.0 signal_phase=-2.100
#  ch38: local_amp=1132.6 local_phase=2.894  peer_amp=1176.7 peer_phase=1.029  signal_amp=1332732.2 signal_phase=-2.361
#  ch41: local_amp=1130.9 local_phase=1.610  peer_amp=1177.5 peer_phase=2.027  signal_amp=1331633.1 signal_phase=-2.646
#  ch44: local_amp=1131.8 local_phase=1.789  peer_amp=1176.3 peer_phase=1.399  signal_amp=1331377.4 signal_phase=-3.095
#  ch47: local_amp=1132.5 local_phase=0.129  peer_amp=1176.1 peer_phase=2.703  signal_amp=1331882.6 signal_phase=2.833
#  ch50: local_amp=1129.8 local_phase=0.478  peer_amp=1176.8 peer_phase=2.050  signal_amp=1329493.2 signal_phase=2.529
# Counter 12:
#  ch2: local_amp=1134.0 local_phase=-1.576  peer_amp=1174.7 peer_phase=3.087  signal_amp=1332179.1 signal_phase=1.511
#  ch5: local_amp=1133.4 local_phase=-2.195  peer_amp=1177.1 peer_phase=-2.976  signal_amp=1334146.7 signal_phase=1.113
#  ch8: local_amp=1130.8 local_phase=-1.357  peer_amp=1174.9 peer_phase=2.228  signal_amp=1328549.8 signal_phase=0.871
#  ch11: local_amp=1131.4 local_phase=0.165  peer_amp=1174.7 peer_phase=0.440  signal_amp=1329071.9 signal_phase=0.605
#  ch14: local_amp=1132.7 local_phase=-1.753  peer_amp=1175.1 peer_phase=2.111  signal_amp=1331051.5 signal_phase=0.358
#  ch17: local_amp=1133.2 local_phase=-3.021  peer_amp=1175.4 peer_phase=2.933  signal_amp=1331944.5 signal_phase=-0.088
#  ch20: local_amp=1133.1 local_phase=-1.486  peer_amp=1176.3 peer_phase=1.092  signal_amp=1332843.9 signal_phase=-0.394
#  ch26: local_amp=1132.4 local_phase=-0.549  peer_amp=1176.1 peer_phase=-0.518  signal_amp=1331869.8 signal_phase=-1.067
#  ch29: local_amp=1132.6 local_phase=-1.731  peer_amp=1176.2 peer_phase=0.454  signal_amp=1332141.6 signal_phase=-1.277
#  ch32: local_amp=1131.4 local_phase=-0.290  peer_amp=1176.5 peer_phase=-1.393  signal_amp=1331110.9 signal_phase=-1.684
#  ch35: local_amp=1131.5 local_phase=1.101  peer_amp=1177.0 peer_phase=3.136  signal_amp=1331764.1 signal_phase=-2.046
#  ch38: local_amp=1132.3 local_phase=2.615  peer_amp=1175.5 peer_phase=1.425  signal_amp=1331074.6 signal_phase=-2.243
#  ch41: local_amp=1133.2 local_phase=3.055  peer_amp=1175.9 peer_phase=0.496  signal_amp=1332590.5 signal_phase=-2.732
#  ch44: local_amp=1133.7 local_phase=-0.435  peer_amp=1176.0 peer_phase=-2.619  signal_amp=1333205.0 signal_phase=-3.054
#  ch47: local_amp=1133.0 local_phase=0.529  peer_amp=1175.1 peer_phase=2.485  signal_amp=1331372.6 signal_phase=3.015
#  ch50: local_amp=1132.3 local_phase=-0.402  peer_amp=1175.8 peer_phase=3.006  signal_amp=1331311.6 signal_phase=2.604
# Counter 14:
#  ch2: local_amp=1130.3 local_phase=1.442  peer_amp=1174.8 peer_phase=0.148  signal_amp=1327930.8 signal_phase=1.590
#  ch5: local_amp=1131.4 local_phase=-0.835  peer_amp=1176.6 peer_phase=1.987  signal_amp=1331154.9 signal_phase=1.152
#  ch8: local_amp=1130.6 local_phase=1.720  peer_amp=1175.9 peer_phase=-0.884  signal_amp=1329443.2 signal_phase=0.836
#  ch11: local_amp=1130.8 local_phase=-1.228  peer_amp=1176.3 peer_phase=1.795  signal_amp=1330139.8 signal_phase=0.566
#  ch14: local_amp=1131.0 local_phase=1.445  peer_amp=1175.5 peer_phase=-1.065  signal_amp=1329375.9 signal_phase=0.380
#  ch17: local_amp=1132.3 local_phase=1.938  peer_amp=1175.3 peer_phase=-1.972  signal_amp=1330818.8 signal_phase=-0.034
#  ch20: local_amp=1130.7 local_phase=1.823  peer_amp=1177.9 peer_phase=-2.180  signal_amp=1331878.3 signal_phase=-0.357
#  ch26: local_amp=1132.3 local_phase=-1.995  peer_amp=1176.0 peer_phase=1.013  signal_amp=1331582.3 signal_phase=-0.981
#  ch29: local_amp=1132.1 local_phase=2.722  peer_amp=1176.3 peer_phase=2.261  signal_amp=1331687.8 signal_phase=-1.300
#  ch32: local_amp=1132.1 local_phase=-3.126  peer_amp=1175.1 peer_phase=1.461  signal_amp=1330383.8 signal_phase=-1.665
#  ch35: local_amp=1134.0 local_phase=-1.360  peer_amp=1176.8 peer_phase=-0.637  signal_amp=1334567.8 signal_phase=-1.997
#  ch38: local_amp=1132.4 local_phase=-0.065  peer_amp=1176.0 peer_phase=-2.305  signal_amp=1331773.1 signal_phase=-2.370
#  ch41: local_amp=1133.3 local_phase=-1.523  peer_amp=1176.1 peer_phase=-1.153  signal_amp=1332831.6 signal_phase=-2.676
#  ch44: local_amp=1132.5 local_phase=2.401  peer_amp=1175.2 peer_phase=0.778  signal_amp=1330980.2 signal_phase=-3.104
#  ch47: local_amp=1132.6 local_phase=2.177  peer_amp=1175.5 peer_phase=0.764  signal_amp=1331358.4 signal_phase=2.940
#  ch50: local_amp=1131.6 local_phase=1.455  peer_amp=1175.1 peer_phase=1.183  signal_amp=1329762.4 signal_phase=2.638
# Counter 16:
#  ch2: local_amp=1129.4 local_phase=0.974  peer_amp=1175.6 peer_phase=0.524  signal_amp=1327757.4 signal_phase=1.497
#  ch5: local_amp=1131.4 local_phase=-1.814  peer_amp=1177.1 peer_phase=2.908  signal_amp=1331800.8 signal_phase=1.093
#  ch8: local_amp=1130.6 local_phase=0.407  peer_amp=1174.2 peer_phase=0.392  signal_amp=1327532.9 signal_phase=0.800
#  ch11: local_amp=1131.9 local_phase=-3.031  peer_amp=1177.1 peer_phase=-2.690  signal_amp=1332440.9 signal_phase=0.563
#  ch14: local_amp=1130.7 local_phase=-2.346  peer_amp=1176.5 peer_phase=2.625  signal_amp=1330271.2 signal_phase=0.280
#  ch17: local_amp=1131.2 local_phase=-2.811  peer_amp=1177.4 peer_phase=2.749  signal_amp=1331849.3 signal_phase=-0.062
#  ch20: local_amp=1129.9 local_phase=0.619  peer_amp=1176.0 peer_phase=-1.026  signal_amp=1328766.3 signal_phase=-0.407
#  ch26: local_amp=1131.9 local_phase=2.184  peer_amp=1176.0 peer_phase=-3.136  signal_amp=1331179.2 signal_phase=-0.952
#  ch29: local_amp=1132.2 local_phase=2.126  peer_amp=1176.8 peer_phase=2.835  signal_amp=1332385.0 signal_phase=-1.322
#  ch32: local_amp=1131.6 local_phase=0.850  peer_amp=1175.0 peer_phase=-2.498  signal_amp=1329625.0 signal_phase=-1.648
#  ch35: local_amp=1130.3 local_phase=1.596  peer_amp=1177.4 peer_phase=2.701  signal_amp=1330850.3 signal_phase=-1.986
#  ch38: local_amp=1130.9 local_phase=2.275  peer_amp=1176.0 peer_phase=1.725  signal_amp=1329917.6 signal_phase=-2.283
#  ch41: local_amp=1132.2 local_phase=0.333  peer_amp=1178.0 peer_phase=-2.957  signal_amp=1333660.9 signal_phase=-2.624
#  ch44: local_amp=1130.8 local_phase=-1.696  peer_amp=1177.1 peer_phase=-1.368  signal_amp=1331100.5 signal_phase=-3.064
#  ch47: local_amp=1131.5 local_phase=1.245  peer_amp=1176.5 peer_phase=1.668  signal_amp=1331217.1 signal_phase=2.913
#  ch50: local_amp=1132.2 local_phase=1.633  peer_amp=1175.3 peer_phase=1.011  signal_amp=1330664.6 signal_phase=2.644
# Counter 18:
#  ch2: local_amp=1128.8 local_phase=1.188  peer_amp=1174.2 peer_phase=0.374  signal_amp=1325464.1 signal_phase=1.562
#  ch5: local_amp=1129.7 local_phase=2.230  peer_amp=1177.4 peer_phase=-0.988  signal_amp=1330118.8 signal_phase=1.242
#  ch8: local_amp=1129.7 local_phase=1.843  peer_amp=1173.8 peer_phase=-0.929  signal_amp=1326010.8 signal_phase=0.915
#  ch11: local_amp=1131.3 local_phase=0.113  peer_amp=1175.9 peer_phase=0.480  signal_amp=1330233.7 signal_phase=0.593
#  ch14: local_amp=1129.3 local_phase=2.511  peer_amp=1175.8 peer_phase=-2.004  signal_amp=1327830.6 signal_phase=0.506
#  ch17: local_amp=1130.3 local_phase=-1.386  peer_amp=1174.6 peer_phase=1.402  signal_amp=1327696.2 signal_phase=0.017
#  ch20: local_amp=1131.5 local_phase=2.369  peer_amp=1174.7 peer_phase=-2.781  signal_amp=1329176.2 signal_phase=-0.412
#  ch26: local_amp=1129.3 local_phase=0.251  peer_amp=1176.2 peer_phase=-1.231  signal_amp=1328287.0 signal_phase=-0.980
#  ch29: local_amp=1131.8 local_phase=1.312  peer_amp=1174.6 peer_phase=-2.547  signal_amp=1329397.8 signal_phase=-1.235
#  ch32: local_amp=1133.8 local_phase=-2.065  peer_amp=1175.6 peer_phase=0.499  signal_amp=1332846.6 signal_phase=-1.566
#  ch35: local_amp=1131.2 local_phase=2.441  peer_amp=1176.6 peer_phase=1.837  signal_amp=1330967.2 signal_phase=-2.004
#  ch38: local_amp=1133.4 local_phase=-2.737  peer_amp=1176.1 peer_phase=0.490  signal_amp=1333055.7 signal_phase=-2.248
#  ch41: local_amp=1133.2 local_phase=-1.922  peer_amp=1176.9 peer_phase=-0.745  signal_amp=1333659.9 signal_phase=-2.667
#  ch44: local_amp=1131.0 local_phase=0.671  peer_amp=1177.7 peer_phase=2.577  signal_amp=1331976.5 signal_phase=-3.035
#  ch47: local_amp=1132.7 local_phase=0.167  peer_amp=1175.3 peer_phase=2.869  signal_amp=1331250.5 signal_phase=3.036
#  ch50: local_amp=1130.2 local_phase=-0.881  peer_amp=1175.3 peer_phase=-2.717  signal_amp=1328304.5 signal_phase=2.685
# Counter 20:
#  ch2: local_amp=1132.0 local_phase=-2.478  peer_amp=1176.8 peer_phase=-2.245  signal_amp=1332128.3 signal_phase=1.559
#  ch5: local_amp=1129.8 local_phase=1.404  peer_amp=1175.9 peer_phase=-0.230  signal_amp=1328527.6 signal_phase=1.174
#  ch8: local_amp=1130.8 local_phase=1.749  peer_amp=1176.0 peer_phase=-0.920  signal_amp=1329883.0 signal_phase=0.828
#  ch11: local_amp=1130.5 local_phase=2.787  peer_amp=1176.6 peer_phase=-2.222  signal_amp=1330193.3 signal_phase=0.565
#  ch14: local_amp=1128.9 local_phase=1.064  peer_amp=1175.5 peer_phase=-0.691  signal_amp=1327069.7 signal_phase=0.373
#  ch17: local_amp=1133.2 local_phase=-1.972  peer_amp=1176.0 peer_phase=1.958  signal_amp=1332659.3 signal_phase=-0.015
#  ch20: local_amp=1130.6 local_phase=1.877  peer_amp=1176.4 peer_phase=-2.187  signal_amp=1330134.3 signal_phase=-0.310
#  ch26: local_amp=1131.6 local_phase=-0.899  peer_amp=1176.6 peer_phase=-0.033  signal_amp=1331541.8 signal_phase=-0.933
#  ch29: local_amp=1131.9 local_phase=-0.511  peer_amp=1176.2 peer_phase=-0.805  signal_amp=1331225.8 signal_phase=-1.317
#  ch32: local_amp=1131.3 local_phase=-0.891  peer_amp=1176.6 peer_phase=-0.782  signal_amp=1331167.6 signal_phase=-1.673
#  ch35: local_amp=1131.8 local_phase=-0.676  peer_amp=1177.1 peer_phase=-1.348  signal_amp=1332203.3 signal_phase=-2.024
#  ch38: local_amp=1132.1 local_phase=-1.584  peer_amp=1176.6 peer_phase=-0.736  signal_amp=1332074.5 signal_phase=-2.320
#  ch41: local_amp=1131.6 local_phase=-0.550  peer_amp=1175.8 peer_phase=-2.148  signal_amp=1330472.6 signal_phase=-2.698
#  ch44: local_amp=1131.0 local_phase=-0.868  peer_amp=1176.5 peer_phase=-2.227  signal_amp=1330603.3 signal_phase=-3.095
#  ch47: local_amp=1131.1 local_phase=2.840  peer_amp=1174.9 peer_phase=0.057  signal_amp=1328895.5 signal_phase=2.897
#  ch50: local_amp=1131.0 local_phase=1.432  peer_amp=1175.4 peer_phase=1.243  signal_amp=1329361.5 signal_phase=2.675
# Counter 22:
#  ch2: local_amp=1131.8 local_phase=-1.996  peer_amp=1176.5 peer_phase=-2.806  signal_amp=1331573.7 signal_phase=1.481
#  ch5: local_amp=1132.6 local_phase=0.155  peer_amp=1176.1 peer_phase=1.071  signal_amp=1332008.6 signal_phase=1.226
#  ch8: local_amp=1132.0 local_phase=3.030  peer_amp=1176.1 peer_phase=-2.133  signal_amp=1331357.7 signal_phase=0.897
#  ch11: local_amp=1131.5 local_phase=0.314  peer_amp=1175.6 peer_phase=0.303  signal_amp=1330206.8 signal_phase=0.618
#  ch14: local_amp=1131.1 local_phase=0.383  peer_amp=1176.0 peer_phase=-0.001  signal_amp=1330144.3 signal_phase=0.382
#  ch17: local_amp=1131.0 local_phase=-0.277  peer_amp=1176.1 peer_phase=0.321  signal_amp=1330147.5 signal_phase=0.044
#  ch20: local_amp=1132.0 local_phase=1.120  peer_amp=1177.1 peer_phase=-1.510  signal_amp=1332518.8 signal_phase=-0.390
#  ch26: local_amp=1131.9 local_phase=-0.912  peer_amp=1176.1 peer_phase=-0.093  signal_amp=1331224.3 signal_phase=-1.005
#  ch29: local_amp=1131.7 local_phase=1.270  peer_amp=1176.6 peer_phase=-2.616  signal_amp=1331597.1 signal_phase=-1.346
#  ch32: local_amp=1133.8 local_phase=-2.189  peer_amp=1176.0 peer_phase=0.539  signal_amp=1333270.6 signal_phase=-1.649
#  ch35: local_amp=1134.2 local_phase=-2.219  peer_amp=1175.2 peer_phase=0.287  signal_amp=1332890.9 signal_phase=-1.932
#  ch38: local_amp=1132.3 local_phase=-0.712  peer_amp=1176.2 peer_phase=-1.590  signal_amp=1331789.6 signal_phase=-2.302
#  ch41: local_amp=1133.1 local_phase=-1.497  peer_amp=1177.1 peer_phase=-1.207  signal_amp=1333791.3 signal_phase=-2.703
#  ch44: local_amp=1131.2 local_phase=1.317  peer_amp=1175.4 peer_phase=1.914  signal_amp=1329603.7 signal_phase=-3.053
#  ch47: local_amp=1132.9 local_phase=0.770  peer_amp=1177.3 peer_phase=2.128  signal_amp=1333823.1 signal_phase=2.899
#  ch50: local_amp=1131.3 local_phase=2.055  peer_amp=1175.7 peer_phase=0.620  signal_amp=1330044.9 signal_phase=2.675
# Counter 24:
#  ch2: local_amp=1129.3 local_phase=0.792  peer_amp=1172.9 peer_phase=0.814  signal_amp=1324499.1 signal_phase=1.607
#  ch5: local_amp=1131.7 local_phase=1.087  peer_amp=1174.9 peer_phase=0.214  signal_amp=1329607.4 signal_phase=1.302
#  ch8: local_amp=1130.6 local_phase=-0.700  peer_amp=1173.1 peer_phase=1.580  signal_amp=1326227.5 signal_phase=0.881
#  ch11: local_amp=1130.5 local_phase=1.678  peer_amp=1176.4 peer_phase=-1.165  signal_amp=1329884.5 signal_phase=0.513
#  ch14: local_amp=1132.5 local_phase=-1.464  peer_amp=1175.7 peer_phase=1.914  signal_amp=1331457.2 signal_phase=0.451
#  ch17: local_amp=1130.2 local_phase=-2.548  peer_amp=1175.0 peer_phase=2.581  signal_amp=1328018.3 signal_phase=0.033
#  ch20: local_amp=1129.6 local_phase=1.916  peer_amp=1176.0 peer_phase=-2.221  signal_amp=1328386.6 signal_phase=-0.305
#  ch26: local_amp=1132.3 local_phase=2.629  peer_amp=1176.4 peer_phase=2.713  signal_amp=1332134.9 signal_phase=-0.941
#  ch29: local_amp=1131.0 local_phase=-1.318  peer_amp=1174.4 peer_phase=0.104  signal_amp=1328170.3 signal_phase=-1.214
#  ch32: local_amp=1132.2 local_phase=-2.451  peer_amp=1175.7 peer_phase=0.893  signal_amp=1331154.0 signal_phase=-1.558
#  ch35: local_amp=1131.3 local_phase=0.725  peer_amp=1175.9 peer_phase=-2.635  signal_amp=1330372.2 signal_phase=-1.910
#  ch38: local_amp=1131.2 local_phase=-0.364  peer_amp=1175.7 peer_phase=-1.932  signal_amp=1329953.1 signal_phase=-2.296
#  ch41: local_amp=1132.2 local_phase=-0.287  peer_amp=1176.1 peer_phase=-2.395  signal_amp=1331518.6 signal_phase=-2.681
#  ch44: local_amp=1132.1 local_phase=-2.785  peer_amp=1175.3 peer_phase=-0.224  signal_amp=1330658.2 signal_phase=-3.009
#  ch47: local_amp=1132.8 local_phase=-2.356  peer_amp=1175.4 peer_phase=-0.930  signal_amp=1331479.3 signal_phase=2.997
#  ch50: local_amp=1132.6 local_phase=-2.933  peer_amp=1174.9 peer_phase=-0.600  signal_amp=1330784.9 signal_phase=2.751
# Counter 26:
#  ch2: local_amp=1130.2 local_phase=-0.584  peer_amp=1174.2 peer_phase=2.195  signal_amp=1327122.9 signal_phase=1.611
#  ch5: local_amp=1129.6 local_phase=-0.034  peer_amp=1175.4 peer_phase=1.318  signal_amp=1327737.1 signal_phase=1.284
#  ch8: local_amp=1128.8 local_phase=-0.125  peer_amp=1175.6 peer_phase=1.061  signal_amp=1327121.0 signal_phase=0.935
#  ch11: local_amp=1130.2 local_phase=1.077  peer_amp=1175.7 peer_phase=-0.386  signal_amp=1328711.7 signal_phase=0.690
#  ch14: local_amp=1129.9 local_phase=-1.174  peer_amp=1174.4 peer_phase=1.597  signal_amp=1326995.6 signal_phase=0.424
#  ch17: local_amp=1130.6 local_phase=-1.309  peer_amp=1174.5 peer_phase=1.408  signal_amp=1327885.8 signal_phase=0.100
#  ch20: local_amp=1132.1 local_phase=2.796  peer_amp=1176.8 peer_phase=-3.051  signal_amp=1332252.8 signal_phase=-0.256
#  ch26: local_amp=1132.3 local_phase=-1.019  peer_amp=1175.0 peer_phase=0.175  signal_amp=1330491.0 signal_phase=-0.843
#  ch29: local_amp=1128.5 local_phase=2.897  peer_amp=1175.4 peer_phase=2.139  signal_amp=1326431.8 signal_phase=-1.247
#  ch32: local_amp=1131.3 local_phase=-1.313  peer_amp=1176.1 peer_phase=-0.310  signal_amp=1330524.5 signal_phase=-1.624
#  ch35: local_amp=1129.6 local_phase=-0.760  peer_amp=1176.2 peer_phase=-1.113  signal_amp=1328650.7 signal_phase=-1.873
#  ch38: local_amp=1130.2 local_phase=-0.164  peer_amp=1176.3 peer_phase=-2.048  signal_amp=1329478.0 signal_phase=-2.212
#  ch41: local_amp=1132.5 local_phase=-0.479  peer_amp=1177.2 peer_phase=-2.104  signal_amp=1333154.5 signal_phase=-2.583
#  ch44: local_amp=1130.6 local_phase=-0.736  peer_amp=1177.0 peer_phase=-2.188  signal_amp=1330767.3 signal_phase=-2.924
#  ch47: local_amp=1130.2 local_phase=2.516  peer_amp=1174.9 peer_phase=0.473  signal_amp=1327821.4 signal_phase=2.989
#  ch50: local_amp=1131.9 local_phase=-1.022  peer_amp=1176.7 peer_phase=-2.526  signal_amp=1331907.8 signal_phase=2.734
# Counter 28:
#  ch2: local_amp=1132.1 local_phase=0.776  peer_amp=1174.1 peer_phase=0.763  signal_amp=1329236.5 signal_phase=1.539
#  ch5: local_amp=1132.2 local_phase=-1.774  peer_amp=1176.5 peer_phase=3.002  signal_amp=1332012.1 signal_phase=1.228
#  ch8: local_amp=1132.6 local_phase=2.633  peer_amp=1175.8 peer_phase=-1.706  signal_amp=1331733.2 signal_phase=0.926
#  ch11: local_amp=1132.6 local_phase=-2.240  peer_amp=1175.4 peer_phase=2.796  signal_amp=1331278.7 signal_phase=0.556
#  ch14: local_amp=1132.4 local_phase=-2.688  peer_amp=1175.3 peer_phase=-3.119  signal_amp=1330926.6 signal_phase=0.476
#  ch17: local_amp=1131.6 local_phase=0.171  peer_amp=1175.1 peer_phase=-0.161  signal_amp=1329760.5 signal_phase=0.011
#  ch20: local_amp=1131.3 local_phase=1.062  peer_amp=1175.7 peer_phase=-1.378  signal_amp=1330054.1 signal_phase=-0.316
#  ch26: local_amp=1130.9 local_phase=-2.185  peer_amp=1175.5 peer_phase=1.238  signal_amp=1329333.3 signal_phase=-0.947
#  ch29: local_amp=1132.7 local_phase=1.434  peer_amp=1177.3 peer_phase=-2.634  signal_amp=1333470.6 signal_phase=-1.201
#  ch32: local_amp=1132.4 local_phase=-1.182  peer_amp=1175.1 peer_phase=-0.442  signal_amp=1330687.8 signal_phase=-1.625
#  ch35: local_amp=1132.2 local_phase=0.287  peer_amp=1176.7 peer_phase=-2.271  signal_amp=1332189.4 signal_phase=-1.984
#  ch38: local_amp=1132.5 local_phase=-1.756  peer_amp=1176.2 peer_phase=-0.467  signal_amp=1331969.0 signal_phase=-2.224
#  ch41: local_amp=1130.9 local_phase=0.542  peer_amp=1177.5 peer_phase=3.045  signal_amp=1331626.0 signal_phase=-2.697
#  ch44: local_amp=1131.9 local_phase=-0.755  peer_amp=1175.8 peer_phase=-2.214  signal_amp=1330864.5 signal_phase=-2.969
#  ch47: local_amp=1132.0 local_phase=-0.686  peer_amp=1177.1 peer_phase=-2.667  signal_amp=1332541.1 signal_phase=2.930
#  ch50: local_amp=1130.1 local_phase=0.174  peer_amp=1175.8 peer_phase=2.471  signal_amp=1328848.6 signal_phase=2.645
# Counter 30:
#  ch2: local_amp=1131.8 local_phase=-1.767  peer_amp=1175.1 peer_phase=-2.926  signal_amp=1329984.1 signal_phase=1.590
#  ch5: local_amp=1131.0 local_phase=1.322  peer_amp=1174.7 peer_phase=-0.129  signal_amp=1328582.7 signal_phase=1.193
#  ch8: local_amp=1131.6 local_phase=-2.692  peer_amp=1174.7 peer_phase=-2.781  signal_amp=1329293.0 signal_phase=0.811
#  ch11: local_amp=1132.9 local_phase=3.083  peer_amp=1175.1 peer_phase=-2.549  signal_amp=1331347.8 signal_phase=0.534
#  ch14: local_amp=1131.9 local_phase=0.557  peer_amp=1174.4 peer_phase=-0.133  signal_amp=1329273.7 signal_phase=0.423
#  ch17: local_amp=1132.2 local_phase=0.662  peer_amp=1175.9 peer_phase=-0.752  signal_amp=1331323.4 signal_phase=-0.090
#  ch20: local_amp=1131.7 local_phase=2.331  peer_amp=1176.8 peer_phase=-2.646  signal_amp=1331797.2 signal_phase=-0.314
#  ch26: local_amp=1131.8 local_phase=-1.415  peer_amp=1175.4 peer_phase=0.479  signal_amp=1330303.8 signal_phase=-0.935
#  ch29: local_amp=1131.0 local_phase=0.933  peer_amp=1177.7 peer_phase=-2.229  signal_amp=1332026.6 signal_phase=-1.295
#  ch32: local_amp=1131.1 local_phase=-1.734  peer_amp=1175.0 peer_phase=0.170  signal_amp=1328974.6 signal_phase=-1.564
#  ch35: local_amp=1131.9 local_phase=-2.900  peer_amp=1175.9 peer_phase=0.819  signal_amp=1330999.8 signal_phase=-2.081
#  ch38: local_amp=1131.5 local_phase=-2.042  peer_amp=1174.3 peer_phase=-0.294  signal_amp=1328701.6 signal_phase=-2.336
#  ch41: local_amp=1131.5 local_phase=-1.245  peer_amp=1178.1 peer_phase=-1.584  signal_amp=1332981.6 signal_phase=-2.829
#  ch44: local_amp=1133.4 local_phase=-3.028  peer_amp=1176.1 peer_phase=0.009  signal_amp=1332895.9 signal_phase=-3.018
#  ch47: local_amp=1133.2 local_phase=-2.727  peer_amp=1174.5 peer_phase=-0.656  signal_amp=1330966.6 signal_phase=2.901
#  ch50: local_amp=1131.3 local_phase=0.707  peer_amp=1175.7 peer_phase=1.939  signal_amp=1330094.3 signal_phase=2.646
# Counter 32:
#  ch2: local_amp=1129.8 local_phase=2.017  peer_amp=1176.0 peer_phase=-0.428  signal_amp=1328707.1 signal_phase=1.590
#  ch5: local_amp=1132.2 local_phase=3.121  peer_amp=1176.3 peer_phase=-1.762  signal_amp=1331881.2 signal_phase=1.360
#  ch8: local_amp=1130.7 local_phase=-2.850  peer_amp=1175.5 peer_phase=-2.451  signal_amp=1329171.9 signal_phase=0.982
#  ch11: local_amp=1129.4 local_phase=2.503  peer_amp=1176.8 peer_phase=-1.796  signal_amp=1329056.9 signal_phase=0.707
#  ch14: local_amp=1130.8 local_phase=-2.714  peer_amp=1175.8 peer_phase=3.073  signal_amp=1329635.7 signal_phase=0.359
#  ch17: local_amp=1129.5 local_phase=-2.334  peer_amp=1174.9 peer_phase=2.381  signal_amp=1327031.1 signal_phase=0.047
#  ch20: local_amp=1129.3 local_phase=0.135  peer_amp=1175.8 peer_phase=-0.423  signal_amp=1327787.4 signal_phase=-0.288
#  ch26: local_amp=1131.3 local_phase=1.594  peer_amp=1177.5 peer_phase=-2.477  signal_amp=1332055.7 signal_phase=-0.883
#  ch29: local_amp=1131.9 local_phase=-2.230  peer_amp=1174.8 peer_phase=1.040  signal_amp=1329814.5 signal_phase=-1.190
#  ch32: local_amp=1131.1 local_phase=3.098  peer_amp=1174.3 peer_phase=1.619  signal_amp=1328246.7 signal_phase=-1.566
#  ch35: local_amp=1130.0 local_phase=-0.042  peer_amp=1177.7 peer_phase=-1.868  signal_amp=1330738.3 signal_phase=-1.910
#  ch38: local_amp=1132.6 local_phase=-1.062  peer_amp=1176.0 peer_phase=-1.188  signal_amp=1331972.0 signal_phase=-2.250
#  ch41: local_amp=1133.1 local_phase=2.701  peer_amp=1173.9 peer_phase=0.997  signal_amp=1330108.5 signal_phase=-2.585
#  ch44: local_amp=1130.3 local_phase=2.413  peer_amp=1174.8 peer_phase=0.922  signal_amp=1327937.7 signal_phase=-2.949
#  ch47: local_amp=1132.1 local_phase=-0.750  peer_amp=1175.9 peer_phase=-2.533  signal_amp=1331226.4 signal_phase=2.999
#  ch50: local_amp=1131.1 local_phase=2.482  peer_amp=1176.1 peer_phase=0.161  signal_amp=1330363.4 signal_phase=2.643
# Counter 34:
#  ch2: local_amp=1128.7 local_phase=0.380  peer_amp=1173.6 peer_phase=1.121  signal_amp=1324596.8 signal_phase=1.502
#  ch5: local_amp=1132.0 local_phase=-1.149  peer_amp=1177.4 peer_phase=2.392  signal_amp=1332823.5 signal_phase=1.243
#  ch8: local_amp=1131.9 local_phase=2.184  peer_amp=1176.7 peer_phase=-1.203  signal_amp=1331904.8 signal_phase=0.980
#  ch11: local_amp=1131.1 local_phase=0.013  peer_amp=1175.9 peer_phase=0.630  signal_amp=1330063.8 signal_phase=0.643
#  ch14: local_amp=1130.9 local_phase=1.132  peer_amp=1174.6 peer_phase=-0.626  signal_amp=1328358.6 signal_phase=0.507
#  ch17: local_amp=1130.8 local_phase=0.983  peer_amp=1176.0 peer_phase=-0.991  signal_amp=1329777.2 signal_phase=-0.008
#  ch20: local_amp=1131.9 local_phase=2.279  peer_amp=1175.3 peer_phase=-2.678  signal_amp=1330347.6 signal_phase=-0.399
#  ch26: local_amp=1131.8 local_phase=0.526  peer_amp=1173.9 peer_phase=-1.448  signal_amp=1328630.0 signal_phase=-0.922
#  ch29: local_amp=1132.8 local_phase=-2.365  peer_amp=1175.8 peer_phase=1.096  signal_amp=1331969.6 signal_phase=-1.268
#  ch32: local_amp=1130.4 local_phase=-2.606  peer_amp=1175.6 peer_phase=1.025  signal_amp=1328893.9 signal_phase=-1.581
#  ch35: local_amp=1133.1 local_phase=-2.725  peer_amp=1175.2 peer_phase=0.717  signal_amp=1331595.5 signal_phase=-2.008
#  ch38: local_amp=1130.7 local_phase=-0.109  peer_amp=1176.7 peer_phase=-2.176  signal_amp=1330488.2 signal_phase=-2.285
#  ch41: local_amp=1131.2 local_phase=3.096  peer_amp=1175.7 peer_phase=0.501  signal_amp=1329852.8 signal_phase=-2.685
#  ch44: local_amp=1131.9 local_phase=3.031  peer_amp=1175.5 peer_phase=0.173  signal_amp=1330560.1 signal_phase=-3.080
#  ch47: local_amp=1130.5 local_phase=1.519  peer_amp=1175.4 peer_phase=1.445  signal_amp=1328786.8 signal_phase=2.963
#  ch50: local_amp=1130.0 local_phase=1.947  peer_amp=1174.7 peer_phase=0.747  signal_amp=1327337.9 signal_phase=2.694
# Counter 36:
#  ch2: local_amp=1130.6 local_phase=-0.205  peer_amp=1174.0 peer_phase=1.736  signal_amp=1327342.2 signal_phase=1.531
#  ch5: local_amp=1131.3 local_phase=-1.923  peer_amp=1175.1 peer_phase=-3.032  signal_amp=1329447.2 signal_phase=1.329
#  ch8: local_amp=1132.3 local_phase=3.054  peer_amp=1175.9 peer_phase=-2.123  signal_amp=1331489.5 signal_phase=0.931
#  ch11: local_amp=1129.3 local_phase=-1.350  peer_amp=1174.4 peer_phase=2.061  signal_amp=1326246.0 signal_phase=0.711
#  ch14: local_amp=1131.8 local_phase=2.265  peer_amp=1174.9 peer_phase=-1.907  signal_amp=1329823.0 signal_phase=0.358
#  ch17: local_amp=1132.4 local_phase=-1.027  peer_amp=1174.8 peer_phase=1.080  signal_amp=1330385.1 signal_phase=0.053
#  ch20: local_amp=1131.0 local_phase=1.445  peer_amp=1175.1 peer_phase=-1.714  signal_amp=1328947.1 signal_phase=-0.269
#  ch26: local_amp=1133.7 local_phase=2.063  peer_amp=1174.8 peer_phase=-2.897  signal_amp=1331930.5 signal_phase=-0.834
#  ch29: local_amp=1132.8 local_phase=-0.464  peer_amp=1174.6 peer_phase=-0.748  signal_amp=1330595.4 signal_phase=-1.212
#  ch32: local_amp=1133.3 local_phase=2.598  peer_amp=1174.7 peer_phase=2.125  signal_amp=1331252.1 signal_phase=-1.560
#  ch35: local_amp=1133.5 local_phase=-2.755  peer_amp=1175.4 peer_phase=0.879  signal_amp=1332300.0 signal_phase=-1.877
#  ch38: local_amp=1131.4 local_phase=1.668  peer_amp=1174.5 peer_phase=2.391  signal_amp=1328797.9 signal_phase=-2.224
#  ch41: local_amp=1132.7 local_phase=-1.702  peer_amp=1175.4 peer_phase=-0.960  signal_amp=1331426.4 signal_phase=-2.662
#  ch44: local_amp=1132.9 local_phase=-0.734  peer_amp=1177.2 peer_phase=-2.242  signal_amp=1333649.8 signal_phase=-2.976
#  ch47: local_amp=1132.6 local_phase=-0.360  peer_amp=1175.3 peer_phase=-2.869  signal_amp=1331130.1 signal_phase=3.054
#  ch50: local_amp=1132.5 local_phase=-1.600  peer_amp=1175.9 peer_phase=-1.992  signal_amp=1331659.8 signal_phase=2.691
# Counter 38:
#  ch2: local_amp=1133.9 local_phase=-3.084  peer_amp=1174.0 peer_phase=-1.720  signal_amp=1331118.9 signal_phase=1.479
#  ch5: local_amp=1130.9 local_phase=0.575  peer_amp=1176.0 peer_phase=0.611  signal_amp=1329890.5 signal_phase=1.186
#  ch8: local_amp=1132.3 local_phase=-2.782  peer_amp=1173.9 peer_phase=-2.624  signal_amp=1329116.8 signal_phase=0.877
#  ch11: local_amp=1131.7 local_phase=-2.054  peer_amp=1175.6 peer_phase=2.535  signal_amp=1330402.8 signal_phase=0.481
#  ch14: local_amp=1132.0 local_phase=-0.383  peer_amp=1174.6 peer_phase=0.798  signal_amp=1329647.8 signal_phase=0.415
#  ch17: local_amp=1132.2 local_phase=-0.428  peer_amp=1173.7 peer_phase=0.359  signal_amp=1328810.4 signal_phase=-0.069
#  ch20: local_amp=1131.3 local_phase=1.907  peer_amp=1175.4 peer_phase=-2.256  signal_amp=1329719.1 signal_phase=-0.349
#  ch26: local_amp=1132.1 local_phase=2.055  peer_amp=1175.9 peer_phase=-3.071  signal_amp=1331316.4 signal_phase=-1.016
#  ch29: local_amp=1133.2 local_phase=-0.552  peer_amp=1175.5 peer_phase=-0.763  signal_amp=1332055.6 signal_phase=-1.314
#  ch32: local_amp=1132.7 local_phase=0.939  peer_amp=1176.0 peer_phase=-2.592  signal_amp=1332042.0 signal_phase=-1.653
#  ch35: local_amp=1132.9 local_phase=-0.366  peer_amp=1176.2 peer_phase=-1.591  signal_amp=1332529.7 signal_phase=-1.957
#  ch38: local_amp=1133.5 local_phase=-1.707  peer_amp=1176.5 peer_phase=-0.550  signal_amp=1333613.9 signal_phase=-2.257
#  ch41: local_amp=1133.8 local_phase=2.597  peer_amp=1176.0 peer_phase=0.952  signal_amp=1333289.0 signal_phase=-2.734
#  ch44: local_amp=1132.5 local_phase=-0.031  peer_amp=1175.4 peer_phase=-3.055  signal_amp=1331227.1 signal_phase=-3.086
#  ch47: local_amp=1133.2 local_phase=1.368  peer_amp=1176.0 peer_phase=1.577  signal_amp=1332636.6 signal_phase=2.945
#  ch50: local_amp=1132.6 local_phase=0.099  peer_amp=1176.0 peer_phase=2.550  signal_amp=1331849.8 signal_phase=2.649
# Counter 40:
#  ch2: local_amp=1131.4 local_phase=-2.502  peer_amp=1175.1 peer_phase=-2.163  signal_amp=1329568.7 signal_phase=1.618
#  ch5: local_amp=1130.5 local_phase=-0.961  peer_amp=1175.7 peer_phase=2.191  signal_amp=1329113.3 signal_phase=1.229
#  ch8: local_amp=1132.1 local_phase=2.533  peer_amp=1175.7 peer_phase=-1.624  signal_amp=1330997.5 signal_phase=0.909
#  ch11: local_amp=1131.9 local_phase=0.675  peer_amp=1175.2 peer_phase=-0.074  signal_amp=1330292.5 signal_phase=0.601
#  ch14: local_amp=1132.4 local_phase=-2.048  peer_amp=1175.8 peer_phase=2.471  signal_amp=1331577.5 signal_phase=0.423
#  ch17: local_amp=1133.6 local_phase=-1.913  peer_amp=1175.3 peer_phase=1.833  signal_amp=1332268.5 signal_phase=-0.079
#  ch20: local_amp=1131.6 local_phase=1.679  peer_amp=1176.9 peer_phase=-2.056  signal_amp=1331769.5 signal_phase=-0.377
#  ch26: local_amp=1131.5 local_phase=-0.079  peer_amp=1175.2 peer_phase=-0.781  signal_amp=1329773.8 signal_phase=-0.859
#  ch29: local_amp=1132.5 local_phase=0.066  peer_amp=1174.2 peer_phase=-1.340  signal_amp=1329796.3 signal_phase=-1.273
#  ch32: local_amp=1132.9 local_phase=-2.689  peer_amp=1174.2 peer_phase=1.084  signal_amp=1330259.5 signal_phase=-1.605
#  ch35: local_amp=1132.8 local_phase=-1.905  peer_amp=1175.2 peer_phase=-0.138  signal_amp=1331313.2 signal_phase=-2.044
#  ch38: local_amp=1132.9 local_phase=-1.013  peer_amp=1175.4 peer_phase=-1.225  signal_amp=1331677.1 signal_phase=-2.238
#  ch41: local_amp=1131.5 local_phase=1.905  peer_amp=1175.7 peer_phase=1.724  signal_amp=1330368.5 signal_phase=-2.655
#  ch44: local_amp=1132.6 local_phase=-0.080  peer_amp=1175.9 peer_phase=-2.927  signal_amp=1331783.5 signal_phase=-3.007
#  ch47: local_amp=1132.1 local_phase=0.044  peer_amp=1176.7 peer_phase=2.871  signal_amp=1332113.5 signal_phase=2.916
#  ch50: local_amp=1131.5 local_phase=-2.006  peer_amp=1175.8 peer_phase=-1.651  signal_amp=1330331.2 signal_phase=2.626
# Counter 42:
#  ch2: local_amp=1133.1 local_phase=3.081  peer_amp=1174.3 peer_phase=-1.595  signal_amp=1330641.0 signal_phase=1.486
#  ch5: local_amp=1132.1 local_phase=0.795  peer_amp=1175.6 peer_phase=0.404  signal_amp=1330914.6 signal_phase=1.199
#  ch8: local_amp=1133.0 local_phase=2.973  peer_amp=1175.3 peer_phase=-2.044  signal_amp=1331706.2 signal_phase=0.929
#  ch11: local_amp=1132.3 local_phase=2.090  peer_amp=1177.1 peer_phase=-1.583  signal_amp=1332826.8 signal_phase=0.507
#  ch14: local_amp=1131.8 local_phase=0.901  peer_amp=1173.1 peer_phase=-0.552  signal_amp=1327748.2 signal_phase=0.349
#  ch17: local_amp=1132.0 local_phase=0.399  peer_amp=1174.4 peer_phase=-0.453  signal_amp=1329490.0 signal_phase=-0.054
#  ch20: local_amp=1131.8 local_phase=-2.702  peer_amp=1175.7 peer_phase=2.327  signal_amp=1330621.9 signal_phase=-0.374
#  ch26: local_amp=1132.4 local_phase=2.028  peer_amp=1175.7 peer_phase=-2.995  signal_amp=1331267.8 signal_phase=-0.967
#  ch29: local_amp=1132.3 local_phase=0.999  peer_amp=1176.5 peer_phase=-2.265  signal_amp=1332170.2 signal_phase=-1.267
#  ch32: local_amp=1134.0 local_phase=2.582  peer_amp=1176.9 peer_phase=1.998  signal_amp=1334632.5 signal_phase=-1.703
#  ch35: local_amp=1130.6 local_phase=0.116  peer_amp=1175.6 peer_phase=-2.081  signal_amp=1329206.9 signal_phase=-1.965
#  ch38: local_amp=1131.0 local_phase=-3.082  peer_amp=1175.8 peer_phase=0.817  signal_amp=1329798.5 signal_phase=-2.266
#  ch41: local_amp=1133.9 local_phase=-1.478  peer_amp=1176.1 peer_phase=-1.253  signal_amp=1333499.7 signal_phase=-2.731
#  ch44: local_amp=1132.7 local_phase=-0.487  peer_amp=1176.2 peer_phase=-2.551  signal_amp=1332277.3 signal_phase=-3.038
#  ch47: local_amp=1132.9 local_phase=-0.162  peer_amp=1176.2 peer_phase=3.031  signal_amp=1332498.3 signal_phase=2.869
#  ch50: local_amp=1132.0 local_phase=0.855  peer_amp=1175.9 peer_phase=1.804  signal_amp=1331078.1 signal_phase=2.659
# Counter 44:
#  ch2: local_amp=1130.7 local_phase=0.448  peer_amp=1173.6 peer_phase=1.121  signal_amp=1326984.2 signal_phase=1.569
#  ch5: local_amp=1131.2 local_phase=1.257  peer_amp=1176.3 peer_phase=0.047  signal_amp=1330596.4 signal_phase=1.304
#  ch8: local_amp=1130.8 local_phase=2.530  peer_amp=1175.6 peer_phase=-1.637  signal_amp=1329341.3 signal_phase=0.893
#  ch11: local_amp=1133.2 local_phase=-2.837  peer_amp=1176.0 peer_phase=-2.800  signal_amp=1332616.3 signal_phase=0.646
#  ch14: local_amp=1132.8 local_phase=-0.822  peer_amp=1174.0 peer_phase=1.186  signal_amp=1329937.1 signal_phase=0.363
#  ch17: local_amp=1132.1 local_phase=-1.527  peer_amp=1175.9 peer_phase=1.480  signal_amp=1331217.4 signal_phase=-0.047
#  ch20: local_amp=1132.2 local_phase=-2.884  peer_amp=1176.4 peer_phase=2.502  signal_amp=1331979.0 signal_phase=-0.382
#  ch26: local_amp=1134.3 local_phase=-2.066  peer_amp=1176.2 peer_phase=1.117  signal_amp=1334134.1 signal_phase=-0.949
#  ch29: local_amp=1132.5 local_phase=2.863  peer_amp=1177.3 peer_phase=2.179  signal_amp=1333360.7 signal_phase=-1.240
#  ch32: local_amp=1131.6 local_phase=2.115  peer_amp=1175.6 peer_phase=2.642  signal_amp=1330237.4 signal_phase=-1.526
#  ch35: local_amp=1134.8 local_phase=-1.322  peer_amp=1175.4 peer_phase=-0.645  signal_amp=1333882.5 signal_phase=-1.968
#  ch38: local_amp=1132.0 local_phase=-0.002  peer_amp=1176.7 peer_phase=-2.365  signal_amp=1331989.5 signal_phase=-2.366
#  ch41: local_amp=1131.9 local_phase=-2.043  peer_amp=1175.8 peer_phase=-0.739  signal_amp=1330896.7 signal_phase=-2.782
#  ch44: local_amp=1132.3 local_phase=2.178  peer_amp=1176.2 peer_phase=1.096  signal_amp=1331924.5 signal_phase=-3.010
#  ch47: local_amp=1131.8 local_phase=0.151  peer_amp=1175.7 peer_phase=2.824  signal_amp=1330755.6 signal_phase=2.975
#  ch50: local_amp=1131.3 local_phase=1.550  peer_amp=1176.2 peer_phase=1.100  signal_amp=1330588.2 signal_phase=2.649
# Counter 46:
#  ch2: local_amp=1131.2 local_phase=3.037  peer_amp=1174.6 peer_phase=-1.540  signal_amp=1328619.6 signal_phase=1.497
#  ch5: local_amp=1131.4 local_phase=-2.797  peer_amp=1177.5 peer_phase=-2.340  signal_amp=1332252.7 signal_phase=1.146
#  ch8: local_amp=1130.9 local_phase=-1.728  peer_amp=1175.5 peer_phase=2.697  signal_amp=1329395.4 signal_phase=0.969
#  ch11: local_amp=1133.2 local_phase=-2.247  peer_amp=1177.6 peer_phase=2.866  signal_amp=1334447.9 signal_phase=0.619
#  ch14: local_amp=1131.7 local_phase=-1.680  peer_amp=1174.9 peer_phase=2.114  signal_amp=1329684.8 signal_phase=0.434
#  ch17: local_amp=1131.6 local_phase=-0.166  peer_amp=1175.0 peer_phase=0.170  signal_amp=1329552.5 signal_phase=0.004
#  ch20: local_amp=1131.0 local_phase=-1.837  peer_amp=1176.1 peer_phase=1.528  signal_amp=1330088.1 signal_phase=-0.309
#  ch26: local_amp=1132.6 local_phase=3.051  peer_amp=1176.6 peer_phase=2.307  signal_amp=1332666.3 signal_phase=-0.925
#  ch29: local_amp=1132.4 local_phase=-1.465  peer_amp=1174.5 peer_phase=0.228  signal_amp=1329996.0 signal_phase=-1.236
#  ch32: local_amp=1132.2 local_phase=0.239  peer_amp=1177.0 peer_phase=-1.894  signal_amp=1332573.4 signal_phase=-1.655
#  ch35: local_amp=1131.3 local_phase=-1.523  peer_amp=1177.8 peer_phase=-0.427  signal_amp=1332488.1 signal_phase=-1.950
#  ch38: local_amp=1133.1 local_phase=2.989  peer_amp=1174.5 peer_phase=1.019  signal_amp=1330864.2 signal_phase=-2.275
#  ch41: local_amp=1131.2 local_phase=-2.264  peer_amp=1176.9 peer_phase=-0.429  signal_amp=1331272.4 signal_phase=-2.694
#  ch44: local_amp=1130.9 local_phase=2.193  peer_amp=1175.8 peer_phase=1.033  signal_amp=1329663.2 signal_phase=-3.057
#  ch47: local_amp=1133.2 local_phase=-0.900  peer_amp=1178.6 peer_phase=-2.432  signal_amp=1335580.5 signal_phase=2.951
#  ch50: local_amp=1132.0 local_phase=0.891  peer_amp=1175.9 peer_phase=1.825  signal_amp=1331038.4 signal_phase=2.716
# Counter 48:
#  ch2: local_amp=1130.9 local_phase=-0.263  peer_amp=1174.2 peer_phase=1.774  signal_amp=1327847.8 signal_phase=1.511
#  ch5: local_amp=1133.1 local_phase=2.200  peer_amp=1177.2 peer_phase=-0.958  signal_amp=1333851.6 signal_phase=1.242
#  ch8: local_amp=1131.8 local_phase=-2.289  peer_amp=1175.1 peer_phase=-3.099  signal_amp=1329915.8 signal_phase=0.895
#  ch11: local_amp=1132.2 local_phase=0.582  peer_amp=1176.1 peer_phase=0.060  signal_amp=1331523.6 signal_phase=0.641
#  ch14: local_amp=1133.0 local_phase=-0.373  peer_amp=1176.3 peer_phase=0.829  signal_amp=1332714.1 signal_phase=0.456
#  ch17: local_amp=1133.1 local_phase=-0.095  peer_amp=1174.8 peer_phase=0.055  signal_amp=1331122.6 signal_phase=-0.039
#  ch20: local_amp=1133.3 local_phase=-1.300  peer_amp=1176.8 peer_phase=0.953  signal_amp=1333592.0 signal_phase=-0.348
#  ch26: local_amp=1132.7 local_phase=0.131  peer_amp=1176.7 peer_phase=-1.029  signal_amp=1332807.5 signal_phase=-0.898
#  ch29: local_amp=1132.8 local_phase=1.028  peer_amp=1177.6 peer_phase=-2.239  signal_amp=1333896.0 signal_phase=-1.211
#  ch32: local_amp=1132.2 local_phase=1.961  peer_amp=1176.5 peer_phase=2.723  signal_amp=1332060.9 signal_phase=-1.599
#  ch35: local_amp=1133.0 local_phase=1.511  peer_amp=1176.0 peer_phase=2.797  signal_amp=1332497.3 signal_phase=-1.975
#  ch38: local_amp=1133.2 local_phase=-0.308  peer_amp=1176.2 peer_phase=-1.942  signal_amp=1332868.9 signal_phase=-2.250
#  ch41: local_amp=1133.5 local_phase=2.760  peer_amp=1175.9 peer_phase=0.862  signal_amp=1332832.7 signal_phase=-2.661
#  ch44: local_amp=1133.7 local_phase=-1.157  peer_amp=1176.1 peer_phase=-1.897  signal_amp=1333357.1 signal_phase=-3.054
#  ch47: local_amp=1133.2 local_phase=-1.525  peer_amp=1177.1 peer_phase=-1.826  signal_amp=1333865.8 signal_phase=2.932
#  ch50: local_amp=1131.4 local_phase=2.135  peer_amp=1176.0 peer_phase=0.544  signal_amp=1330443.5 signal_phase=2.679
# Counter 50:
#  ch2: local_amp=1130.8 local_phase=0.980  peer_amp=1173.9 peer_phase=0.467  signal_amp=1327450.6 signal_phase=1.447
#  ch5: local_amp=1131.3 local_phase=-1.483  peer_amp=1175.0 peer_phase=2.663  signal_amp=1329278.7 signal_phase=1.180
# ...
#  ch35: local_amp=1132.3 local_phase=-2.988  peer_amp=1176.6 peer_phase=1.046  signal_amp=1332274.8 signal_phase=-1.943
#  ch38: local_amp=1132.7 local_phase=-2.522  peer_amp=1175.9 peer_phase=0.389  signal_amp=1331923.1 signal_phase=-2.133
#  ch41: local_amp=1132.2 local_phase=-1.794  peer_amp=1177.5 peer_phase=-0.836  signal_amp=1333081.9 signal_phase=-2.631
#  ch44: local_amp=1130.3 local_phase=-0.336  peer_amp=1177.7 peer_phase=-2.542  signal_amp=1331190.3 signal_phase=-2.878
#  ch47: local_amp=1133.2 local_phase=-3.123  peer_amp=1176.6 peer_phase=-0.183  signal_amp=1333344.4 signal_phase=2.977
#  ch50: local_amp=1132.8 local_phase=-2.351  peer_amp=1176.6 peer_phase=-1.335  signal_amp=1332838.7 signal_phase=2.597
# Counter 594:
#  ch2: local_amp=1127.9 local_phase=1.058  peer_amp=1174.1 peer_phase=0.506  signal_amp=1324226.0 signal_phase=1.564
#  ch5: local_amp=1130.1 local_phase=-2.097  peer_amp=1178.2 peer_phase=-3.004  signal_amp=1331487.2 signal_phase=1.182
#  ch8: local_amp=1131.4 local_phase=-0.847  peer_amp=1175.8 peer_phase=1.759  signal_amp=1330281.6 signal_phase=0.912
#  ch11: local_amp=1130.8 local_phase=-0.392  peer_amp=1176.0 peer_phase=0.920  signal_amp=1329820.6 signal_phase=0.528
#  ch14: local_amp=1131.8 local_phase=1.144  peer_amp=1175.2 peer_phase=-0.751  signal_amp=1330029.3 signal_phase=0.392
#  ch17: local_amp=1130.9 local_phase=-2.610  peer_amp=1175.9 peer_phase=2.526  signal_amp=1329787.3 signal_phase=-0.084
#  ch20: local_amp=1130.6 local_phase=2.594  peer_amp=1176.6 peer_phase=-2.888  signal_amp=1330186.6 signal_phase=-0.295
#  ch26: local_amp=1131.6 local_phase=-0.116  peer_amp=1177.5 peer_phase=-0.865  signal_amp=1332471.4 signal_phase=-0.981
#  ch29: local_amp=1130.7 local_phase=3.105  peer_amp=1174.9 peer_phase=1.878  signal_amp=1328527.4 signal_phase=-1.300
#  ch32: local_amp=1130.7 local_phase=0.847  peer_amp=1177.6 peer_phase=-2.429  signal_amp=1331493.4 signal_phase=-1.582
#  ch35: local_amp=1132.0 local_phase=2.990  peer_amp=1177.0 peer_phase=1.290  signal_amp=1332404.5 signal_phase=-2.003
#  ch38: local_amp=1130.7 local_phase=2.900  peer_amp=1174.4 peer_phase=1.106  signal_amp=1327886.3 signal_phase=-2.276
#  ch41: local_amp=1131.2 local_phase=-3.125  peer_amp=1176.2 peer_phase=0.475  signal_amp=1330524.5 signal_phase=-2.650
#  ch44: local_amp=1131.4 local_phase=2.540  peer_amp=1176.4 peer_phase=0.652  signal_amp=1331041.0 signal_phase=-3.091
#  ch47: local_amp=1129.7 local_phase=2.869  peer_amp=1175.4 peer_phase=0.049  signal_amp=1327853.0 signal_phase=2.918
#  ch50: local_amp=1131.8 local_phase=-2.252  peer_amp=1177.4 peer_phase=-1.420  signal_amp=1332579.5 signal_phase=2.611
# Counter 596:
#  ch2: local_amp=1132.4 local_phase=-2.887  peer_amp=1176.6 peer_phase=-1.780  signal_amp=1332415.3 signal_phase=1.616
#  ch5: local_amp=1131.0 local_phase=-2.157  peer_amp=1177.1 peer_phase=-2.904  signal_amp=1331293.4 signal_phase=1.222
#  ch8: local_amp=1131.6 local_phase=-2.019  peer_amp=1176.7 peer_phase=2.954  signal_amp=1331598.5 signal_phase=0.935
#  ch11: local_amp=1129.5 local_phase=-2.102  peer_amp=1177.7 peer_phase=2.793  signal_amp=1330295.2 signal_phase=0.691
#  ch14: local_amp=1129.7 local_phase=0.655  peer_amp=1176.5 peer_phase=-0.273  signal_amp=1329072.1 signal_phase=0.382
#  ch17: local_amp=1131.7 local_phase=2.850  peer_amp=1176.8 peer_phase=-2.868  signal_amp=1331729.6 signal_phase=-0.018
#  ch20: local_amp=1130.5 local_phase=-0.345  peer_amp=1176.5 peer_phase=0.030  signal_amp=1330051.3 signal_phase=-0.315
#  ch26: local_amp=1131.6 local_phase=-0.278  peer_amp=1176.5 peer_phase=-0.586  signal_amp=1331323.0 signal_phase=-0.865
#  ch29: local_amp=1130.1 local_phase=0.898  peer_amp=1176.1 peer_phase=-2.073  signal_amp=1329133.3 signal_phase=-1.175
#  ch32: local_amp=1130.2 local_phase=1.699  peer_amp=1176.5 peer_phase=2.996  signal_amp=1329686.0 signal_phase=-1.589
#  ch35: local_amp=1131.6 local_phase=2.548  peer_amp=1176.8 peer_phase=1.866  signal_amp=1331665.6 signal_phase=-1.870
#  ch38: local_amp=1132.2 local_phase=-1.347  peer_amp=1177.3 peer_phase=-0.870  signal_amp=1332929.9 signal_phase=-2.217
#  ch41: local_amp=1133.0 local_phase=-1.869  peer_amp=1177.4 peer_phase=-0.749  signal_amp=1334029.5 signal_phase=-2.618
#  ch44: local_amp=1131.0 local_phase=1.827  peer_amp=1177.3 peer_phase=1.524  signal_amp=1331532.7 signal_phase=-2.932
#  ch47: local_amp=1130.5 local_phase=1.385  peer_amp=1176.2 peer_phase=1.589  signal_amp=1329665.3 signal_phase=2.974
#  ch50: local_amp=1131.0 local_phase=-1.644  peer_amp=1176.8 peer_phase=-1.983  signal_amp=1331023.8 signal_phase=2.655
# Counter 598:
#  ch2: local_amp=1131.2 local_phase=1.368  peer_amp=1176.0 peer_phase=0.189  signal_amp=1330256.3 signal_phase=1.557
#  ch5: local_amp=1130.3 local_phase=1.546  peer_amp=1178.0 peer_phase=-0.346  signal_amp=1331539.0 signal_phase=1.200
#  ch8: local_amp=1130.2 local_phase=2.120  peer_amp=1175.5 peer_phase=-1.171  signal_amp=1328543.0 signal_phase=0.949
#  ch11: local_amp=1130.9 local_phase=1.703  peer_amp=1176.1 peer_phase=-1.145  signal_amp=1330015.6 signal_phase=0.558
#  ch14: local_amp=1132.1 local_phase=-2.053  peer_amp=1175.1 peer_phase=2.424  signal_amp=1330271.1 signal_phase=0.371
#  ch17: local_amp=1131.3 local_phase=2.792  peer_amp=1176.2 peer_phase=-2.802  signal_amp=1330629.6 signal_phase=-0.009
#  ch20: local_amp=1132.0 local_phase=-0.955  peer_amp=1174.3 peer_phase=0.620  signal_amp=1329381.2 signal_phase=-0.335
#  ch26: local_amp=1131.7 local_phase=-1.793  peer_amp=1176.7 peer_phase=0.800  signal_amp=1331763.3 signal_phase=-0.993
#  ch29: local_amp=1129.1 local_phase=0.095  peer_amp=1178.3 peer_phase=-1.319  signal_amp=1330361.3 signal_phase=-1.224
#  ch32: local_amp=1131.8 local_phase=-0.694  peer_amp=1177.0 peer_phase=-0.954  signal_amp=1332198.5 signal_phase=-1.648
#  ch35: local_amp=1131.7 local_phase=0.419  peer_amp=1177.5 peer_phase=-2.407  signal_amp=1332530.0 signal_phase=-1.989
#  ch38: local_amp=1133.0 local_phase=-1.630  peer_amp=1177.1 peer_phase=-0.672  signal_amp=1333617.5 signal_phase=-2.302
#  ch41: local_amp=1131.1 local_phase=-0.095  peer_amp=1179.1 peer_phase=-2.544  signal_amp=1333607.9 signal_phase=-2.639
#  ch44: local_amp=1131.2 local_phase=0.216  peer_amp=1177.1 peer_phase=3.126  signal_amp=1331565.4 signal_phase=-2.941
#  ch47: local_amp=1131.0 local_phase=2.681  peer_amp=1175.7 peer_phase=0.197  signal_amp=1329744.1 signal_phase=2.878
#  ch50: local_amp=1130.9 local_phase=-1.611  peer_amp=1177.2 peer_phase=-2.049  signal_amp=1331332.5 signal_phase=2.622
# Counter 600:
#  ch2: local_amp=1129.4 local_phase=2.781  peer_amp=1176.2 peer_phase=-1.207  signal_amp=1328416.3 signal_phase=1.575
#  ch5: local_amp=1131.5 local_phase=-0.435  peer_amp=1176.6 peer_phase=1.623  signal_amp=1331257.6 signal_phase=1.187
#  ch8: local_amp=1131.1 local_phase=0.322  peer_amp=1174.7 peer_phase=0.562  signal_amp=1328754.2 signal_phase=0.884
#  ch11: local_amp=1132.1 local_phase=-2.575  peer_amp=1177.2 peer_phase=3.125  signal_amp=1332675.4 signal_phase=0.551
#  ch14: local_amp=1131.7 local_phase=-2.226  peer_amp=1174.9 peer_phase=2.629  signal_amp=1329597.4 signal_phase=0.403
#  ch17: local_amp=1129.8 local_phase=0.935  peer_amp=1176.9 peer_phase=-0.950  signal_amp=1329690.7 signal_phase=-0.015
#  ch20: local_amp=1131.2 local_phase=-1.290  peer_amp=1176.6 peer_phase=0.933  signal_amp=1330949.2 signal_phase=-0.358
#  ch26: local_amp=1132.5 local_phase=1.783  peer_amp=1178.0 peer_phase=-2.795  signal_amp=1334082.5 signal_phase=-1.012
#  ch29: local_amp=1130.2 local_phase=0.281  peer_amp=1177.9 peer_phase=-1.515  signal_amp=1331213.5 signal_phase=-1.234
#  ch32: local_amp=1131.6 local_phase=-3.034  peer_amp=1176.5 peer_phase=1.425  signal_amp=1331315.1 signal_phase=-1.609
#  ch35: local_amp=1132.5 local_phase=1.492  peer_amp=1178.0 peer_phase=2.773  signal_amp=1334036.6 signal_phase=-2.018
#  ch38: local_amp=1133.0 local_phase=0.041  peer_amp=1177.8 peer_phase=-2.329  signal_amp=1334376.0 signal_phase=-2.288
#  ch41: local_amp=1130.1 local_phase=-1.740  peer_amp=1178.3 peer_phase=-0.912  signal_amp=1331616.7 signal_phase=-2.652
#  ch44: local_amp=1132.3 local_phase=-0.096  peer_amp=1177.1 peer_phase=-2.919  signal_amp=1332752.8 signal_phase=-3.015
#  ch47: local_amp=1130.0 local_phase=0.936  peer_amp=1176.6 peer_phase=2.033  signal_amp=1329632.4 signal_phase=2.969
#  ch50: local_amp=1131.6 local_phase=-2.863  peer_amp=1176.0 peer_phase=-0.715  signal_amp=1330738.1 signal_phase=2.705
# Counter 602:
#  ch2: local_amp=1133.4 local_phase=1.224  peer_amp=1174.6 peer_phase=0.273  signal_amp=1331267.1 signal_phase=1.497
#  ch5: local_amp=1132.0 local_phase=1.564  peer_amp=1176.7 peer_phase=-0.415  signal_amp=1332049.1 signal_phase=1.149
#  ch8: local_amp=1131.8 local_phase=2.327  peer_amp=1176.8 peer_phase=-1.448  signal_amp=1331996.3 signal_phase=0.879
#  ch11: local_amp=1132.4 local_phase=1.725  peer_amp=1177.3 peer_phase=-1.197  signal_amp=1333269.1 signal_phase=0.528
#  ch14: local_amp=1132.6 local_phase=-2.466  peer_amp=1176.1 peer_phase=2.831  signal_amp=1332051.9 signal_phase=0.365
#  ch17: local_amp=1132.3 local_phase=-0.076  peer_amp=1176.6 peer_phase=-0.031  signal_amp=1332174.1 signal_phase=-0.107
#  ch20: local_amp=1132.9 local_phase=2.304  peer_amp=1177.1 peer_phase=-2.690  signal_amp=1333624.8 signal_phase=-0.386
#  ch26: local_amp=1133.0 local_phase=-1.575  peer_amp=1175.7 peer_phase=0.550  signal_amp=1332061.1 signal_phase=-1.025
#  ch29: local_amp=1133.2 local_phase=2.849  peer_amp=1176.5 peer_phase=2.101  signal_amp=1333263.0 signal_phase=-1.333
#  ch32: local_amp=1133.1 local_phase=0.888  peer_amp=1176.8 peer_phase=-2.531  signal_amp=1333436.5 signal_phase=-1.643
#  ch35: local_amp=1132.8 local_phase=-1.051  peer_amp=1177.1 peer_phase=-0.990  signal_amp=1333434.0 signal_phase=-2.041
#  ch38: local_amp=1135.0 local_phase=-1.960  peer_amp=1175.3 peer_phase=-0.466  signal_amp=1333961.9 signal_phase=-2.426
#  ch41: local_amp=1134.0 local_phase=-0.002  peer_amp=1177.9 peer_phase=-2.716  signal_amp=1335777.5 signal_phase=-2.718
#  ch44: local_amp=1133.5 local_phase=-0.792  peer_amp=1176.4 peer_phase=-2.273  signal_amp=1333513.5 signal_phase=-3.065
#  ch47: local_amp=1134.0 local_phase=-1.129  peer_amp=1176.5 peer_phase=-2.242  signal_amp=1334054.0 signal_phase=2.912
#  ch50: local_amp=1133.7 local_phase=-1.891  peer_amp=1176.9 peer_phase=-1.854  signal_amp=1334248.0 signal_phase=2.538
# Counter 604:
#  ch2: local_amp=1131.3 local_phase=-0.228  peer_amp=1175.4 peer_phase=1.757  signal_amp=1329774.4 signal_phase=1.529
#  ch5: local_amp=1132.1 local_phase=1.717  peer_amp=1176.7 peer_phase=-0.537  signal_amp=1332081.8 signal_phase=1.180
#  ch8: local_amp=1131.8 local_phase=-1.052  peer_amp=1175.3 peer_phase=2.029  signal_amp=1330217.9 signal_phase=0.977
#  ch11: local_amp=1133.2 local_phase=1.864  peer_amp=1176.6 peer_phase=-1.279  signal_amp=1333322.2 signal_phase=0.584
#  ch14: local_amp=1131.6 local_phase=-1.731  peer_amp=1173.9 peer_phase=2.117  signal_amp=1328382.4 signal_phase=0.386
#  ch17: local_amp=1132.3 local_phase=-1.873  peer_amp=1177.0 peer_phase=1.815  signal_amp=1332759.8 signal_phase=-0.058
#  ch20: local_amp=1132.3 local_phase=0.765  peer_amp=1176.0 peer_phase=-1.151  signal_amp=1331578.1 signal_phase=-0.386
#  ch26: local_amp=1132.0 local_phase=0.663  peer_amp=1176.1 peer_phase=-1.631  signal_amp=1331421.6 signal_phase=-0.968
#  ch29: local_amp=1131.6 local_phase=1.277  peer_amp=1175.4 peer_phase=-2.551  signal_amp=1330076.2 signal_phase=-1.274
#  ch32: local_amp=1134.0 local_phase=-2.472  peer_amp=1177.0 peer_phase=0.903  signal_amp=1334654.2 signal_phase=-1.569
#  ch35: local_amp=1133.8 local_phase=-2.471  peer_amp=1176.7 peer_phase=0.472  signal_amp=1334131.8 signal_phase=-1.999
#  ch38: local_amp=1132.1 local_phase=0.847  peer_amp=1177.2 peer_phase=-3.124  signal_amp=1332669.6 signal_phase=-2.277
#  ch41: local_amp=1132.5 local_phase=-0.297  peer_amp=1177.8 peer_phase=-2.383  signal_amp=1333761.0 signal_phase=-2.680
#  ch44: local_amp=1132.8 local_phase=0.779  peer_amp=1176.3 peer_phase=2.509  signal_amp=1332494.2 signal_phase=-2.995
#  ch47: local_amp=1133.1 local_phase=-0.730  peer_amp=1177.1 peer_phase=-2.586  signal_amp=1333786.2 signal_phase=2.967
#  ch50: local_amp=1131.7 local_phase=-1.871  peer_amp=1177.1 peer_phase=-1.742  signal_amp=1332162.6 signal_phase=2.670
# Counter 606:
#  ch2: local_amp=1131.2 local_phase=-1.553  peer_amp=1175.5 peer_phase=3.064  signal_amp=1329729.5 signal_phase=1.511
#  ch5: local_amp=1131.1 local_phase=0.659  peer_amp=1176.6 peer_phase=0.555  signal_amp=1330909.1 signal_phase=1.214
#  ch8: local_amp=1131.7 local_phase=-1.640  peer_amp=1176.4 peer_phase=2.569  signal_amp=1331308.6 signal_phase=0.930
#  ch11: local_amp=1130.8 local_phase=0.857  peer_amp=1176.0 peer_phase=-0.226  signal_amp=1329794.6 signal_phase=0.631
#  ch14: local_amp=1132.0 local_phase=2.493  peer_amp=1176.5 peer_phase=-2.059  signal_amp=1331851.7 signal_phase=0.434
#  ch17: local_amp=1130.7 local_phase=0.162  peer_amp=1175.8 peer_phase=-0.226  signal_amp=1329517.8 signal_phase=-0.064
#  ch20: local_amp=1131.6 local_phase=-2.267  peer_amp=1176.5 peer_phase=1.929  signal_amp=1331315.7 signal_phase=-0.339
#  ch26: local_amp=1131.8 local_phase=-1.653  peer_amp=1175.1 peer_phase=0.677  signal_amp=1329958.2 signal_phase=-0.976
#  ch29: local_amp=1130.9 local_phase=0.840  peer_amp=1176.7 peer_phase=-2.049  signal_amp=1330798.2 signal_phase=-1.209
#  ch32: local_amp=1131.5 local_phase=-2.140  peer_amp=1175.8 peer_phase=0.526  signal_amp=1330370.3 signal_phase=-1.614
#  ch35: local_amp=1131.0 local_phase=1.079  peer_amp=1179.1 peer_phase=-3.131  signal_amp=1333520.2 signal_phase=-2.052
#  ch38: local_amp=1131.5 local_phase=-0.030  peer_amp=1176.8 peer_phase=-2.230  signal_amp=1331505.7 signal_phase=-2.260
#  ch41: local_amp=1131.0 local_phase=-3.081  peer_amp=1176.3 peer_phase=0.422  signal_amp=1330435.6 signal_phase=-2.659
#  ch44: local_amp=1131.7 local_phase=2.908  peer_amp=1176.6 peer_phase=0.360  signal_amp=1331628.7 signal_phase=-3.015
#  ch47: local_amp=1133.3 local_phase=-1.300  peer_amp=1178.1 peer_phase=-2.098  signal_amp=1335116.6 signal_phase=2.885
#  ch50: local_amp=1132.3 local_phase=2.790  peer_amp=1175.4 peer_phase=-0.177  signal_amp=1330855.3 signal_phase=2.613
# Counter 608:
#  ch2: local_amp=1132.0 local_phase=-3.100  peer_amp=1177.1 peer_phase=-1.586  signal_amp=1332491.7 signal_phase=1.597
#  ch5: local_amp=1130.0 local_phase=-0.371  peer_amp=1177.1 peer_phase=1.654  signal_amp=1330112.6 signal_phase=1.283
#  ch8: local_amp=1131.5 local_phase=1.157  peer_amp=1175.1 peer_phase=-0.161  signal_amp=1329681.0 signal_phase=0.996
#  ch11: local_amp=1132.1 local_phase=-2.295  peer_amp=1177.3 peer_phase=2.907  signal_amp=1332828.8 signal_phase=0.612
#  ch14: local_amp=1131.0 local_phase=1.205  peer_amp=1176.0 peer_phase=-0.901  signal_amp=1330059.8 signal_phase=0.303
#  ch17: local_amp=1132.2 local_phase=2.994  peer_amp=1177.9 peer_phase=-2.944  signal_amp=1333629.6 signal_phase=0.050
#  ch20: local_amp=1131.8 local_phase=-3.072  peer_amp=1178.0 peer_phase=2.718  signal_amp=1333237.0 signal_phase=-0.354
#  ch26: local_amp=1133.8 local_phase=-1.005  peer_amp=1177.7 peer_phase=0.067  signal_amp=1335228.2 signal_phase=-0.938
#  ch29: local_amp=1131.3 local_phase=0.154  peer_amp=1175.8 peer_phase=-1.323  signal_amp=1330207.9 signal_phase=-1.170
#  ch32: local_amp=1132.8 local_phase=-2.319  peer_amp=1176.3 peer_phase=0.760  signal_amp=1332580.4 signal_phase=-1.560
#  ch35: local_amp=1133.4 local_phase=-1.825  peer_amp=1176.9 peer_phase=-0.148  signal_amp=1333956.2 signal_phase=-1.973
#  ch38: local_amp=1130.6 local_phase=0.995  peer_amp=1177.5 peer_phase=3.076  signal_amp=1331254.2 signal_phase=-2.212
#  ch41: local_amp=1131.7 local_phase=2.453  peer_amp=1176.8 peer_phase=1.182  signal_amp=1331822.2 signal_phase=-2.648
#  ch44: local_amp=1133.4 local_phase=-3.076  peer_amp=1177.0 peer_phase=0.109  signal_amp=1334011.6 signal_phase=-2.967
#  ch47: local_amp=1132.7 local_phase=0.707  peer_amp=1177.3 peer_phase=2.354  signal_amp=1333571.0 signal_phase=3.062
#  ch50: local_amp=1130.3 local_phase=0.365  peer_amp=1176.7 peer_phase=2.306  signal_amp=1330019.8 signal_phase=2.670

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_iq_trend(data_per_counter, channels_to_plot):
    """
    随着counter变化，绘制每个指定channel的local/peer/signal的幅值和相位趋势
    """
    counters = sorted(data_per_counter.keys())
    for ch in channels_to_plot:
        # 针对每个信道，收集各counter下的local/peer/signal幅值和相位
        local_amp, peer_amp, signal_amp = [], [], []
        local_phs, peer_phs, signal_phs = [], [], []
        valid_counters = []
        for counter in counters:
            ch_list = data_per_counter[counter]
            entry = next((e for e in ch_list if e['channel'] == ch), None)
            if entry is not None:
                local_amp.append(entry['local']['amplitude'])
                peer_amp.append(entry['peer']['amplitude'])
                signal_amp.append(entry['signal']['amplitude'])
                local_phs.append(entry['local']['phase'])
                peer_phs.append(entry['peer']['phase'])
                signal_phs.append(entry['signal']['phase'])
                valid_counters.append(counter)
        if not valid_counters:
            print(f"Channel {ch} not found in any counter.")
            continue
        
        # 相位展开
        local_phs = np.unwrap(local_phs)
        peer_phs = np.unwrap(peer_phs)
        signal_phs = np.unwrap(signal_phs)
        
        # 画幅值
        plt.figure(figsize=(10,6))
        plt.plot(valid_counters, local_amp, 'b-o', label='Local amplitude')
        plt.plot(valid_counters, peer_amp, 'g-o', label='Peer amplitude')
        # plt.plot(valid_counters, signal_amp, 'r-o', label='Signal amplitude')
        plt.xlabel('Ranging Counter')
        plt.ylabel('Amplitude')
        plt.title(f'Channel {ch}: Amplitude Trend')
        plt.legend()
        plt.grid()
        plt.tight_layout()
        plt.show()
        
        # 画相位
        plt.figure(figsize=(10,6))
        plt.plot(valid_counters, local_phs, 'b-o', label='Local phase')
        plt.plot(valid_counters, peer_phs, 'g-o', label='Peer phase')
        plt.plot(valid_counters, signal_phs, 'r-o', label='Signal phase')
        # plt.ylim(-10, 10)
        plt.xlabel('Ranging Counter')
        plt.ylabel('Unwrapped Phase (rad)')
        plt.title(f'Channel {ch}: Phase Trend')
        plt.legend()
        plt.grid()
        plt.tight_layout()
        plt.show()

# 用法举例
if __name__ == '__main__':
    # 假设 data_per_counter 已经由上面的 parse_and_process_iq 生成
    channels_to_plot = [2, 14, 29, 50]  # 你希望观察的信道号
    plot_iq_trend(data_per_counter, channels_to_plot)

# %% [markdown]
# local,peer,signal 的幅值相位变化。注意signal 的幅值就是peer，乘积的幅值没有实际意义。

# %%
import numpy as np
import matplotlib.pyplot as plt
# from matplotlib import cm

def plot_amplitude_vs_counter(data_per_counter, channels_to_plot):
    """
    幅值随counter变化。每个信道画三条曲线：local/peer/signal的amplitude。

    """
    axis_label_size = 18
    title_size = 20
    legend_size = 16
    tick_size = 14
    scale_size = 3
    pt = 1/72.27
    linewidth = 246*pt

    # n_ch = len(channels_to_plot)
    # color_map = cm.get_cmap('tab10', n_ch)
    # line_styles = ['-', '--', '-.', ':', (0, (3, 1, 1, 1)), (0, (5, 1)), (0, (1, 1))]
    # marker = '^'

    counters = sorted(data_per_counter.keys())
    plt.figure(figsize=(scale_size*1.4*linewidth, scale_size*0.5*linewidth))
    for ch in channels_to_plot:
        # 收集数据
        local_amp, peer_amp, signal_amp, valid_counters = [], [], [], []
        for counter in counters:
            entry = next((e for e in data_per_counter[counter] if e['channel'] == ch), None)
            if entry:
                local_amp.append(entry['local']['amplitude'])
                peer_amp.append(entry['peer']['amplitude'])
                # signal_amp.append(entry['signal']['amplitude'])
                valid_counters.append(counter)
        if valid_counters:
            plt.plot(valid_counters, local_amp, '-o', label=f'ch{ch} local')
            plt.plot(valid_counters, peer_amp, '--s', label=f'ch{ch} peer')
            # plt.plot(valid_counters, signal_amp, '-.^', label=f'ch{ch} signal')
    plt.xlabel('Subevent Counter', fontsize=axis_label_size)
    plt.ylabel('Amplitude', fontsize=axis_label_size)
    plt.title('(c) Amplitude Variation (2m)', fontsize=title_size)
    plt.legend(loc='upper right', ncol=2, fontsize=legend_size)
    plt.grid()
    plt.tight_layout()
    plt.savefig('./poster.fig/Amplitude vs Counter.svg', dpi=300)
    plt.savefig('./poster.fig/Amplitude vs Counter.pdf', dpi=300)
    plt.show()

def plot_phase_vs_counter(data_per_counter, channels_to_plot):
    """
    相位随counter变化。每个信道画三条曲线：local/peer/signal的phase。
    """
    counters = sorted(data_per_counter.keys())
    plt.figure(figsize=(14, 7))
    for ch in channels_to_plot:
        local_phs, peer_phs, signal_phs, valid_counters = [], [], [], []
        for counter in counters:
            entry = next((e for e in data_per_counter[counter] if e['channel'] == ch), None)
            if entry:
                local_phs.append(entry['local']['phase'])
                peer_phs.append(entry['peer']['phase'])
                signal_phs.append(entry['signal']['phase'])
                valid_counters.append(counter)
        if valid_counters:
            # 相位展开
            local_phs = np.unwrap(local_phs)
            peer_phs = np.unwrap(peer_phs)
            signal_phs = np.unwrap(signal_phs)
            plt.plot(valid_counters, local_phs, '-o', label=f'ch{ch} local')
            plt.plot(valid_counters, peer_phs, '--s', label=f'ch{ch} peer')
            plt.plot(valid_counters, signal_phs, '-.^', label=f'ch{ch} signal')
    plt.xlabel('Ranging Counter')
    plt.ylabel('Unwrapped Phase (rad)')
    plt.title('Phase vs Counter for Each Channel (Local/Peer/Signal)')
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.show()

# 用法举例
if __name__ == '__main__':
    # 假设 data_per_counter 已由 parse_and_process_iq 生成
    channels_to_plot = [2, 14, 29, 50]  # 可自由指定
    # channels_to_plot = [2, 14]  # 可自由指定
    # channels_to_plot = [2, 5, 8, 11, 14, 17, 20, 23, 26, 29, 32, 35, 38, 41, 44, 47, 50]
    channels_to_plot = [2,   8,   14,  20,  26,  32, 38,  44,  50]  # 展示的信道pcd.itv.4.cable
    plot_amplitude_vs_counter(data_per_counter, channels_to_plot)
    plot_phase_vs_counter(data_per_counter, channels_to_plot)

# %% [markdown]
# local,peer,signal 的幅值相位变化。注意signal 的幅值就是peer，乘积的幅值没有实际意义。

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def plot_amplitude_vs_counter_pretty(data_per_counter, channels_to_plot):
    """
    更美观的幅值随counter变化图，同一信道同色，local/peer/signal不同线型
    """
    counters = sorted(data_per_counter.keys())
    n_ch = len(channels_to_plot)
    color_map = cm.get_cmap('tab10', n_ch)
    line_styles = {'local': '-o', 'peer': '--s', 'signal': '-.^'}
    labels = {'local': 'local', 'peer': 'peer', 'signal': 'signal'}

    plt.figure(figsize=(14, 7))
    for idx, ch in enumerate(channels_to_plot):
        color = color_map(idx)
        for kind in ['local', 'peer']:
            y, valid_counters = [], []
            for counter in counters:
                entry = next((e for e in data_per_counter[counter] if e['channel'] == ch), None)
                if entry:
                    y.append(entry[kind]['amplitude'])
                    valid_counters.append(counter)
            if valid_counters:
                plt.plot(valid_counters, y, line_styles[kind], color=color,
                         label=f'ch{ch} {labels[kind]}')
    plt.xlabel('Ranging Counter')
    plt.ylabel('Amplitude')
    plt.title('Amplitude vs Counter for Each Channel (Pretty)')
    plt.legend(loc='best', ncol=2)
    plt.grid()
    plt.tight_layout()
    plt.show()

def plot_phase_vs_counter_pretty(data_per_counter, channels_to_plot):
    """
    更美观的相位随counter变化图，同一信道同色，local/peer/signal不同线型
    """
    counters = sorted(data_per_counter.keys())
    n_ch = len(channels_to_plot)
    color_map = cm.get_cmap('tab10', n_ch)
    line_styles = {'local': '-o', 'peer': '--s', 'signal': '-.^'}
    labels = {'local': 'local', 'peer': 'peer', 'signal': 'signal'}

    plt.figure(figsize=(14, 7))
    for idx, ch in enumerate(channels_to_plot):
        color = color_map(idx)
        for kind in ['local', 'peer', 'signal']:
            y, valid_counters = [], []
            for counter in counters:
                entry = next((e for e in data_per_counter[counter] if e['channel'] == ch), None)
                if entry:
                    y.append(entry[kind]['phase'])
                    valid_counters.append(counter)
            if valid_counters:
                y = np.unwrap(y)
                plt.plot(valid_counters, y, line_styles[kind], color=color,
                         label=f'ch{ch} {labels[kind]}')
    plt.xlabel('Ranging Counter')
    plt.ylabel('Unwrapped Phase (rad)')
    plt.title('Phase vs Counter for Each Channel (Pretty)')
    plt.legend(loc='best', ncol=2)
    plt.grid()
    plt.tight_layout()
    plt.show()

channels_to_plot = [2, 14, 29, 50]  # 可自由调节
plot_amplitude_vs_counter_pretty(data_per_counter, channels_to_plot)
plot_phase_vs_counter_pretty(data_per_counter, channels_to_plot)
# Out:
# C:\Users\cwdbo\AppData\Local\Temp\ipykernel_55500\2119902642.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = cm.get_cmap('tab10', n_ch)
# C:\Users\cwdbo\AppData\Local\Temp\ipykernel_55500\2119902642.py:42: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = cm.get_cmap('tab10', n_ch)

# %% [markdown]
# 单次采样的相位变化，可见mode-0确实需要每一次都执行。否则，local应该是静止的

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_phase_vs_channel_at_counter(data_per_counter, counter):
    """
    展示某一counter下，所有channel的local/peer/signal相位随channel变化
    """
    if counter not in data_per_counter:
        print(f"Counter {counter} not found.")
        return
    ch_entries = sorted(data_per_counter[counter], key=lambda e: e['channel'])
    channels = [e['channel'] for e in ch_entries]
    local_phs = np.unwrap([e['local']['phase'] for e in ch_entries])
    peer_phs  = np.unwrap([e['peer']['phase']  for e in ch_entries])
    signal_phs= np.unwrap([e['signal']['phase'] for e in ch_entries])

    plt.figure(figsize=(10,5))
    plt.plot(channels, local_phs, '-o', label='local')
    plt.plot(channels, peer_phs, '--s', label='peer')
    plt.plot(channels, signal_phs, '-.^', label='signal')
    plt.xlabel('Channel')
    plt.ylabel('Unwrapped Phase (rad)')
    plt.title(f'Counter {counter}: Phase vs Channel')
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.show()

plot_phase_vs_channel_at_counter(data_per_counter, counter=0)  # counter编号可自定

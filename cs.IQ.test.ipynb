# %%
import re
import numpy as np

def parse_and_process_iq(log_lines):
    # 存储结构：{counter: [ {...}, ... ]}
    data_per_counter = {}
    ranging_counter = None
    current_data = []
    for line in log_lines:
        # 检测counter标记
        m = re.search(r'I: Ranging data get completed for ranging counter (\d+)', line)
        if m:
            if ranging_counter is not None and current_data:
                # 按channel排序后保存
                current_data.sort(key=lambda x: x['channel'])
                data_per_counter[ranging_counter] = current_data
            ranging_counter = int(m.group(1))
            current_data = []
        # 解析IQ行
        m = re.match(r'id:(\d+), f:(\d+), ch:(\d+), ap:(\d+), li:(-?\d+), lq:(-?\d+), pi:(-?\d+), pq:(-?\d+)', line)
        if m:
            failed = int(m.group(2))
            if failed:
                continue
            channel = int(m.group(3))
            li, lq, pi, pq = map(int, [m.group(5), m.group(6), m.group(7), m.group(8)])
            # local/peer幅值和相位
            local_amp  = np.hypot(li, lq)
            local_phs  = np.arctan2(lq, li)
            peer_amp   = np.hypot(pi, pq)
            peer_phs   = np.arctan2(pq, pi)
            # signal = local x conj(peer)
            sig_i = li * pi - lq * pq
            sig_q = li * pq + lq * pi
            sig_amp = np.hypot(sig_i, sig_q)
            sig_phs = np.arctan2(sig_q, sig_i)
            entry = {
                'channel': channel,
                'local':  {'i': li, 'q': lq, 'amplitude': local_amp, 'phase': local_phs},
                'peer':   {'i': pi, 'q': pq, 'amplitude': peer_amp, 'phase': peer_phs},
                'signal': {'i': sig_i, 'q': sig_q, 'amplitude': sig_amp, 'phase': sig_phs},
            }
            current_data.append(entry)
    # 最后一组
    if ranging_counter is not None and current_data:
        current_data.sort(key=lambda x: x['channel'])
        data_per_counter[ranging_counter] = current_data
    return data_per_counter

# 用法举例
if __name__ == '__main__':
    with open('iqtest1.txt', 'r', encoding='utf-8') as f:
        log_lines = f.readlines()
    data_per_counter = parse_and_process_iq(log_lines)

    # 访问数据示例
    for counter, ch_list in data_per_counter.items():
        print(f'Counter {counter}:')
        for entry in ch_list:
            ch = entry['channel']
            la, lp = entry['local']['amplitude'], entry['local']['phase']
            pa, pp = entry['peer']['amplitude'], entry['peer']['phase']
            sa, sp = entry['signal']['amplitude'], entry['signal']['phase']
            print(f' ch{ch}: local_amp={la:.1f} local_phase={lp:.3f}  '
                  f'peer_amp={pa:.1f} peer_phase={pp:.3f}  '
                  f'signal_amp={sa:.1f} signal_phase={sp:.3f}')
# Out:
# Counter 0:
#  ch2: local_amp=1131.6 local_phase=0.358  peer_amp=1175.7 peer_phase=1.169  signal_amp=1330394.6 signal_phase=1.526
#  ch5: local_amp=1132.4 local_phase=-0.929  peer_amp=1175.0 peer_phase=2.092  signal_amp=1330552.9 signal_phase=1.163
#  ch8: local_amp=1131.5 local_phase=1.119  peer_amp=1176.1 peer_phase=-0.268  signal_amp=1330835.1 signal_phase=0.851
#  ch11: local_amp=1132.7 local_phase=2.653  peer_amp=1176.8 peer_phase=-2.139  signal_amp=1332918.4 signal_phase=0.514
#  ch14: local_amp=1131.6 local_phase=-0.377  peer_amp=1174.7 peer_phase=0.691  signal_amp=1329380.2 signal_phase=0.314
#  ch17: local_amp=1132.3 local_phase=1.204  peer_amp=1176.5 peer_phase=-1.298  signal_amp=1332153.8 signal_phase=-0.094
#  ch20: local_amp=1133.3 local_phase=2.154  peer_amp=1177.1 peer_phase=-2.688  signal_amp=1333994.3 signal_phase=-0.534
#  ch26: local_amp=1132.2 local_phase=1.190  peer_amp=1175.9 peer_phase=-2.179  signal_amp=1331368.7 signal_phase=-0.989
#  ch29: local_amp=1131.2 local_phase=1.000  peer_amp=1177.4 peer_phase=-2.348  signal_amp=1331845.5 signal_phase=-1.348
#  ch32: local_amp=1132.9 local_phase=2.572  peer_amp=1176.5 peer_phase=1.998  signal_amp=1332871.5 signal_phase=-1.714
#  ch35: local_amp=1133.2 local_phase=1.712  peer_amp=1175.7 peer_phase=2.464  signal_amp=1332293.1 signal_phase=-2.108
#  ch38: local_amp=1133.0 local_phase=-1.295  peer_amp=1177.3 peer_phase=-1.048  signal_amp=1333877.1 signal_phase=-2.342
#  ch41: local_amp=1132.1 local_phase=0.779  peer_amp=1175.9 peer_phase=2.742  signal_amp=1331199.6 signal_phase=-2.763
#  ch44: local_amp=1131.8 local_phase=1.174  peer_amp=1176.6 peer_phase=2.041  signal_amp=1331690.7 signal_phase=-3.068
#  ch47: local_amp=1134.6 local_phase=-1.896  peer_amp=1177.2 peer_phase=-1.487  signal_amp=1335657.3 signal_phase=2.900
#  ch50: local_amp=1131.9 local_phase=2.477  peer_amp=1175.0 peer_phase=0.041  signal_amp=1329902.4 signal_phase=2.518
# Counter 2:
#  ch2: local_amp=1132.4 local_phase=-2.399  peer_amp=1175.6 peer_phase=-2.291  signal_amp=1331262.2 signal_phase=1.594
#  ch5: local_amp=1131.9 local_phase=-3.031  peer_amp=1176.4 peer_phase=-2.053  signal_amp=1331576.6 signal_phase=1.199
#  ch8: local_amp=1131.8 local_phase=-1.226  peer_amp=1176.1 peer_phase=2.071  signal_amp=1331036.4 signal_phase=0.845
#  ch11: local_amp=1133.1 local_phase=-1.195  peer_amp=1176.9 peer_phase=1.793  signal_amp=1333522.4 signal_phase=0.598
#  ch14: local_amp=1132.9 local_phase=1.123  peer_amp=1174.7 peer_phase=-0.803  signal_amp=1330829.7 signal_phase=0.320
#  ch17: local_amp=1133.5 local_phase=-2.760  peer_amp=1175.7 peer_phase=2.640  signal_amp=1332597.5 signal_phase=-0.120
#  ch20: local_amp=1132.9 local_phase=-0.406  peer_amp=1176.2 peer_phase=0.084  signal_amp=1332501.7 signal_phase=-0.321
#  ch26: local_amp=1132.2 local_phase=2.480  peer_amp=1176.4 peer_phase=2.809  signal_amp=1331953.9 signal_phase=-0.995
#  ch29: local_amp=1132.9 local_phase=-3.101  peer_amp=1175.1 peer_phase=1.823  signal_amp=1331326.9 signal_phase=-1.278
#  ch32: local_amp=1132.0 local_phase=-1.392  peer_amp=1175.5 peer_phase=-0.273  signal_amp=1330706.3 signal_phase=-1.665
#  ch35: local_amp=1133.5 local_phase=-0.229  peer_amp=1176.3 peer_phase=-1.787  signal_amp=1333369.5 signal_phase=-2.015
#  ch38: local_amp=1133.8 local_phase=-2.964  peer_amp=1176.8 peer_phase=0.685  signal_amp=1334274.0 signal_phase=-2.279
#  ch41: local_amp=1131.7 local_phase=0.869  peer_amp=1176.8 peer_phase=2.757  signal_amp=1331796.6 signal_phase=-2.657
#  ch44: local_amp=1133.2 local_phase=-1.382  peer_amp=1176.0 peer_phase=-1.663  signal_amp=1332606.8 signal_phase=-3.044
#  ch47: local_amp=1134.8 local_phase=-2.425  peer_amp=1175.5 peer_phase=-0.892  signal_amp=1333985.4 signal_phase=2.966
#  ch50: local_amp=1132.1 local_phase=1.561  peer_amp=1174.9 peer_phase=1.052  signal_amp=1330000.9 signal_phase=2.613
# Counter 4:
#  ch2: local_amp=1132.3 local_phase=-0.096  peer_amp=1174.5 peer_phase=1.600  signal_amp=1329829.2 signal_phase=1.503
#  ch5: local_amp=1132.5 local_phase=2.226  peer_amp=1175.3 peer_phase=-1.039  signal_amp=1331026.6 signal_phase=1.187
#  ch8: local_amp=1132.2 local_phase=2.165  peer_amp=1174.9 peer_phase=-1.313  signal_amp=1330233.0 signal_phase=0.853
#  ch11: local_amp=1132.7 local_phase=2.135  peer_amp=1177.2 peer_phase=-1.587  signal_amp=1333400.9 signal_phase=0.548
#  ch14: local_amp=1131.8 local_phase=2.936  peer_amp=1176.2 peer_phase=-2.554  signal_amp=1331298.5 signal_phase=0.382
#  ch17: local_amp=1133.1 local_phase=-1.690  peer_amp=1175.1 peer_phase=1.631  signal_amp=1331524.8 signal_phase=-0.059
#  ch20: local_amp=1132.0 local_phase=-1.704  peer_amp=1175.5 peer_phase=1.343  signal_amp=1330636.0 signal_phase=-0.361
#  ch26: local_amp=1132.7 local_phase=1.784  peer_amp=1176.2 peer_phase=-2.745  signal_amp=1332251.6 signal_phase=-0.961
#  ch29: local_amp=1132.0 local_phase=-0.931  peer_amp=1175.9 peer_phase=-0.432  signal_amp=1331101.7 signal_phase=-1.363
#  ch32: local_amp=1133.4 local_phase=1.839  peer_amp=1176.4 peer_phase=2.820  signal_amp=1333322.4 signal_phase=-1.625
#  ch35: local_amp=1133.3 local_phase=-0.994  peer_amp=1177.3 peer_phase=-1.013  signal_amp=1334308.3 signal_phase=-2.007
#  ch38: local_amp=1131.0 local_phase=-2.063  peer_amp=1175.0 peer_phase=-0.230  signal_amp=1328895.8 signal_phase=-2.293
#  ch41: local_amp=1133.1 local_phase=1.260  peer_amp=1176.6 peer_phase=2.288  signal_amp=1333183.8 signal_phase=-2.735
#  ch44: local_amp=1133.6 local_phase=-1.015  peer_amp=1176.0 peer_phase=-2.055  signal_amp=1333032.7 signal_phase=-3.070
#  ch47: local_amp=1133.1 local_phase=-2.701  peer_amp=1176.4 peer_phase=-0.710  signal_amp=1332995.4 signal_phase=2.872
#  ch50: local_amp=1133.2 local_phase=0.203  peer_amp=1176.2 peer_phase=2.380  signal_amp=1332887.1 signal_phase=2.582
# Counter 6:
#  ch2: local_amp=1132.8 local_phase=-0.995  peer_amp=1174.8 peer_phase=2.501  signal_amp=1330795.4 signal_phase=1.506
#  ch5: local_amp=1131.0 local_phase=-1.572  peer_amp=1177.4 peer_phase=2.809  signal_amp=1331617.9 signal_phase=1.238
#  ch8: local_amp=1132.7 local_phase=-0.269  peer_amp=1174.2 peer_phase=1.152  signal_amp=1330099.4 signal_phase=0.884
#  ch11: local_amp=1133.3 local_phase=0.521  peer_amp=1173.9 peer_phase=0.057  signal_amp=1330404.6 signal_phase=0.578
#  ch14: local_amp=1134.0 local_phase=-1.772  peer_amp=1175.1 peer_phase=2.011  signal_amp=1332561.5 signal_phase=0.239
#  ch17: local_amp=1134.3 local_phase=-1.782  peer_amp=1175.7 peer_phase=1.706  signal_amp=1333499.4 signal_phase=-0.077
#  ch20: local_amp=1131.1 local_phase=0.505  peer_amp=1177.0 peer_phase=-0.828  signal_amp=1331252.5 signal_phase=-0.323
#  ch26: local_amp=1133.8 local_phase=-2.137  peer_amp=1175.7 peer_phase=1.203  signal_amp=1333046.7 signal_phase=-0.934
#  ch29: local_amp=1132.3 local_phase=2.485  peer_amp=1175.9 peer_phase=2.526  signal_amp=1331416.6 signal_phase=-1.272
#  ch32: local_amp=1133.8 local_phase=-1.533  peer_amp=1176.9 peer_phase=-0.082  signal_amp=1334412.4 signal_phase=-1.615
#  ch35: local_amp=1133.0 local_phase=1.402  peer_amp=1176.2 peer_phase=2.863  signal_amp=1332707.5 signal_phase=-2.017
#  ch38: local_amp=1133.7 local_phase=-2.527  peer_amp=1175.6 peer_phase=0.209  signal_amp=1332734.6 signal_phase=-2.318
#  ch41: local_amp=1133.4 local_phase=3.092  peer_amp=1175.3 peer_phase=0.455  signal_amp=1332096.4 signal_phase=-2.737
#  ch44: local_amp=1133.4 local_phase=2.049  peer_amp=1174.4 peer_phase=1.228  signal_amp=1331047.8 signal_phase=-3.006
#  ch47: local_amp=1133.0 local_phase=-1.301  peer_amp=1176.8 peer_phase=-2.052  signal_amp=1333311.1 signal_phase=2.930
#  ch50: local_amp=1133.3 local_phase=2.685  peer_amp=1176.1 peer_phase=-0.137  signal_amp=1332801.3 signal_phase=2.547
# Counter 8:
#  ch2: local_amp=1132.0 local_phase=-0.453  peer_amp=1175.5 peer_phase=2.016  signal_amp=1330606.2 signal_phase=1.563
#  ch5: local_amp=1133.0 local_phase=2.337  peer_amp=1176.3 peer_phase=-1.120  signal_amp=1332701.4 signal_phase=1.217
#  ch8: local_amp=1131.8 local_phase=0.178  peer_amp=1173.3 peer_phase=0.706  signal_amp=1327923.4 signal_phase=0.883
#  ch11: local_amp=1130.7 local_phase=-0.144  peer_amp=1176.0 peer_phase=0.776  signal_amp=1329624.9 signal_phase=0.633
#  ch14: local_amp=1132.9 local_phase=1.809  peer_amp=1177.2 peer_phase=-1.487  signal_amp=1333630.6 signal_phase=0.322
#  ch17: local_amp=1134.2 local_phase=-1.912  peer_amp=1175.8 peer_phase=1.946  signal_amp=1333632.5 signal_phase=0.035
#  ch20: local_amp=1130.9 local_phase=-1.611  peer_amp=1176.1 peer_phase=1.290  signal_amp=1330076.8 signal_phase=-0.322
#  ch26: local_amp=1133.6 local_phase=-1.708  peer_amp=1175.9 peer_phase=0.792  signal_amp=1333104.9 signal_phase=-0.916
#  ch29: local_amp=1132.2 local_phase=1.450  peer_amp=1176.8 peer_phase=-2.710  signal_amp=1332354.5 signal_phase=-1.260
#  ch32: local_amp=1132.6 local_phase=-1.229  peer_amp=1177.3 peer_phase=-0.316  signal_amp=1333504.5 signal_phase=-1.545
#  ch35: local_amp=1133.0 local_phase=-0.986  peer_amp=1177.6 peer_phase=-1.044  signal_amp=1334222.8 signal_phase=-2.031
#  ch38: local_amp=1132.4 local_phase=1.027  peer_amp=1176.4 peer_phase=3.037  signal_amp=1332223.4 signal_phase=-2.219
#  ch41: local_amp=1133.0 local_phase=2.375  peer_amp=1176.8 peer_phase=1.262  signal_amp=1333269.6 signal_phase=-2.647
#  ch44: local_amp=1133.6 local_phase=-3.108  peer_amp=1176.0 peer_phase=0.130  signal_amp=1333151.9 signal_phase=-2.978
#  ch47: local_amp=1134.7 local_phase=-2.863  peer_amp=1176.4 peer_phase=-0.485  signal_amp=1334935.8 signal_phase=2.936
#  ch50: local_amp=1132.9 local_phase=0.304  peer_amp=1176.0 peer_phase=2.366  signal_amp=1332277.9 signal_phase=2.670
# Counter 10:
#  ch2: local_amp=1132.1 local_phase=1.705  peer_amp=1175.6 peer_phase=-0.141  signal_amp=1330956.0 signal_phase=1.564
#  ch5: local_amp=1131.9 local_phase=-2.862  peer_amp=1177.5 peer_phase=-2.235  signal_amp=1332706.6 signal_phase=1.186
#  ch8: local_amp=1132.2 local_phase=0.179  peer_amp=1175.1 peer_phase=0.682  signal_amp=1330391.5 signal_phase=0.862
#  ch11: local_amp=1131.0 local_phase=1.986  peer_amp=1175.4 peer_phase=-1.420  signal_amp=1329381.2 signal_phase=0.566
#  ch14: local_amp=1132.1 local_phase=2.106  peer_amp=1175.7 peer_phase=-1.763  signal_amp=1331020.3 signal_phase=0.342
#  ch17: local_amp=1132.3 local_phase=-0.415  peer_amp=1174.8 peer_phase=0.312  signal_amp=1330291.0 signal_phase=-0.103
#  ch20: local_amp=1134.3 local_phase=-2.511  peer_amp=1175.4 peer_phase=2.208  signal_amp=1333275.5 signal_phase=-0.303
#  ch26: local_amp=1133.3 local_phase=2.225  peer_amp=1175.8 peer_phase=3.106  signal_amp=1332442.7 signal_phase=-0.952
#  ch29: local_amp=1131.1 local_phase=1.017  peer_amp=1175.3 peer_phase=-2.306  signal_amp=1329423.3 signal_phase=-1.289
#  ch32: local_amp=1131.6 local_phase=0.984  peer_amp=1176.8 peer_phase=-2.646  signal_amp=1331637.6 signal_phase=-1.662
#  ch35: local_amp=1133.6 local_phase=-1.175  peer_amp=1175.8 peer_phase=-0.853  signal_amp=1332914.9 signal_phase=-2.028
#  ch38: local_amp=1132.8 local_phase=1.103  peer_amp=1175.3 peer_phase=2.879  signal_amp=1331344.4 signal_phase=-2.301
#  ch41: local_amp=1134.0 local_phase=-1.703  peer_amp=1175.5 peer_phase=-0.957  signal_amp=1332999.5 signal_phase=-2.661
#  ch44: local_amp=1133.4 local_phase=1.124  peer_amp=1176.3 peer_phase=2.114  signal_amp=1333227.5 signal_phase=-3.045
#  ch47: local_amp=1132.1 local_phase=1.167  peer_amp=1176.4 peer_phase=1.733  signal_amp=1331881.4 signal_phase=2.900
#  ch50: local_amp=1132.0 local_phase=2.911  peer_amp=1174.9 peer_phase=-0.268  signal_amp=1330028.1 signal_phase=2.643
# Counter 12:
#  ch2: local_amp=1132.5 local_phase=-3.052  peer_amp=1175.0 peer_phase=-1.746  signal_amp=1330726.0 signal_phase=1.485
#  ch5: local_amp=1131.5 local_phase=-2.808  peer_amp=1176.6 peer_phase=-2.354  signal_amp=1331412.9 signal_phase=1.122
#  ch8: local_amp=1132.1 local_phase=0.211  peer_amp=1175.5 peer_phase=0.697  signal_amp=1330779.1 signal_phase=0.908
#  ch11: local_amp=1130.5 local_phase=1.946  peer_amp=1175.7 peer_phase=-1.314  signal_amp=1329116.8 signal_phase=0.632
#  ch14: local_amp=1132.9 local_phase=-2.708  peer_amp=1175.9 peer_phase=2.944  signal_amp=1332138.0 signal_phase=0.236
#  ch17: local_amp=1131.8 local_phase=-0.877  peer_amp=1174.5 peer_phase=0.782  signal_amp=1329364.4 signal_phase=-0.094
#  ch20: local_amp=1132.2 local_phase=-1.634  peer_amp=1174.7 peer_phase=1.267  signal_amp=1329991.0 signal_phase=-0.366
#  ch26: local_amp=1131.8 local_phase=1.859  peer_amp=1176.3 peer_phase=-2.839  signal_amp=1331278.6 signal_phase=-0.980
#  ch29: local_amp=1133.3 local_phase=0.739  peer_amp=1175.7 peer_phase=-1.996  signal_amp=1332441.5 signal_phase=-1.257
#  ch32: local_amp=1133.0 local_phase=2.935  peer_amp=1175.9 peer_phase=1.700  signal_amp=1332264.1 signal_phase=-1.647
#  ch35: local_amp=1133.2 local_phase=-1.657  peer_amp=1176.2 peer_phase=-0.372  signal_amp=1332869.4 signal_phase=-2.028
#  ch38: local_amp=1134.5 local_phase=-2.864  peer_amp=1175.5 peer_phase=0.529  signal_amp=1333594.6 signal_phase=-2.335
#  ch41: local_amp=1132.8 local_phase=-2.392  peer_amp=1176.4 peer_phase=-0.311  signal_amp=1332660.3 signal_phase=-2.703
#  ch44: local_amp=1132.3 local_phase=-1.310  peer_amp=1176.8 peer_phase=-1.730  signal_amp=1332480.2 signal_phase=-3.039
#  ch47: local_amp=1132.6 local_phase=0.360  peer_amp=1176.0 peer_phase=2.559  signal_amp=1331926.4 signal_phase=2.919
#  ch50: local_amp=1133.0 local_phase=-2.503  peer_amp=1175.0 peer_phase=-1.141  signal_amp=1331341.4 signal_phase=2.639
# Counter 14:
#  ch2: local_amp=1129.9 local_phase=0.132  peer_amp=1176.6 peer_phase=1.362  signal_amp=1329378.0 signal_phase=1.494
#  ch5: local_amp=1133.0 local_phase=2.885  peer_amp=1177.6 peer_phase=-1.717  signal_amp=1334199.1 signal_phase=1.168
#  ch8: local_amp=1133.0 local_phase=-0.619  peer_amp=1174.5 peer_phase=1.506  signal_amp=1330607.4 signal_phase=0.887
#  ch11: local_amp=1131.8 local_phase=1.191  peer_amp=1176.8 peer_phase=-0.714  signal_amp=1331871.4 signal_phase=0.476
#  ch14: local_amp=1132.3 local_phase=2.534  peer_amp=1175.4 peer_phase=-2.208  signal_amp=1330993.2 signal_phase=0.327
#  ch17: local_amp=1132.1 local_phase=-1.402  peer_amp=1176.9 peer_phase=1.300  signal_amp=1332361.4 signal_phase=-0.102
#  ch20: local_amp=1133.4 local_phase=1.904  peer_amp=1176.7 peer_phase=-2.343  signal_amp=1333749.0 signal_phase=-0.439
#  ch26: local_amp=1132.5 local_phase=2.730  peer_amp=1177.0 peer_phase=2.474  signal_amp=1332948.9 signal_phase=-1.079
#  ch29: local_amp=1132.5 local_phase=-3.075  peer_amp=1176.1 peer_phase=1.673  signal_amp=1331959.8 signal_phase=-1.402
#  ch32: local_amp=1133.6 local_phase=-0.067  peer_amp=1175.0 peer_phase=-1.680  signal_amp=1331913.8 signal_phase=-1.747
#  ch35: local_amp=1131.7 local_phase=-2.893  peer_amp=1176.5 peer_phase=0.817  signal_amp=1331435.8 signal_phase=-2.076
#  ch38: local_amp=1132.2 local_phase=2.205  peer_amp=1174.5 peer_phase=1.668  signal_amp=1329876.5 signal_phase=-2.410
#  ch41: local_amp=1132.2 local_phase=1.085  peer_amp=1176.3 peer_phase=2.411  signal_amp=1331749.9 signal_phase=-2.788
#  ch44: local_amp=1133.4 local_phase=2.822  peer_amp=1176.3 peer_phase=0.360  signal_amp=1333134.3 signal_phase=-3.101
#  ch47: local_amp=1132.8 local_phase=-2.270  peer_amp=1176.7 peer_phase=-1.095  signal_amp=1332917.6 signal_phase=2.918
#  ch50: local_amp=1131.3 local_phase=1.799  peer_amp=1175.1 peer_phase=0.853  signal_amp=1329391.7 signal_phase=2.652
# Counter 16:
#  ch2: local_amp=1132.4 local_phase=0.097  peer_amp=1173.5 peer_phase=1.431  signal_amp=1328837.4 signal_phase=1.528
#  ch5: local_amp=1132.5 local_phase=-2.748  peer_amp=1176.6 peer_phase=-2.288  signal_amp=1332412.6 signal_phase=1.247
#  ch8: local_amp=1132.1 local_phase=2.484  peer_amp=1175.4 peer_phase=-1.521  signal_amp=1330721.7 signal_phase=0.963
#  ch11: local_amp=1131.8 local_phase=-0.417  peer_amp=1175.4 peer_phase=0.963  signal_amp=1330279.2 signal_phase=0.547
#  ch14: local_amp=1130.5 local_phase=1.915  peer_amp=1176.1 peer_phase=-1.558  signal_amp=1329570.8 signal_phase=0.357
#  ch17: local_amp=1132.7 local_phase=2.405  peer_amp=1176.9 peer_phase=-2.444  signal_amp=1333113.9 signal_phase=-0.039
#  ch20: local_amp=1132.2 local_phase=-0.542  peer_amp=1175.3 peer_phase=0.167  signal_amp=1330704.1 signal_phase=-0.375
#  ch26: local_amp=1131.8 local_phase=1.045  peer_amp=1175.3 peer_phase=-2.037  signal_amp=1330231.0 signal_phase=-0.992
#  ch29: local_amp=1132.6 local_phase=2.870  peer_amp=1177.0 peer_phase=2.141  signal_amp=1333014.6 signal_phase=-1.273
#  ch32: local_amp=1132.0 local_phase=2.124  peer_amp=1176.3 peer_phase=2.514  signal_amp=1331605.7 signal_phase=-1.645
#  ch35: local_amp=1132.3 local_phase=-1.922  peer_amp=1176.0 peer_phase=-0.130  signal_amp=1331561.7 signal_phase=-2.053
#  ch38: local_amp=1133.0 local_phase=-2.013  peer_amp=1176.6 peer_phase=-0.253  signal_amp=1333125.9 signal_phase=-2.267
#  ch41: local_amp=1131.7 local_phase=0.683  peer_amp=1176.8 peer_phase=2.898  signal_amp=1331732.4 signal_phase=-2.703
#  ch44: local_amp=1133.4 local_phase=-1.668  peer_amp=1176.4 peer_phase=-1.409  signal_amp=1333324.0 signal_phase=-3.077
#  ch47: local_amp=1132.0 local_phase=-0.006  peer_amp=1176.3 peer_phase=2.851  signal_amp=1331604.9 signal_phase=2.845
#  ch50: local_amp=1134.6 local_phase=2.842  peer_amp=1175.7 peer_phase=-0.201  signal_amp=1333958.7 signal_phase=2.641
# Counter 18:
#  ch2: local_amp=1131.7 local_phase=-2.453  peer_amp=1174.2 peer_phase=-2.291  signal_amp=1328899.3 signal_phase=1.539
#  ch5: local_amp=1132.0 local_phase=2.788  peer_amp=1176.0 peer_phase=-1.572  signal_amp=1331277.6 signal_phase=1.215
#  ch8: local_amp=1131.9 local_phase=-3.070  peer_amp=1174.2 peer_phase=-2.291  signal_amp=1329088.6 signal_phase=0.923
#  ch11: local_amp=1132.6 local_phase=-1.491  peer_amp=1176.1 peer_phase=2.193  signal_amp=1332005.0 signal_phase=0.701
#  ch14: local_amp=1134.2 local_phase=3.021  peer_amp=1175.8 peer_phase=-2.688  signal_amp=1333557.6 signal_phase=0.333
#  ch17: local_amp=1131.9 local_phase=-1.530  peer_amp=1175.1 peer_phase=1.557  signal_amp=1330147.0 signal_phase=0.027
#  ch20: local_amp=1133.4 local_phase=-1.736  peer_amp=1175.3 peer_phase=1.475  signal_amp=1332100.8 signal_phase=-0.260
#  ch26: local_amp=1132.8 local_phase=2.084  peer_amp=1176.0 peer_phase=-3.025  signal_amp=1332216.9 signal_phase=-0.941
#  ch29: local_amp=1133.5 local_phase=1.313  peer_amp=1176.7 peer_phase=-2.519  signal_amp=1333701.4 signal_phase=-1.206
#  ch32: local_amp=1134.3 local_phase=-0.346  peer_amp=1175.1 peer_phase=-1.272  signal_amp=1332948.8 signal_phase=-1.618
#  ch35: local_amp=1131.6 local_phase=1.731  peer_amp=1176.7 peer_phase=2.590  signal_amp=1331551.8 signal_phase=-1.962
#  ch38: local_amp=1134.3 local_phase=1.984  peer_amp=1174.9 peer_phase=2.097  signal_amp=1332625.8 signal_phase=-2.203
#  ch41: local_amp=1134.5 local_phase=2.291  peer_amp=1174.7 peer_phase=1.338  signal_amp=1332694.4 signal_phase=-2.654
#  ch44: local_amp=1135.0 local_phase=-2.033  peer_amp=1175.9 peer_phase=-0.889  signal_amp=1334637.4 signal_phase=-2.922
#  ch47: local_amp=1132.1 local_phase=0.508  peer_amp=1174.6 peer_phase=2.427  signal_amp=1329794.0 signal_phase=2.935
#  ch50: local_amp=1133.9 local_phase=-0.340  peer_amp=1174.4 peer_phase=2.990  signal_amp=1331625.3 signal_phase=2.650
# Counter 20:
#  ch2: local_amp=1132.4 local_phase=2.253  peer_amp=1174.4 peer_phase=-0.753  signal_amp=1329966.7 signal_phase=1.500
#  ch5: local_amp=1132.1 local_phase=-2.995  peer_amp=1174.8 peer_phase=-2.060  signal_amp=1329938.4 signal_phase=1.228
#  ch8: local_amp=1131.6 local_phase=-1.650  peer_amp=1174.6 peer_phase=2.593  signal_amp=1329201.7 signal_phase=0.942
#  ch11: local_amp=1132.0 local_phase=1.805  peer_amp=1173.6 peer_phase=-1.240  signal_amp=1328450.6 signal_phase=0.565
#  ch14: local_amp=1130.4 local_phase=0.625  peer_amp=1175.2 peer_phase=-0.332  signal_amp=1328408.2 signal_phase=0.293
#  ch17: local_amp=1134.1 local_phase=-1.674  peer_amp=1176.0 peer_phase=1.612  signal_amp=1333622.0 signal_phase=-0.063
#  ch20: local_amp=1131.0 local_phase=1.378  peer_amp=1175.3 peer_phase=-1.675  signal_amp=1329334.1 signal_phase=-0.297
#  ch26: local_amp=1133.7 local_phase=-2.036  peer_amp=1174.8 peer_phase=1.025  signal_amp=1331838.6 signal_phase=-1.012
#  ch29: local_amp=1132.3 local_phase=1.450  peer_amp=1176.0 peer_phase=-2.743  signal_amp=1331614.2 signal_phase=-1.294
#  ch32: local_amp=1132.1 local_phase=1.497  peer_amp=1175.6 peer_phase=3.111  signal_amp=1330865.9 signal_phase=-1.676
#  ch35: local_amp=1133.9 local_phase=-1.329  peer_amp=1174.9 peer_phase=-0.684  signal_amp=1332219.8 signal_phase=-2.013
#  ch38: local_amp=1132.8 local_phase=0.454  peer_amp=1176.3 peer_phase=-2.693  signal_amp=1332571.9 signal_phase=-2.239
#  ch41: local_amp=1134.6 local_phase=-1.959  peer_amp=1176.2 peer_phase=-0.669  signal_amp=1334522.6 signal_phase=-2.628
#  ch44: local_amp=1131.3 local_phase=2.101  peer_amp=1174.4 peer_phase=1.180  signal_amp=1328552.4 signal_phase=-3.002
#  ch47: local_amp=1133.0 local_phase=-0.168  peer_amp=1175.1 peer_phase=3.049  signal_amp=1331402.1 signal_phase=2.880
#  ch50: local_amp=1133.6 local_phase=-2.894  peer_amp=1176.5 peer_phase=-0.718  signal_amp=1333660.4 signal_phase=2.671
# Counter 22:
#  ch2: local_amp=1131.4 local_phase=-0.750  peer_amp=1175.2 peer_phase=2.351  signal_amp=1329628.4 signal_phase=1.602
#  ch5: local_amp=1132.5 local_phase=-2.199  peer_amp=1177.0 peer_phase=-2.780  signal_amp=1332946.8 signal_phase=1.303
#  ch8: local_amp=1131.2 local_phase=-0.954  peer_amp=1174.6 peer_phase=1.959  signal_amp=1328680.0 signal_phase=1.005
#  ch11: local_amp=1132.8 local_phase=-2.239  peer_amp=1175.3 peer_phase=2.837  signal_amp=1331283.7 signal_phase=0.597
#  ch14: local_amp=1132.6 local_phase=1.194  peer_amp=1175.7 peer_phase=-0.860  signal_amp=1331505.4 signal_phase=0.334
#  ch17: local_amp=1132.8 local_phase=3.041  peer_amp=1176.0 peer_phase=-3.025  signal_amp=1332123.5 signal_phase=0.016
#  ch20: local_amp=1133.9 local_phase=-1.198  peer_amp=1175.9 peer_phase=0.889  signal_amp=1333296.7 signal_phase=-0.309
#  ch26: local_amp=1134.0 local_phase=1.035  peer_amp=1175.6 peer_phase=-1.922  signal_amp=1333082.1 signal_phase=-0.887
#  ch29: local_amp=1133.3 local_phase=-0.533  peer_amp=1175.8 peer_phase=-0.738  signal_amp=1332561.7 signal_phase=-1.271
#  ch32: local_amp=1133.9 local_phase=-1.531  peer_amp=1174.9 peer_phase=-0.039  signal_amp=1332212.2 signal_phase=-1.570
#  ch35: local_amp=1133.5 local_phase=-3.112  peer_amp=1176.2 peer_phase=1.101  signal_amp=1333224.2 signal_phase=-2.010
#  ch38: local_amp=1132.4 local_phase=1.693  peer_amp=1175.3 peer_phase=2.347  signal_amp=1330918.0 signal_phase=-2.244
#  ch41: local_amp=1135.0 local_phase=-1.578  peer_amp=1175.8 peer_phase=-1.119  signal_amp=1334579.4 signal_phase=-2.697
#  ch44: local_amp=1132.2 local_phase=1.401  peer_amp=1174.6 peer_phase=1.838  signal_amp=1329963.4 signal_phase=-3.044
#  ch47: local_amp=1132.0 local_phase=2.271  peer_amp=1175.8 peer_phase=0.728  signal_amp=1330944.6 signal_phase=2.998
#  ch50: local_amp=1134.2 local_phase=-2.084  peer_amp=1175.5 peer_phase=-1.457  signal_amp=1333297.9 signal_phase=2.742
# Counter 24:
#  ch2: local_amp=1130.7 local_phase=-1.651  peer_amp=1175.7 peer_phase=-3.027  signal_amp=1329282.8 signal_phase=1.604
#  ch5: local_amp=1130.5 local_phase=-1.481  peer_amp=1176.2 peer_phase=2.682  signal_amp=1329696.1 signal_phase=1.200
#  ch8: local_amp=1130.8 local_phase=1.853  peer_amp=1175.4 peer_phase=-0.865  signal_amp=1329146.7 signal_phase=0.988
#  ch11: local_amp=1131.7 local_phase=-2.732  peer_amp=1176.5 peer_phase=-2.925  signal_amp=1331524.9 signal_phase=0.627
#  ch14: local_amp=1130.7 local_phase=-2.051  peer_amp=1175.1 peer_phase=2.298  signal_amp=1328683.8 signal_phase=0.247
#  ch17: local_amp=1133.3 local_phase=-1.841  peer_amp=1175.1 peer_phase=1.846  signal_amp=1331721.0 signal_phase=0.004
#  ch20: local_amp=1131.3 local_phase=1.062  peer_amp=1175.2 peer_phase=-1.363  signal_amp=1329439.6 signal_phase=-0.301
#  ch26: local_amp=1130.9 local_phase=-0.390  peer_amp=1175.6 peer_phase=-0.524  signal_amp=1329543.9 signal_phase=-0.914
#  ch29: local_amp=1132.1 local_phase=-0.146  peer_amp=1174.8 peer_phase=-1.106  signal_amp=1330013.5 signal_phase=-1.252
#  ch32: local_amp=1132.7 local_phase=-2.546  peer_amp=1175.2 peer_phase=0.991  signal_amp=1331146.3 signal_phase=-1.556
#  ch35: local_amp=1133.6 local_phase=2.233  peer_amp=1176.2 peer_phase=2.075  signal_amp=1333375.6 signal_phase=-1.975
#  ch38: local_amp=1134.3 local_phase=2.814  peer_amp=1174.5 peer_phase=1.251  signal_amp=1332237.7 signal_phase=-2.218
#  ch41: local_amp=1132.5 local_phase=0.089  peer_amp=1175.7 peer_phase=-2.733  signal_amp=1331523.8 signal_phase=-2.644
#  ch44: local_amp=1131.1 local_phase=-1.038  peer_amp=1175.8 peer_phase=-1.955  signal_amp=1329938.8 signal_phase=-2.993
#  ch47: local_amp=1131.3 local_phase=0.212  peer_amp=1176.9 peer_phase=2.871  signal_amp=1331489.9 signal_phase=3.083
#  ch50: local_amp=1130.2 local_phase=0.274  peer_amp=1175.9 peer_phase=2.448  signal_amp=1329006.7 signal_phase=2.722
# Counter 26:
#  ch2: local_amp=1132.0 local_phase=-0.885  peer_amp=1174.6 peer_phase=2.369  signal_amp=1329666.5 signal_phase=1.484
#  ch5: local_amp=1131.6 local_phase=0.191  peer_amp=1176.0 peer_phase=0.994  signal_amp=1330824.5 signal_phase=1.186
#  ch8: local_amp=1131.7 local_phase=0.571  peer_amp=1174.5 peer_phase=0.346  signal_amp=1329224.9 signal_phase=0.917
#  ch11: local_amp=1131.4 local_phase=-1.007  peer_amp=1176.5 peer_phase=1.601  signal_amp=1331061.0 signal_phase=0.594
#  ch14: local_amp=1131.8 local_phase=-2.311  peer_amp=1175.8 peer_phase=2.570  signal_amp=1330872.7 signal_phase=0.260
#  ch17: local_amp=1132.5 local_phase=0.563  peer_amp=1174.7 peer_phase=-0.601  signal_amp=1330329.7 signal_phase=-0.038
#  ch20: local_amp=1131.5 local_phase=-0.407  peer_amp=1177.2 peer_phase=0.094  signal_amp=1332017.4 signal_phase=-0.313
#  ch26: local_amp=1131.9 local_phase=0.592  peer_amp=1175.7 peer_phase=-1.606  signal_amp=1330764.6 signal_phase=-1.013
#  ch29: local_amp=1131.7 local_phase=-2.890  peer_amp=1176.0 peer_phase=1.612  signal_amp=1330854.0 signal_phase=-1.278
#  ch32: local_amp=1132.6 local_phase=2.839  peer_amp=1175.0 peer_phase=1.790  signal_amp=1330820.9 signal_phase=-1.655
#  ch35: local_amp=1132.9 local_phase=-2.889  peer_amp=1175.6 peer_phase=0.908  signal_amp=1331866.6 signal_phase=-1.981
#  ch38: local_amp=1134.5 local_phase=-2.335  peer_amp=1175.2 peer_phase=0.094  signal_amp=1333164.5 signal_phase=-2.241
#  ch41: local_amp=1131.8 local_phase=1.533  peer_amp=1176.2 peer_phase=2.027  signal_amp=1331249.8 signal_phase=-2.724
#  ch44: local_amp=1133.3 local_phase=2.075  peer_amp=1174.4 peer_phase=1.185  signal_amp=1330895.3 signal_phase=-3.023
#  ch47: local_amp=1132.2 local_phase=-0.215  peer_amp=1176.1 peer_phase=-3.069  signal_amp=1331513.0 signal_phase=2.999
#  ch50: local_amp=1131.7 local_phase=0.949  peer_amp=1174.5 peer_phase=1.705  signal_amp=1329194.1 signal_phase=2.654
# Counter 28:
#  ch2: local_amp=1133.4 local_phase=-2.016  peer_amp=1173.3 peer_phase=-2.723  signal_amp=1329897.0 signal_phase=1.544
#  ch5: local_amp=1132.1 local_phase=1.782  peer_amp=1175.8 peer_phase=-0.599  signal_amp=1331060.3 signal_phase=1.183
#  ch8: local_amp=1130.3 local_phase=-0.122  peer_amp=1176.0 peer_phase=0.982  signal_amp=1329231.9 signal_phase=0.861
#  ch11: local_amp=1131.9 local_phase=1.716  peer_amp=1174.9 peer_phase=-1.181  signal_amp=1329966.1 signal_phase=0.535
#  ch14: local_amp=1131.8 local_phase=1.534  peer_amp=1176.2 peer_phase=-1.263  signal_amp=1331165.7 signal_phase=0.270
#  ch17: local_amp=1130.2 local_phase=0.017  peer_amp=1174.5 peer_phase=-0.028  signal_amp=1327331.6 signal_phase=-0.011
#  ch20: local_amp=1132.7 local_phase=2.160  peer_amp=1176.6 peer_phase=-2.466  signal_amp=1332748.2 signal_phase=-0.306
#  ch26: local_amp=1132.4 local_phase=-2.665  peer_amp=1174.8 peer_phase=1.686  signal_amp=1330378.8 signal_phase=-0.979
#  ch29: local_amp=1133.7 local_phase=-0.466  peer_amp=1174.7 peer_phase=-0.865  signal_amp=1331724.7 signal_phase=-1.331
#  ch32: local_amp=1134.9 local_phase=-2.945  peer_amp=1175.2 peer_phase=1.340  signal_amp=1333763.9 signal_phase=-1.605
#  ch35: local_amp=1134.6 local_phase=-0.300  peer_amp=1176.1 peer_phase=-1.737  signal_amp=1334396.3 signal_phase=-2.036
#  ch38: local_amp=1133.8 local_phase=2.334  peer_amp=1176.2 peer_phase=1.664  signal_amp=1333480.4 signal_phase=-2.284
#  ch41: local_amp=1134.2 local_phase=1.524  peer_amp=1176.0 peer_phase=2.069  signal_amp=1333844.3 signal_phase=-2.690
#  ch44: local_amp=1131.5 local_phase=1.350  peer_amp=1176.1 peer_phase=1.902  signal_amp=1330782.1 signal_phase=-3.031
#  ch47: local_amp=1132.1 local_phase=1.755  peer_amp=1174.6 peer_phase=1.182  signal_amp=1329703.9 signal_phase=2.937
#  ch50: local_amp=1132.9 local_phase=-0.157  peer_amp=1174.4 peer_phase=2.781  signal_amp=1330483.2 signal_phase=2.624
# Counter 30:
#  ch2: local_amp=1130.0 local_phase=-0.008  peer_amp=1172.6 peer_phase=1.392  signal_amp=1325074.8 signal_phase=1.385
#  ch5: local_amp=1133.5 local_phase=-1.128  peer_amp=1176.2 peer_phase=2.262  signal_amp=1333143.4 signal_phase=1.135
#  ch8: local_amp=1132.8 local_phase=2.037  peer_amp=1175.3 peer_phase=-1.199  signal_amp=1331385.7 signal_phase=0.838
#  ch11: local_amp=1132.4 local_phase=-1.254  peer_amp=1175.9 peer_phase=1.707  signal_amp=1331658.4 signal_phase=0.453
#  ch14: local_amp=1132.5 local_phase=-1.867  peer_amp=1176.4 peer_phase=2.223  signal_amp=1332267.9 signal_phase=0.356
#  ch17: local_amp=1131.9 local_phase=-1.066  peer_amp=1174.9 peer_phase=0.950  signal_amp=1329934.1 signal_phase=-0.116
#  ch20: local_amp=1131.9 local_phase=-2.869  peer_amp=1175.9 peer_phase=2.448  signal_amp=1330953.5 signal_phase=-0.421
#  ch26: local_amp=1132.3 local_phase=-1.293  peer_amp=1176.1 peer_phase=0.316  signal_amp=1331625.3 signal_phase=-0.978
#  ch29: local_amp=1131.9 local_phase=-0.958  peer_amp=1174.4 peer_phase=-0.425  signal_amp=1329315.9 signal_phase=-1.383
#  ch32: local_amp=1133.4 local_phase=-0.602  peer_amp=1176.5 peer_phase=-1.054  signal_amp=1333375.9 signal_phase=-1.656
#  ch35: local_amp=1134.8 local_phase=-1.433  peer_amp=1176.3 peer_phase=-0.613  signal_amp=1334878.7 signal_phase=-2.046
#  ch38: local_amp=1133.2 local_phase=-2.740  peer_amp=1173.9 peer_phase=0.403  signal_amp=1330220.7 signal_phase=-2.337
#  ch41: local_amp=1131.8 local_phase=2.611  peer_amp=1175.2 peer_phase=0.969  signal_amp=1330100.8 signal_phase=-2.703
#  ch44: local_amp=1133.5 local_phase=-2.744  peer_amp=1176.0 peer_phase=-0.299  signal_amp=1333012.3 signal_phase=-3.043
#  ch47: local_amp=1130.8 local_phase=0.486  peer_amp=1176.2 peer_phase=2.410  signal_amp=1330073.9 signal_phase=2.896
#  ch50: local_amp=1131.7 local_phase=-0.968  peer_amp=1177.3 peer_phase=-2.763  signal_amp=1332385.2 signal_phase=2.552
# Counter 32:
#  ch2: local_amp=1133.5 local_phase=-0.653  peer_amp=1173.6 peer_phase=2.248  signal_amp=1330277.8 signal_phase=1.594
#  ch5: local_amp=1132.5 local_phase=-0.906  peer_amp=1176.3 peer_phase=2.203  signal_amp=1332094.4 signal_phase=1.297
#  ch8: local_amp=1132.0 local_phase=0.383  peer_amp=1175.0 peer_phase=0.623  signal_amp=1330144.5 signal_phase=1.006
#  ch11: local_amp=1131.4 local_phase=-0.384  peer_amp=1173.8 peer_phase=1.005  signal_amp=1328054.2 signal_phase=0.621
#  ch14: local_amp=1133.6 local_phase=2.061  peer_amp=1176.1 peer_phase=-1.630  signal_amp=1333265.5 signal_phase=0.431
#  ch17: local_amp=1130.3 local_phase=1.277  peer_amp=1174.7 peer_phase=-1.210  signal_amp=1327853.3 signal_phase=0.068
#  ch20: local_amp=1132.1 local_phase=0.776  peer_amp=1175.5 peer_phase=-1.009  signal_amp=1330864.6 signal_phase=-0.233
#  ch26: local_amp=1131.5 local_phase=-1.111  peer_amp=1174.5 peer_phase=0.221  signal_amp=1328857.8 signal_phase=-0.890
#  ch29: local_amp=1132.6 local_phase=1.731  peer_amp=1175.9 peer_phase=-2.874  signal_amp=1331742.9 signal_phase=-1.143
#  ch32: local_amp=1131.6 local_phase=-0.566  peer_amp=1175.8 peer_phase=-0.894  signal_amp=1330550.3 signal_phase=-1.461
#  ch35: local_amp=1133.8 local_phase=-3.004  peer_amp=1176.2 peer_phase=1.107  signal_amp=1333524.1 signal_phase=-1.896
#  ch38: local_amp=1132.6 local_phase=2.723  peer_amp=1174.8 peer_phase=1.365  signal_amp=1330573.9 signal_phase=-2.195
#  ch41: local_amp=1133.0 local_phase=0.373  peer_amp=1178.0 peer_phase=-2.916  signal_amp=1334584.2 signal_phase=-2.542
#  ch44: local_amp=1134.2 local_phase=1.364  peer_amp=1176.2 peer_phase=1.995  signal_amp=1334032.2 signal_phase=-2.924
#  ch47: local_amp=1132.4 local_phase=2.524  peer_amp=1174.8 peer_phase=0.469  signal_amp=1330362.9 signal_phase=2.993
#  ch50: local_amp=1133.0 local_phase=-2.168  peer_amp=1176.0 peer_phase=-1.462  signal_amp=1332418.5 signal_phase=2.654
# Counter 34:
#  ch2: local_amp=1132.6 local_phase=0.291  peer_amp=1174.2 peer_phase=1.239  signal_amp=1329954.7 signal_phase=1.530
#  ch5: local_amp=1133.2 local_phase=2.517  peer_amp=1176.4 peer_phase=-1.339  signal_amp=1333094.0 signal_phase=1.177
#  ch8: local_amp=1132.2 local_phase=1.765  peer_amp=1175.5 peer_phase=-0.950  signal_amp=1330880.6 signal_phase=0.815
#  ch11: local_amp=1132.9 local_phase=-2.689  peer_amp=1175.7 peer_phase=-3.043  signal_amp=1331952.1 signal_phase=0.551
#  ch14: local_amp=1132.6 local_phase=-1.127  peer_amp=1175.9 peer_phase=1.391  signal_amp=1331798.3 signal_phase=0.264
#  ch17: local_amp=1133.3 local_phase=1.835  peer_amp=1178.0 peer_phase=-1.889  signal_amp=1335023.0 signal_phase=-0.053
#  ch20: local_amp=1133.0 local_phase=-0.442  peer_amp=1174.4 peer_phase=0.096  signal_amp=1330600.0 signal_phase=-0.347
#  ch26: local_amp=1132.9 local_phase=1.877  peer_amp=1176.1 peer_phase=-2.807  signal_amp=1332403.6 signal_phase=-0.930
#  ch29: local_amp=1132.7 local_phase=-1.440  peer_amp=1176.2 peer_phase=0.155  signal_amp=1332256.3 signal_phase=-1.284
#  ch32: local_amp=1131.2 local_phase=0.170  peer_amp=1175.6 peer_phase=-1.807  signal_amp=1329905.4 signal_phase=-1.637
#  ch35: local_amp=1134.6 local_phase=-1.463  peer_amp=1176.0 peer_phase=-0.523  signal_amp=1334241.9 signal_phase=-1.986
#  ch38: local_amp=1133.9 local_phase=-1.445  peer_amp=1176.4 peer_phase=-0.830  signal_amp=1333923.5 signal_phase=-2.275
#  ch41: local_amp=1132.6 local_phase=0.054  peer_amp=1177.0 peer_phase=-2.813  signal_amp=1333154.0 signal_phase=-2.759
#  ch44: local_amp=1135.1 local_phase=-1.690  peer_amp=1175.7 peer_phase=-1.397  signal_amp=1334439.3 signal_phase=-3.087
#  ch47: local_amp=1134.7 local_phase=-1.640  peer_amp=1176.1 peer_phase=-1.761  signal_amp=1334549.1 signal_phase=2.883
#  ch50: local_amp=1133.2 local_phase=1.828  peer_amp=1174.6 peer_phase=0.796  signal_amp=1331027.3 signal_phase=2.623
# Counter 36:
#  ch2: local_amp=1132.3 local_phase=-1.619  peer_amp=1175.9 peer_phase=-3.103  signal_amp=1331414.2 signal_phase=1.561
#  ch5: local_amp=1132.3 local_phase=-1.507  peer_amp=1177.6 peer_phase=2.734  signal_amp=1333342.3 signal_phase=1.227
#  ch8: local_amp=1131.3 local_phase=1.185  peer_amp=1175.6 peer_phase=-0.243  signal_amp=1329893.8 signal_phase=0.942
#  ch11: local_amp=1131.0 local_phase=0.395  peer_amp=1174.8 peer_phase=0.210  signal_amp=1328733.0 signal_phase=0.605
#  ch14: local_amp=1130.6 local_phase=0.365  peer_amp=1176.0 peer_phase=0.003  signal_amp=1329643.0 signal_phase=0.369
#  ch17: local_amp=1131.1 local_phase=-1.397  peer_amp=1175.7 peer_phase=1.338  signal_amp=1329802.2 signal_phase=-0.058
#  ch20: local_amp=1132.3 local_phase=-0.290  peer_amp=1176.3 peer_phase=-0.104  signal_amp=1332024.5 signal_phase=-0.394
#  ch26: local_amp=1133.6 local_phase=2.498  peer_amp=1177.2 peer_phase=2.799  signal_amp=1334525.1 signal_phase=-0.985
#  ch29: local_amp=1131.0 local_phase=-1.569  peer_amp=1175.6 peer_phase=0.267  signal_amp=1329615.6 signal_phase=-1.302
#  ch32: local_amp=1131.2 local_phase=0.128  peer_amp=1176.7 peer_phase=-1.776  signal_amp=1331125.4 signal_phase=-1.649
#  ch35: local_amp=1133.2 local_phase=-0.408  peer_amp=1177.6 peer_phase=-1.602  signal_amp=1334413.3 signal_phase=-2.011
#  ch38: local_amp=1133.5 local_phase=2.262  peer_amp=1176.6 peer_phase=1.692  signal_amp=1333694.9 signal_phase=-2.329
#  ch41: local_amp=1133.2 local_phase=-1.377  peer_amp=1176.4 peer_phase=-1.384  signal_amp=1333030.5 signal_phase=-2.762
#  ch44: local_amp=1133.5 local_phase=-3.111  peer_amp=1176.7 peer_phase=0.067  signal_amp=1333786.1 signal_phase=-3.044
#  ch47: local_amp=1133.9 local_phase=-1.963  peer_amp=1178.0 peer_phase=-1.386  signal_amp=1335736.5 signal_phase=2.934
#  ch50: local_amp=1132.7 local_phase=1.316  peer_amp=1177.2 peer_phase=1.293  signal_amp=1333393.3 signal_phase=2.608
# Counter 38:
#  ch2: local_amp=1132.7 local_phase=0.321  peer_amp=1174.8 peer_phase=1.273  signal_amp=1330729.0 signal_phase=1.593
#  ch5: local_amp=1132.3 local_phase=-2.930  peer_amp=1176.1 peer_phase=-2.141  signal_amp=1331747.5 signal_phase=1.212
#  ch8: local_amp=1130.5 local_phase=0.416  peer_amp=1172.9 peer_phase=0.596  signal_amp=1326003.6 signal_phase=1.012
#  ch11: local_amp=1132.6 local_phase=-2.327  peer_amp=1176.7 peer_phase=3.035  signal_amp=1332642.9 signal_phase=0.708
#  ch14: local_amp=1133.5 local_phase=-0.136  peer_amp=1175.3 peer_phase=0.542  signal_amp=1332192.6 signal_phase=0.405
#  ch17: local_amp=1133.4 local_phase=2.220  peer_amp=1176.0 peer_phase=-2.169  signal_amp=1332923.4 signal_phase=0.051
#  ch20: local_amp=1130.9 local_phase=0.402  peer_amp=1177.5 peer_phase=-0.633  signal_amp=1331645.9 signal_phase=-0.232
#  ch26: local_amp=1132.4 local_phase=-2.894  peer_amp=1175.6 peer_phase=1.975  signal_amp=1331236.5 signal_phase=-0.920
#  ch29: local_amp=1133.0 local_phase=-0.430  peer_amp=1176.3 peer_phase=-0.731  signal_amp=1332706.4 signal_phase=-1.160
#  ch32: local_amp=1132.8 local_phase=-2.489  peer_amp=1175.5 peer_phase=0.967  signal_amp=1331716.8 signal_phase=-1.521
#  ch35: local_amp=1133.6 local_phase=-2.183  peer_amp=1177.5 peer_phase=0.305  signal_amp=1334751.3 signal_phase=-1.877
#  ch38: local_amp=1135.1 local_phase=-0.061  peer_amp=1175.7 peer_phase=-2.158  signal_amp=1334522.3 signal_phase=-2.218
#  ch41: local_amp=1133.9 local_phase=-2.112  peer_amp=1176.7 peer_phase=-0.474  signal_amp=1334296.0 signal_phase=-2.586
#  ch44: local_amp=1133.2 local_phase=-3.021  peer_amp=1176.3 peer_phase=0.181  signal_amp=1332929.4 signal_phase=-2.840
#  ch47: local_amp=1133.1 local_phase=-2.107  peer_amp=1176.3 peer_phase=-1.170  signal_amp=1332812.5 signal_phase=3.006
#  ch50: local_amp=1133.8 local_phase=-2.445  peer_amp=1175.9 peer_phase=-1.091  signal_amp=1333176.7 signal_phase=2.747
# Counter 40:
#  ch2: local_amp=1132.1 local_phase=-1.711  peer_amp=1176.2 peer_phase=-2.997  signal_amp=1331557.5 signal_phase=1.575
#  ch5: local_amp=1131.0 local_phase=0.590  peer_amp=1176.1 peer_phase=0.659  signal_amp=1330253.4 signal_phase=1.249
#  ch8: local_amp=1130.5 local_phase=2.199  peer_amp=1174.7 peer_phase=-1.288  signal_amp=1328068.6 signal_phase=0.911
#  ch11: local_amp=1131.5 local_phase=0.331  peer_amp=1176.1 peer_phase=0.275  signal_amp=1330761.0 signal_phase=0.606
#  ch14: local_amp=1131.5 local_phase=-2.074  peer_amp=1175.6 peer_phase=2.437  signal_amp=1330094.6 signal_phase=0.363
#  ch17: local_amp=1130.5 local_phase=-1.600  peer_amp=1175.3 peer_phase=1.594  signal_amp=1328666.7 signal_phase=-0.006
#  ch20: local_amp=1130.4 local_phase=1.071  peer_amp=1175.8 peer_phase=-1.435  signal_amp=1329136.9 signal_phase=-0.364
#  ch26: local_amp=1131.5 local_phase=-1.338  peer_amp=1175.8 peer_phase=0.470  signal_amp=1330379.0 signal_phase=-0.868
#  ch29: local_amp=1131.5 local_phase=3.090  peer_amp=1175.5 peer_phase=1.983  signal_amp=1330049.0 signal_phase=-1.210
#  ch32: local_amp=1131.6 local_phase=-0.984  peer_amp=1177.0 peer_phase=-0.546  signal_amp=1331893.4 signal_phase=-1.529
#  ch35: local_amp=1133.2 local_phase=-1.729  peer_amp=1176.3 peer_phase=-0.167  signal_amp=1332986.9 signal_phase=-1.896
#  ch38: local_amp=1131.5 local_phase=0.474  peer_amp=1174.7 peer_phase=-2.755  signal_amp=1329214.8 signal_phase=-2.281
#  ch41: local_amp=1133.4 local_phase=-1.355  peer_amp=1176.4 peer_phase=-1.336  signal_amp=1333230.6 signal_phase=-2.690
#  ch44: local_amp=1132.8 local_phase=1.353  peer_amp=1177.3 peer_phase=1.926  signal_amp=1333688.2 signal_phase=-3.005
#  ch47: local_amp=1131.7 local_phase=-0.429  peer_amp=1174.7 peer_phase=-2.928  signal_amp=1329368.1 signal_phase=2.926
#  ch50: local_amp=1131.6 local_phase=1.800  peer_amp=1174.7 peer_phase=0.957  signal_amp=1329260.8 signal_phase=2.756
# Counter 42:
#  ch2: local_amp=1132.0 local_phase=3.099  peer_amp=1176.0 peer_phase=-1.564  signal_amp=1331284.1 signal_phase=1.535
#  ch5: local_amp=1131.9 local_phase=-2.685  peer_amp=1175.0 peer_phase=-2.386  signal_amp=1330030.7 signal_phase=1.212
#  ch8: local_amp=1130.8 local_phase=3.041  peer_amp=1175.6 peer_phase=-2.206  signal_amp=1329363.6 signal_phase=0.834
#  ch11: local_amp=1131.3 local_phase=-1.359  peer_amp=1177.4 peer_phase=1.900  signal_amp=1331958.9 signal_phase=0.541
#  ch14: local_amp=1133.7 local_phase=2.824  peer_amp=1176.3 peer_phase=-2.509  signal_amp=1333528.6 signal_phase=0.315
#  ch17: local_amp=1132.6 local_phase=-2.642  peer_amp=1176.0 peer_phase=2.556  signal_amp=1331954.1 signal_phase=-0.086
#  ch20: local_amp=1129.3 local_phase=0.495  peer_amp=1177.8 peer_phase=-0.875  signal_amp=1330110.1 signal_phase=-0.380
#  ch26: local_amp=1132.4 local_phase=-0.651  peer_amp=1175.6 peer_phase=-0.306  signal_amp=1331246.6 signal_phase=-0.957
#  ch29: local_amp=1133.3 local_phase=0.549  peer_amp=1175.8 peer_phase=-1.902  signal_amp=1332516.6 signal_phase=-1.353
#  ch32: local_amp=1131.2 local_phase=-0.311  peer_amp=1175.2 peer_phase=-1.302  signal_amp=1329372.8 signal_phase=-1.613
#  ch35: local_amp=1131.3 local_phase=-0.087  peer_amp=1175.7 peer_phase=-1.939  signal_amp=1330046.4 signal_phase=-2.026
#  ch38: local_amp=1132.4 local_phase=0.682  peer_amp=1176.2 peer_phase=-3.031  signal_amp=1331991.6 signal_phase=-2.349
#  ch41: local_amp=1133.1 local_phase=-1.528  peer_amp=1178.0 peer_phase=-1.169  signal_amp=1334693.2 signal_phase=-2.696
#  ch44: local_amp=1133.4 local_phase=1.009  peer_amp=1175.2 peer_phase=2.252  signal_amp=1331956.2 signal_phase=-3.023
#  ch47: local_amp=1132.9 local_phase=-0.570  peer_amp=1175.4 peer_phase=-2.820  signal_amp=1331618.6 signal_phase=2.894
#  ch50: local_amp=1132.7 local_phase=3.106  peer_amp=1174.2 peer_phase=-0.499  signal_amp=1330052.6 signal_phase=2.607
# Counter 44:
#  ch2: local_amp=1132.2 local_phase=-2.899  peer_amp=1175.7 peer_phase=-1.888  signal_amp=1331131.6 signal_phase=1.496
#  ch5: local_amp=1130.9 local_phase=-1.207  peer_amp=1176.1 peer_phase=2.375  signal_amp=1330034.8 signal_phase=1.167
#  ch8: local_amp=1129.4 local_phase=0.919  peer_amp=1173.5 peer_phase=-0.050  signal_amp=1325376.9 signal_phase=0.869
#  ch11: local_amp=1130.9 local_phase=1.682  peer_amp=1175.5 peer_phase=-1.140  signal_amp=1329361.5 signal_phase=0.542
#  ch14: local_amp=1131.0 local_phase=0.463  peer_amp=1174.5 peer_phase=-0.146  signal_amp=1328380.4 signal_phase=0.317
#  ch17: local_amp=1129.9 local_phase=0.591  peer_amp=1175.2 peer_phase=-0.563  signal_amp=1327928.5 signal_phase=0.029
#  ch20: local_amp=1130.3 local_phase=1.676  peer_amp=1177.3 peer_phase=-2.015  signal_amp=1330666.3 signal_phase=-0.339
#  ch26: local_amp=1132.0 local_phase=0.686  peer_amp=1176.5 peer_phase=-1.658  signal_amp=1331838.9 signal_phase=-0.973
#  ch29: local_amp=1130.8 local_phase=0.403  peer_amp=1176.3 peer_phase=-1.727  signal_amp=1330198.9 signal_phase=-1.324
#  ch32: local_amp=1132.4 local_phase=-2.674  peer_amp=1175.4 peer_phase=0.986  signal_amp=1330983.8 signal_phase=-1.689
#  ch35: local_amp=1133.4 local_phase=-2.966  peer_amp=1175.4 peer_phase=0.953  signal_amp=1332212.4 signal_phase=-2.013
#  ch38: local_amp=1132.2 local_phase=1.436  peer_amp=1175.6 peer_phase=2.497  signal_amp=1331072.3 signal_phase=-2.350
#  ch41: local_amp=1132.4 local_phase=-1.209  peer_amp=1175.7 peer_phase=-1.442  signal_amp=1331379.5 signal_phase=-2.651
#  ch44: local_amp=1133.0 local_phase=-3.135  peer_amp=1176.2 peer_phase=0.095  signal_amp=1332723.5 signal_phase=-3.040
#  ch47: local_amp=1131.7 local_phase=1.218  peer_amp=1176.2 peer_phase=1.674  signal_amp=1331140.7 signal_phase=2.892
#  ch50: local_amp=1131.2 local_phase=2.130  peer_amp=1175.4 peer_phase=0.504  signal_amp=1329599.4 signal_phase=2.634
# Counter 46:
#  ch2: local_amp=1130.1 local_phase=1.360  peer_amp=1173.9 peer_phase=0.175  signal_amp=1326616.8 signal_phase=1.534
#  ch5: local_amp=1132.4 local_phase=-2.994  peer_amp=1177.1 peer_phase=-2.038  signal_amp=1332896.4 signal_phase=1.252
#  ch8: local_amp=1129.4 local_phase=1.936  peer_amp=1174.9 peer_phase=-1.007  signal_amp=1326895.3 signal_phase=0.929
#  ch11: local_amp=1130.0 local_phase=-1.578  peer_amp=1175.5 peer_phase=2.132  signal_amp=1328396.7 signal_phase=0.554
#  ch14: local_amp=1131.4 local_phase=2.345  peer_amp=1176.2 peer_phase=-2.023  signal_amp=1330857.2 signal_phase=0.322
#  ch17: local_amp=1128.0 local_phase=0.677  peer_amp=1175.0 peer_phase=-0.740  signal_amp=1325485.4 signal_phase=-0.062
#  ch20: local_amp=1131.7 local_phase=-1.702  peer_amp=1176.8 peer_phase=1.361  signal_amp=1331791.5 signal_phase=-0.341
#  ch26: local_amp=1130.0 local_phase=-0.735  peer_amp=1176.1 peer_phase=-0.245  signal_amp=1328894.6 signal_phase=-0.980
#  ch29: local_amp=1130.7 local_phase=-0.797  peer_amp=1174.4 peer_phase=-0.466  signal_amp=1327930.6 signal_phase=-1.264
#  ch32: local_amp=1130.4 local_phase=-2.657  peer_amp=1175.0 peer_phase=1.050  signal_amp=1328162.2 signal_phase=-1.607
#  ch35: local_amp=1129.1 local_phase=0.687  peer_amp=1176.6 peer_phase=-2.681  signal_amp=1328484.0 signal_phase=-1.994
#  ch38: local_amp=1131.4 local_phase=-1.795  peer_amp=1175.9 peer_phase=-0.528  signal_amp=1330427.7 signal_phase=-2.323
#  ch41: local_amp=1131.0 local_phase=2.650  peer_amp=1174.3 peer_phase=0.975  signal_amp=1328176.1 signal_phase=-2.658
#  ch44: local_amp=1130.8 local_phase=0.318  peer_amp=1176.5 peer_phase=2.990  signal_amp=1330478.0 signal_phase=-2.975
#  ch47: local_amp=1134.0 local_phase=-2.606  peer_amp=1176.8 peer_phase=-0.680  signal_amp=1334428.5 signal_phase=2.997
#  ch50: local_amp=1131.2 local_phase=-1.591  peer_amp=1175.6 peer_phase=-2.060  signal_amp=1329932.7 signal_phase=2.633
# Counter 48:
#  ch2: local_amp=1130.8 local_phase=1.141  peer_amp=1174.5 peer_phase=0.478  signal_amp=1328080.6 signal_phase=1.619
#  ch5: local_amp=1131.6 local_phase=-0.826  peer_amp=1176.9 peer_phase=2.133  signal_amp=1331801.9 signal_phase=1.307
#  ch8: local_amp=1130.9 local_phase=-0.058  peer_amp=1175.1 peer_phase=1.087  signal_amp=1328928.4 signal_phase=1.028
#  ch11: local_amp=1132.4 local_phase=-2.947  peer_amp=1175.2 peer_phase=-2.750  signal_amp=1330724.5 signal_phase=0.587
#  ch14: local_amp=1131.1 local_phase=-1.022  peer_amp=1176.7 peer_phase=1.481  signal_amp=1330926.3 signal_phase=0.459
#  ch17: local_amp=1130.9 local_phase=-1.344  peer_amp=1176.5 peer_phase=1.371  signal_amp=1330502.3 signal_phase=0.026
#  ch20: local_amp=1130.4 local_phase=0.728  peer_amp=1177.0 peer_phase=-0.922  signal_amp=1330516.7 signal_phase=-0.194
#  ch26: local_amp=1131.3 local_phase=0.105  peer_amp=1176.3 peer_phase=-0.996  signal_amp=1330762.3 signal_phase=-0.890
#  ch29: local_amp=1132.4 local_phase=2.735  peer_amp=1176.9 peer_phase=2.378  signal_amp=1332709.3 signal_phase=-1.171
#  ch32: local_amp=1130.0 local_phase=1.332  peer_amp=1176.0 peer_phase=-2.843  signal_amp=1328932.1 signal_phase=-1.511
#  ch35: local_amp=1133.7 local_phase=-2.374  peer_amp=1175.6 peer_phase=0.517  signal_amp=1332756.1 signal_phase=-1.857
#  ch38: local_amp=1132.4 local_phase=0.809  peer_amp=1175.9 peer_phase=-3.019  signal_amp=1331510.2 signal_phase=-2.210
#  ch41: local_amp=1132.7 local_phase=-0.182  peer_amp=1177.7 peer_phase=-2.521  signal_amp=1333992.5 signal_phase=-2.703
#  ch44: local_amp=1132.2 local_phase=2.373  peer_amp=1175.2 peer_phase=0.928  signal_amp=1330608.1 signal_phase=-2.982
#  ch47: local_amp=1132.4 local_phase=-1.227  peer_amp=1177.4 peer_phase=-1.989  signal_amp=1333256.7 signal_phase=3.068
#  ch50: local_amp=1132.5 local_phase=1.928  peer_amp=1176.2 peer_phase=0.891  signal_amp=1331988.1 signal_phase=2.819
# Counter 50:
#  ch2: local_amp=1130.4 local_phase=1.429  peer_amp=1174.3 peer_phase=0.172  signal_amp=1327439.8 signal_phase=1.601
#  ch5: local_amp=1130.9 local_phase=-2.438  peer_amp=1177.2 peer_phase=-2.567  signal_amp=1331233.9 signal_phase=1.279
# ...
#  ch35: local_amp=1133.7 local_phase=-1.687  peer_amp=1174.9 peer_phase=-0.222  signal_amp=1332000.1 signal_phase=-1.910
#  ch38: local_amp=1135.3 local_phase=2.855  peer_amp=1175.1 peer_phase=1.127  signal_amp=1334064.9 signal_phase=-2.302
#  ch41: local_amp=1134.6 local_phase=2.816  peer_amp=1175.2 peer_phase=0.793  signal_amp=1333469.5 signal_phase=-2.675
#  ch44: local_amp=1133.9 local_phase=2.204  peer_amp=1174.9 peer_phase=1.115  signal_amp=1332134.7 signal_phase=-2.964
#  ch47: local_amp=1133.2 local_phase=-2.414  peer_amp=1176.2 peer_phase=-0.922  signal_amp=1332937.4 signal_phase=2.948
#  ch50: local_amp=1132.0 local_phase=0.361  peer_amp=1176.0 peer_phase=2.365  signal_amp=1331223.6 signal_phase=2.726
# Counter 60:
#  ch2: local_amp=1132.6 local_phase=-2.591  peer_amp=1175.7 peer_phase=-2.180  signal_amp=1331623.3 signal_phase=1.512
#  ch5: local_amp=1131.6 local_phase=0.481  peer_amp=1175.2 peer_phase=0.784  signal_amp=1329904.8 signal_phase=1.266
#  ch8: local_amp=1131.5 local_phase=2.672  peer_amp=1176.3 peer_phase=-1.775  signal_amp=1330980.4 signal_phase=0.897
#  ch11: local_amp=1132.8 local_phase=-2.807  peer_amp=1177.9 peer_phase=-2.852  signal_amp=1334392.8 signal_phase=0.624
#  ch14: local_amp=1131.6 local_phase=0.306  peer_amp=1176.6 peer_phase=0.031  signal_amp=1331421.9 signal_phase=0.338
#  ch17: local_amp=1134.1 local_phase=-0.045  peer_amp=1175.0 peer_phase=-0.003  signal_amp=1332630.7 signal_phase=-0.048
#  ch20: local_amp=1133.5 local_phase=1.957  peer_amp=1177.6 peer_phase=-2.234  signal_amp=1334845.5 signal_phase=-0.277
#  ch26: local_amp=1133.8 local_phase=-1.965  peer_amp=1176.2 peer_phase=1.077  signal_amp=1333587.6 signal_phase=-0.887
#  ch29: local_amp=1133.3 local_phase=-1.699  peer_amp=1175.5 peer_phase=0.388  signal_amp=1332195.7 signal_phase=-1.311
#  ch32: local_amp=1133.5 local_phase=0.986  peer_amp=1175.8 peer_phase=-2.564  signal_amp=1332753.9 signal_phase=-1.578
#  ch35: local_amp=1132.5 local_phase=-0.968  peer_amp=1176.4 peer_phase=-0.965  signal_amp=1332357.9 signal_phase=-1.933
#  ch38: local_amp=1134.3 local_phase=2.049  peer_amp=1176.9 peer_phase=1.953  signal_amp=1334948.0 signal_phase=-2.281
#  ch41: local_amp=1133.0 local_phase=-2.823  peer_amp=1177.2 peer_phase=0.132  signal_amp=1333880.7 signal_phase=-2.691
#  ch44: local_amp=1132.8 local_phase=-3.086  peer_amp=1177.2 peer_phase=0.074  signal_amp=1333498.9 signal_phase=-3.012
#  ch47: local_amp=1134.1 local_phase=-1.580  peer_amp=1175.9 peer_phase=-1.707  signal_amp=1333573.9 signal_phase=2.995
#  ch50: local_amp=1132.9 local_phase=2.086  peer_amp=1176.1 peer_phase=0.562  signal_amp=1332426.8 signal_phase=2.648
# Counter 62:
#  ch2: local_amp=1133.4 local_phase=-1.202  peer_amp=1175.0 peer_phase=2.775  signal_amp=1331723.1 signal_phase=1.574
#  ch5: local_amp=1132.5 local_phase=-2.272  peer_amp=1177.0 peer_phase=-2.788  signal_amp=1332944.4 signal_phase=1.223
#  ch8: local_amp=1131.4 local_phase=1.620  peer_amp=1176.5 peer_phase=-0.619  signal_amp=1331125.0 signal_phase=1.001
#  ch11: local_amp=1132.6 local_phase=2.618  peer_amp=1176.9 peer_phase=-2.056  signal_amp=1332917.2 signal_phase=0.562
#  ch14: local_amp=1132.6 local_phase=2.517  peer_amp=1176.1 peer_phase=-2.125  signal_amp=1332038.2 signal_phase=0.392
#  ch17: local_amp=1132.0 local_phase=-1.673  peer_amp=1175.9 peer_phase=1.679  signal_amp=1331046.6 signal_phase=0.006
#  ch20: local_amp=1132.0 local_phase=1.572  peer_amp=1176.7 peer_phase=-1.885  signal_amp=1332041.3 signal_phase=-0.314
#  ch26: local_amp=1132.1 local_phase=2.463  peer_amp=1177.3 peer_phase=2.942  signal_amp=1332823.2 signal_phase=-0.878
#  ch29: local_amp=1134.2 local_phase=-1.067  peer_amp=1176.5 peer_phase=-0.146  signal_amp=1334349.6 signal_phase=-1.212
#  ch32: local_amp=1131.4 local_phase=-0.576  peer_amp=1175.7 peer_phase=-0.984  signal_amp=1330168.6 signal_phase=-1.560
#  ch35: local_amp=1132.8 local_phase=0.936  peer_amp=1177.7 peer_phase=-2.878  signal_amp=1334166.0 signal_phase=-1.942
#  ch38: local_amp=1131.9 local_phase=-0.906  peer_amp=1175.2 peer_phase=-1.359  signal_amp=1330205.8 signal_phase=-2.265
#  ch41: local_amp=1135.5 local_phase=-2.229  peer_amp=1176.4 peer_phase=-0.379  signal_amp=1335817.1 signal_phase=-2.608
#  ch44: local_amp=1131.6 local_phase=-1.800  peer_amp=1178.0 peer_phase=-1.135  signal_amp=1332966.2 signal_phase=-2.935
#  ch47: local_amp=1133.4 local_phase=2.644  peer_amp=1175.3 peer_phase=0.360  signal_amp=1332169.4 signal_phase=3.004
#  ch50: local_amp=1132.2 local_phase=-0.874  peer_amp=1177.6 peer_phase=-2.668  signal_amp=1333285.3 signal_phase=2.742
# Counter 64:
#  ch2: local_amp=1132.8 local_phase=3.024  peer_amp=1175.3 peer_phase=-1.523  signal_amp=1331459.9 signal_phase=1.501
#  ch5: local_amp=1131.4 local_phase=0.847  peer_amp=1175.2 peer_phase=0.397  signal_amp=1329678.6 signal_phase=1.244
#  ch8: local_amp=1131.4 local_phase=1.731  peer_amp=1175.0 peer_phase=-0.728  signal_amp=1329420.4 signal_phase=1.002
#  ch11: local_amp=1131.9 local_phase=2.064  peer_amp=1176.4 peer_phase=-1.466  signal_amp=1331676.9 signal_phase=0.598
#  ch14: local_amp=1134.0 local_phase=0.260  peer_amp=1175.6 peer_phase=0.106  signal_amp=1333052.4 signal_phase=0.365
#  ch17: local_amp=1133.5 local_phase=0.294  peer_amp=1175.3 peer_phase=-0.246  signal_amp=1332227.5 signal_phase=0.048
#  ch20: local_amp=1133.2 local_phase=2.650  peer_amp=1176.8 peer_phase=-2.901  signal_amp=1333588.8 signal_phase=-0.251
#  ch26: local_amp=1132.9 local_phase=1.119  peer_amp=1176.7 peer_phase=-2.065  signal_amp=1333061.6 signal_phase=-0.946
#  ch29: local_amp=1133.5 local_phase=2.961  peer_amp=1176.9 peer_phase=2.058  signal_amp=1334077.6 signal_phase=-1.265
#  ch32: local_amp=1133.8 local_phase=-0.394  peer_amp=1176.7 peer_phase=-1.215  signal_amp=1334148.4 signal_phase=-1.609
#  ch35: local_amp=1133.5 local_phase=0.692  peer_amp=1177.4 peer_phase=-2.656  signal_amp=1334558.3 signal_phase=-1.964
#  ch38: local_amp=1133.6 local_phase=0.797  peer_amp=1176.6 peer_phase=-3.109  signal_amp=1333776.2 signal_phase=-2.312
#  ch41: local_amp=1133.9 local_phase=-2.660  peer_amp=1176.2 peer_phase=0.020  signal_amp=1333680.3 signal_phase=-2.641
#  ch44: local_amp=1133.9 local_phase=-0.252  peer_amp=1177.0 peer_phase=-2.773  signal_amp=1334606.1 signal_phase=-3.025
#  ch47: local_amp=1132.7 local_phase=-3.025  peer_amp=1175.3 peer_phase=-0.224  signal_amp=1331334.4 signal_phase=3.034
#  ch50: local_amp=1133.5 local_phase=-3.005  peer_amp=1174.9 peer_phase=-0.564  signal_amp=1331781.7 signal_phase=2.714
# Counter 66:
#  ch2: local_amp=1131.7 local_phase=1.357  peer_amp=1173.0 peer_phase=0.198  signal_amp=1327498.5 signal_phase=1.555
#  ch5: local_amp=1134.0 local_phase=1.722  peer_amp=1175.5 peer_phase=-0.508  signal_amp=1333033.0 signal_phase=1.214
#  ch8: local_amp=1132.4 local_phase=0.247  peer_amp=1173.3 peer_phase=0.573  signal_amp=1328675.1 signal_phase=0.820
#  ch11: local_amp=1132.3 local_phase=-0.465  peer_amp=1175.6 peer_phase=1.030  signal_amp=1331212.1 signal_phase=0.565
#  ch14: local_amp=1132.6 local_phase=-1.742  peer_amp=1175.3 peer_phase=2.031  signal_amp=1331086.6 signal_phase=0.289
#  ch17: local_amp=1132.6 local_phase=-2.606  peer_amp=1175.8 peer_phase=2.490  signal_amp=1331741.8 signal_phase=-0.116
#  ch20: local_amp=1134.1 local_phase=-1.561  peer_amp=1175.6 peer_phase=1.189  signal_amp=1333236.4 signal_phase=-0.372
#  ch26: local_amp=1134.7 local_phase=2.151  peer_amp=1176.6 peer_phase=-3.063  signal_amp=1335060.0 signal_phase=-0.912
#  ch29: local_amp=1134.0 local_phase=3.030  peer_amp=1174.7 peer_phase=1.932  signal_amp=1332186.3 signal_phase=-1.321
#  ch32: local_amp=1134.4 local_phase=-2.503  peer_amp=1174.8 peer_phase=0.806  signal_amp=1332670.9 signal_phase=-1.697
#  ch35: local_amp=1134.8 local_phase=-1.534  peer_amp=1175.6 peer_phase=-0.397  signal_amp=1334066.5 signal_phase=-1.931
#  ch38: local_amp=1133.4 local_phase=-0.049  peer_amp=1176.3 peer_phase=-2.329  signal_amp=1333255.5 signal_phase=-2.379
#  ch41: local_amp=1134.8 local_phase=0.818  peer_amp=1176.0 peer_phase=2.743  signal_amp=1334526.8 signal_phase=-2.722
#  ch44: local_amp=1132.3 local_phase=-1.155  peer_amp=1176.9 peer_phase=-1.863  signal_amp=1332604.6 signal_phase=-3.018
#  ch47: local_amp=1131.7 local_phase=-0.237  peer_amp=1175.5 peer_phase=3.054  signal_amp=1330343.1 signal_phase=2.817
#  ch50: local_amp=1133.7 local_phase=0.672  peer_amp=1174.5 peer_phase=1.966  signal_amp=1331450.5 signal_phase=2.638
# Counter 68:
#  ch2: local_amp=1133.5 local_phase=-2.730  peer_amp=1174.7 peer_phase=-2.012  signal_amp=1331439.9 signal_phase=1.540
#  ch5: local_amp=1132.2 local_phase=-0.235  peer_amp=1176.1 peer_phase=1.487  signal_amp=1331579.7 signal_phase=1.252
#  ch8: local_amp=1129.9 local_phase=2.391  peer_amp=1175.4 peer_phase=-1.507  signal_amp=1328101.5 signal_phase=0.884
#  ch11: local_amp=1132.3 local_phase=3.066  peer_amp=1177.2 peer_phase=-2.465  signal_amp=1332953.9 signal_phase=0.600
#  ch14: local_amp=1131.3 local_phase=-1.864  peer_amp=1176.4 peer_phase=2.281  signal_amp=1330867.4 signal_phase=0.417
#  ch17: local_amp=1133.9 local_phase=2.927  peer_amp=1174.7 peer_phase=-2.949  signal_amp=1332055.5 signal_phase=-0.021
#  ch20: local_amp=1131.2 local_phase=-0.287  peer_amp=1176.0 peer_phase=0.007  signal_amp=1330328.0 signal_phase=-0.280
#  ch26: local_amp=1131.8 local_phase=-0.332  peer_amp=1176.8 peer_phase=-0.594  signal_amp=1331971.9 signal_phase=-0.926
#  ch29: local_amp=1132.2 local_phase=0.886  peer_amp=1176.2 peer_phase=-2.102  signal_amp=1331629.4 signal_phase=-1.216
#  ch32: local_amp=1132.8 local_phase=-0.782  peer_amp=1174.3 peer_phase=-0.843  signal_amp=1330291.6 signal_phase=-1.625
#  ch35: local_amp=1134.2 local_phase=0.047  peer_amp=1176.8 peer_phase=-1.992  signal_amp=1334762.2 signal_phase=-1.945
#  ch38: local_amp=1132.9 local_phase=-2.077  peer_amp=1176.1 peer_phase=-0.194  signal_amp=1332430.1 signal_phase=-2.271
#  ch41: local_amp=1134.6 local_phase=-1.385  peer_amp=1176.1 peer_phase=-1.247  signal_amp=1334354.0 signal_phase=-2.632
#  ch44: local_amp=1132.7 local_phase=-0.595  peer_amp=1176.1 peer_phase=-2.436  signal_amp=1332191.2 signal_phase=-3.031
#  ch47: local_amp=1131.6 local_phase=0.217  peer_amp=1175.6 peer_phase=2.702  signal_amp=1330360.2 signal_phase=2.920
#  ch50: local_amp=1132.8 local_phase=2.672  peer_amp=1175.4 peer_phase=0.026  signal_amp=1331520.4 signal_phase=2.698
# Counter 70:
#  ch2: local_amp=1134.1 local_phase=-2.963  peer_amp=1174.0 peer_phase=-1.720  signal_amp=1331435.2 signal_phase=1.601
#  ch5: local_amp=1133.5 local_phase=3.005  peer_amp=1178.3 peer_phase=-1.742  signal_amp=1335581.7 signal_phase=1.263
#  ch8: local_amp=1133.5 local_phase=-1.128  peer_amp=1174.8 peer_phase=2.034  signal_amp=1331644.0 signal_phase=0.906
#  ch11: local_amp=1133.2 local_phase=-0.018  peer_amp=1175.5 peer_phase=0.658  signal_amp=1332078.3 signal_phase=0.640
#  ch14: local_amp=1132.2 local_phase=-0.141  peer_amp=1176.7 peer_phase=0.520  signal_amp=1332303.9 signal_phase=0.379
#  ch17: local_amp=1133.1 local_phase=1.143  peer_amp=1175.3 peer_phase=-1.109  signal_amp=1331680.0 signal_phase=0.034
#  ch20: local_amp=1134.1 local_phase=-2.783  peer_amp=1177.2 peer_phase=2.465  signal_amp=1335141.2 signal_phase=-0.318
#  ch26: local_amp=1132.4 local_phase=0.275  peer_amp=1176.5 peer_phase=-1.178  signal_amp=1332238.5 signal_phase=-0.904
#  ch29: local_amp=1133.0 local_phase=2.213  peer_amp=1175.8 peer_phase=2.894  signal_amp=1332200.4 signal_phase=-1.176
#  ch32: local_amp=1133.4 local_phase=-3.076  peer_amp=1174.3 peer_phase=1.459  signal_amp=1331006.6 signal_phase=-1.617
#  ch35: local_amp=1134.6 local_phase=-2.208  peer_amp=1175.1 peer_phase=0.290  signal_amp=1333252.8 signal_phase=-1.918
#  ch38: local_amp=1133.8 local_phase=2.247  peer_amp=1175.9 peer_phase=1.808  signal_amp=1333207.4 signal_phase=-2.228
#  ch41: local_amp=1134.3 local_phase=2.016  peer_amp=1176.0 peer_phase=1.663  signal_amp=1333945.8 signal_phase=-2.605
#  ch44: local_amp=1135.0 local_phase=-2.757  peer_amp=1176.4 peer_phase=-0.177  signal_amp=1335140.5 signal_phase=-2.934
#  ch47: local_amp=1133.7 local_phase=-1.208  peer_amp=1176.8 peer_phase=-2.110  signal_amp=1334128.8 signal_phase=2.965
#  ch50: local_amp=1133.7 local_phase=1.480  peer_amp=1175.1 peer_phase=1.197  signal_amp=1332205.8 signal_phase=2.677
# Counter 72:
#  ch2: local_amp=1133.7 local_phase=1.245  peer_amp=1173.5 peer_phase=0.270  signal_amp=1330394.5 signal_phase=1.515
#  ch5: local_amp=1131.8 local_phase=0.617  peer_amp=1174.7 peer_phase=0.629  signal_amp=1329545.9 signal_phase=1.246
#  ch8: local_amp=1132.0 local_phase=1.373  peer_amp=1175.9 peer_phase=-0.413  signal_amp=1331084.6 signal_phase=0.960
#  ch11: local_amp=1131.6 local_phase=1.604  peer_amp=1176.6 peer_phase=-0.933  signal_amp=1331504.0 signal_phase=0.672
#  ch14: local_amp=1131.8 local_phase=0.814  peer_amp=1175.2 peer_phase=-0.501  signal_amp=1330118.1 signal_phase=0.314
#  ch17: local_amp=1132.7 local_phase=-1.822  peer_amp=1175.5 peer_phase=1.799  signal_amp=1331440.0 signal_phase=-0.023
#  ch20: local_amp=1131.3 local_phase=1.547  peer_amp=1176.1 peer_phase=-1.905  signal_amp=1330599.0 signal_phase=-0.358
#  ch26: local_amp=1131.2 local_phase=2.130  peer_amp=1176.2 peer_phase=-3.016  signal_amp=1330577.4 signal_phase=-0.886
#  ch29: local_amp=1131.1 local_phase=-0.095  peer_amp=1175.8 peer_phase=-1.096  signal_amp=1329905.1 signal_phase=-1.191
#  ch32: local_amp=1133.2 local_phase=2.280  peer_amp=1176.3 peer_phase=2.488  signal_amp=1332987.5 signal_phase=-1.515
#  ch35: local_amp=1131.2 local_phase=0.708  peer_amp=1175.6 peer_phase=-2.632  signal_amp=1329875.9 signal_phase=-1.923
#  ch38: local_amp=1134.2 local_phase=-3.096  peer_amp=1175.1 peer_phase=0.816  signal_amp=1332742.0 signal_phase=-2.280
#  ch41: local_amp=1134.4 local_phase=-1.746  peer_amp=1175.5 peer_phase=-0.880  signal_amp=1333520.3 signal_phase=-2.626
#  ch44: local_amp=1132.8 local_phase=0.071  peer_amp=1176.6 peer_phase=-3.111  signal_amp=1332830.2 signal_phase=-3.040
#  ch47: local_amp=1132.9 local_phase=0.838  peer_amp=1177.2 peer_phase=2.085  signal_amp=1333715.8 signal_phase=2.923
#  ch50: local_amp=1133.3 local_phase=-1.873  peer_amp=1176.0 peer_phase=-1.730  signal_amp=1332680.0 signal_phase=2.680
# Counter 74:
#  ch2: local_amp=1132.6 local_phase=1.229  peer_amp=1171.6 peer_phase=0.218  signal_amp=1327056.7 signal_phase=1.446
#  ch5: local_amp=1133.2 local_phase=-1.718  peer_amp=1177.3 peer_phase=2.736  signal_amp=1334137.4 signal_phase=1.019
#  ch8: local_amp=1131.7 local_phase=0.124  peer_amp=1175.2 peer_phase=0.676  signal_amp=1329974.7 signal_phase=0.800
#  ch11: local_amp=1131.6 local_phase=2.021  peer_amp=1175.3 peer_phase=-1.475  signal_amp=1329975.7 signal_phase=0.545
#  ch14: local_amp=1133.4 local_phase=1.596  peer_amp=1175.5 peer_phase=-1.398  signal_amp=1332262.2 signal_phase=0.198
#  ch17: local_amp=1131.0 local_phase=0.860  peer_amp=1176.5 peer_phase=-1.047  signal_amp=1330563.4 signal_phase=-0.188
#  ch20: local_amp=1133.1 local_phase=-2.541  peer_amp=1176.3 peer_phase=2.017  signal_amp=1332868.3 signal_phase=-0.524
#  ch26: local_amp=1131.6 local_phase=-0.859  peer_amp=1176.2 peer_phase=-0.176  signal_amp=1330992.3 signal_phase=-1.035
#  ch29: local_amp=1133.8 local_phase=0.910  peer_amp=1175.4 peer_phase=-2.374  signal_amp=1332640.0 signal_phase=-1.464
#  ch32: local_amp=1134.3 local_phase=-3.021  peer_amp=1175.3 peer_phase=1.194  signal_amp=1333119.6 signal_phase=-1.826
#  ch35: local_amp=1132.2 local_phase=1.046  peer_amp=1176.3 peer_phase=-3.119  signal_amp=1331798.9 signal_phase=-2.073
#  ch38: local_amp=1132.8 local_phase=2.031  peer_amp=1176.9 peer_phase=1.848  signal_amp=1333198.3 signal_phase=-2.404
#  ch41: local_amp=1132.4 local_phase=1.027  peer_amp=1175.3 peer_phase=2.482  signal_amp=1330977.3 signal_phase=-2.774
#  ch44: local_amp=1131.9 local_phase=0.958  peer_amp=1175.5 peer_phase=2.132  signal_amp=1330638.2 signal_phase=3.090
#  ch47: local_amp=1132.7 local_phase=-0.687  peer_amp=1176.5 peer_phase=-2.856  signal_amp=1332588.7 signal_phase=2.740
#  ch50: local_amp=1130.2 local_phase=1.552  peer_amp=1174.4 peer_phase=0.969  signal_amp=1327317.3 signal_phase=2.521

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_iq_trend(data_per_counter, channels_to_plot):
    """
    随着counter变化，绘制每个指定channel的local/peer/signal的幅值和相位趋势
    """
    counters = sorted(data_per_counter.keys())
    for ch in channels_to_plot:
        # 针对每个信道，收集各counter下的local/peer/signal幅值和相位
        local_amp, peer_amp, signal_amp = [], [], []
        local_phs, peer_phs, signal_phs = [], [], []
        valid_counters = []
        for counter in counters:
            ch_list = data_per_counter[counter]
            entry = next((e for e in ch_list if e['channel'] == ch), None)
            if entry is not None:
                local_amp.append(entry['local']['amplitude'])
                peer_amp.append(entry['peer']['amplitude'])
                signal_amp.append(entry['signal']['amplitude'])
                local_phs.append(entry['local']['phase'])
                peer_phs.append(entry['peer']['phase'])
                signal_phs.append(entry['signal']['phase'])
                valid_counters.append(counter)
        if not valid_counters:
            print(f"Channel {ch} not found in any counter.")
            continue
        
        # 相位展开
        local_phs = np.unwrap(local_phs)
        peer_phs = np.unwrap(peer_phs)
        signal_phs = np.unwrap(signal_phs)
        
        # 画幅值
        plt.figure(figsize=(10,3))
        plt.plot(valid_counters, local_amp, 'b-o', label='Local amplitude')
        plt.plot(valid_counters, peer_amp, 'g-o', label='Peer amplitude')
        # plt.plot(valid_counters, signal_amp, 'r-o', label='Signal amplitude')
        plt.xlabel('Ranging Counter')
        plt.ylabel('Amplitude')
        plt.title(f'Channel {ch}: Amplitude Trend')
        plt.legend()
        plt.grid()
        plt.tight_layout()
        plt.show()
        
        # 画相位
        plt.figure(figsize=(10,3))
        plt.plot(valid_counters, local_phs, 'b-o', label='Local phase')
        plt.plot(valid_counters, peer_phs, 'g-o', label='Peer phase')
        plt.plot(valid_counters, signal_phs, 'r-o', label='Signal phase')
        plt.xlabel('Ranging Counter')
        plt.ylabel('Unwrapped Phase (rad)')
        plt.title(f'Channel {ch}: Phase Trend')
        plt.legend()
        plt.grid()
        plt.tight_layout()
        plt.show()

# 用法举例
if __name__ == '__main__':
    # 假设 data_per_counter 已经由上面的 parse_and_process_iq 生成
    channels_to_plot = [2, 14, 29, 50]  # 你希望观察的信道号
    plot_iq_trend(data_per_counter, channels_to_plot)

# %% [markdown]
# local,peer,signal 的幅值相位变化。注意signal 的幅值就是peer，乘积的幅值没有实际意义。

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_amplitude_vs_counter(data_per_counter, channels_to_plot):
    """
    幅值随counter变化。每个信道画三条曲线：local/peer/signal的amplitude。
    """
    counters = sorted(data_per_counter.keys())
    plt.figure(figsize=(14, 7))
    for ch in channels_to_plot:
        # 收集数据
        local_amp, peer_amp, signal_amp, valid_counters = [], [], [], []
        for counter in counters:
            entry = next((e for e in data_per_counter[counter] if e['channel'] == ch), None)
            if entry:
                local_amp.append(entry['local']['amplitude'])
                peer_amp.append(entry['peer']['amplitude'])
                signal_amp.append(entry['signal']['amplitude'])
                valid_counters.append(counter)
        if valid_counters:
            plt.plot(valid_counters, local_amp, '-o', label=f'ch{ch} local')
            plt.plot(valid_counters, peer_amp, '--s', label=f'ch{ch} peer')
            # plt.plot(valid_counters, signal_amp, '-.^', label=f'ch{ch} signal')
    plt.xlabel('Ranging Counter')
    plt.ylabel('Amplitude')
    plt.title('Amplitude vs Counter for Each Channel (Local/Peer/Signal)')
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.show()

def plot_phase_vs_counter(data_per_counter, channels_to_plot):
    """
    相位随counter变化。每个信道画三条曲线：local/peer/signal的phase。
    """
    counters = sorted(data_per_counter.keys())
    plt.figure(figsize=(14, 7))
    for ch in channels_to_plot:
        local_phs, peer_phs, signal_phs, valid_counters = [], [], [], []
        for counter in counters:
            entry = next((e for e in data_per_counter[counter] if e['channel'] == ch), None)
            if entry:
                local_phs.append(entry['local']['phase'])
                peer_phs.append(entry['peer']['phase'])
                signal_phs.append(entry['signal']['phase'])
                valid_counters.append(counter)
        if valid_counters:
            # 相位展开
            local_phs = np.unwrap(local_phs)
            peer_phs = np.unwrap(peer_phs)
            signal_phs = np.unwrap(signal_phs)
            plt.plot(valid_counters, local_phs, '-o', label=f'ch{ch} local')
            plt.plot(valid_counters, peer_phs, '--s', label=f'ch{ch} peer')
            plt.plot(valid_counters, signal_phs, '-.^', label=f'ch{ch} signal')
    plt.xlabel('Ranging Counter')
    plt.ylabel('Unwrapped Phase (rad)')
    plt.title('Phase vs Counter for Each Channel (Local/Peer/Signal)')
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.show()

# 用法举例
if __name__ == '__main__':
    # 假设 data_per_counter 已由 parse_and_process_iq 生成
    channels_to_plot = [2, 14, 29, 50]  # 可自由指定
    plot_amplitude_vs_counter(data_per_counter, channels_to_plot)
    plot_phase_vs_counter(data_per_counter, channels_to_plot)

# %% [markdown]
# local,peer,signal 的幅值相位变化。注意signal 的幅值就是peer，乘积的幅值没有实际意义。

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm

def plot_amplitude_vs_counter_pretty(data_per_counter, channels_to_plot):
    """
    更美观的幅值随counter变化图，同一信道同色，local/peer/signal不同线型
    """
    counters = sorted(data_per_counter.keys())
    n_ch = len(channels_to_plot)
    color_map = cm.get_cmap('tab10', n_ch)
    line_styles = {'local': '-o', 'peer': '--s', 'signal': '-.^'}
    labels = {'local': 'local', 'peer': 'peer', 'signal': 'signal'}

    plt.figure(figsize=(14, 7))
    for idx, ch in enumerate(channels_to_plot):
        color = color_map(idx)
        for kind in ['local', 'peer']:
            y, valid_counters = [], []
            for counter in counters:
                entry = next((e for e in data_per_counter[counter] if e['channel'] == ch), None)
                if entry:
                    y.append(entry[kind]['amplitude'])
                    valid_counters.append(counter)
            if valid_counters:
                plt.plot(valid_counters, y, line_styles[kind], color=color,
                         label=f'ch{ch} {labels[kind]}')
    plt.xlabel('Ranging Counter')
    plt.ylabel('Amplitude')
    plt.title('Amplitude vs Counter for Each Channel (Pretty)')
    plt.legend(loc='best', ncol=2)
    plt.grid()
    plt.tight_layout()
    plt.show()

def plot_phase_vs_counter_pretty(data_per_counter, channels_to_plot):
    """
    更美观的相位随counter变化图，同一信道同色，local/peer/signal不同线型
    """
    counters = sorted(data_per_counter.keys())
    n_ch = len(channels_to_plot)
    color_map = cm.get_cmap('tab10', n_ch)
    line_styles = {'local': '-o', 'peer': '--s', 'signal': '-.^'}
    labels = {'local': 'local', 'peer': 'peer', 'signal': 'signal'}

    plt.figure(figsize=(14, 7))
    for idx, ch in enumerate(channels_to_plot):
        color = color_map(idx)
        for kind in ['local', 'peer', 'signal']:
            y, valid_counters = [], []
            for counter in counters:
                entry = next((e for e in data_per_counter[counter] if e['channel'] == ch), None)
                if entry:
                    y.append(entry[kind]['phase'])
                    valid_counters.append(counter)
            if valid_counters:
                y = np.unwrap(y)
                plt.plot(valid_counters, y, line_styles[kind], color=color,
                         label=f'ch{ch} {labels[kind]}')
    plt.xlabel('Ranging Counter')
    plt.ylabel('Unwrapped Phase (rad)')
    plt.title('Phase vs Counter for Each Channel (Pretty)')
    plt.legend(loc='best', ncol=2)
    plt.grid()
    plt.tight_layout()
    plt.show()

channels_to_plot = [2, 14, 29, 50]  # 可自由调节
plot_amplitude_vs_counter_pretty(data_per_counter, channels_to_plot)
plot_phase_vs_counter_pretty(data_per_counter, channels_to_plot)
# Out:
# C:\Users\cwdbo\AppData\Local\Temp\ipykernel_8512\2119902642.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = cm.get_cmap('tab10', n_ch)
# C:\Users\cwdbo\AppData\Local\Temp\ipykernel_8512\2119902642.py:42: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   color_map = cm.get_cmap('tab10', n_ch)

# %% [markdown]
# 单次采样的相位变化，可见mode-0确实需要每一次都执行。否则，local应该是静止的

# %%
import numpy as np
import matplotlib.pyplot as plt

def plot_phase_vs_channel_at_counter(data_per_counter, counter):
    """
    展示某一counter下，所有channel的local/peer/signal相位随channel变化
    """
    if counter not in data_per_counter:
        print(f"Counter {counter} not found.")
        return
    ch_entries = sorted(data_per_counter[counter], key=lambda e: e['channel'])
    channels = [e['channel'] for e in ch_entries]
    local_phs = np.unwrap([e['local']['phase'] for e in ch_entries])
    peer_phs  = np.unwrap([e['peer']['phase']  for e in ch_entries])
    signal_phs= np.unwrap([e['signal']['phase'] for e in ch_entries])

    plt.figure(figsize=(10,5))
    plt.plot(channels, local_phs, '-o', label='local')
    plt.plot(channels, peer_phs, '--s', label='peer')
    plt.plot(channels, signal_phs, '-.^', label='signal')
    plt.xlabel('Channel')
    plt.ylabel('Unwrapped Phase (rad)')
    plt.title(f'Counter {counter}: Phase vs Channel')
    plt.legend()
    plt.grid()
    plt.tight_layout()
    plt.show()

plot_phase_vs_channel_at_counter(data_per_counter, counter=0)  # counter编号可自定
